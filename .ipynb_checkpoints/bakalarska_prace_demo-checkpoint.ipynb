# %% [markdown]
# # Načtení dat

# %%
import pandas as pd
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import optuna

from plotly.subplots import make_subplots
from matplotlib import pyplot as plt
from mlforecast import MLForecast
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from statsforecast import StatsForecast
from statsforecast.models import Naive, HistoricAverage, WindowAverage

# %%
# Load dataset
df = pd.read_csv("data/dataset_ml.csv", sep=';', parse_dates=['date'], date_format='%d.%m.%Y')

df.head(10)
# Out:
#         region       date  price
# 0        praha 2019-03-31  73818
# 1        praha 2019-06-30  75162
# 2        praha 2019-09-30  77202
# 3        praha 2019-12-31  79382
# 4  stredocesky 2019-03-31  28777
# 5  stredocesky 2019-06-30  31328
# 6  stredocesky 2019-09-30  31846
# 7  stredocesky 2019-12-31  32882
# 8    jihocesky 2019-03-31  26028
# 9    jihocesky 2019-06-30  26896

# %%
# Prague only
only_prague = df[df["region"] == "praha"]
one_length = len(only_prague)
print(one_length)
print(only_prague)
# Out:
# 24
#     region       date   price
# 0    praha 2019-03-31   73818
# 1    praha 2019-06-30   75162
# 2    praha 2019-09-30   77202
# 3    praha 2019-12-31   79382
# 56   praha 2020-03-31   82409
# 57   praha 2020-06-30   84096
# 58   praha 2020-09-30   88315
# 59   praha 2020-12-31   88315
# 112  praha 2021-03-31   93413
# 113  praha 2021-06-30   96950
# 114  praha 2021-09-30  103196
# 115  praha 2021-12-31  109350
# 168  praha 2022-03-31  110995
# 169  praha 2022-06-30  114746
# 170  praha 2022-09-30  114792
# 171  praha 2022-12-31  110171
# 224  praha 2023-03-31  103549
# 225  praha 2023-06-30  103992
# 226  praha 2023-09-30  103859
# 227  praha 2023-12-31  103372
# 280  praha 2024-03-31  109246
# 281  praha 2024-06-30  114305
# 282  praha 2024-09-30  118362
# 283  praha 2024-12-31  121643

# %%
fig = px.line(
    df,
    x="date",
    y="price",
    color="region",
    title="Historical apartment prices in CR",
    color_discrete_sequence=px.colors.qualitative.Alphabet
)

fig.update_yaxes(range=[df["price"].min(), df["price"].max()])

fig.update_layout(
    autosize=True,
    height=500,
    xaxis_title="Price [m2]",
    yaxis_title="Date",
    legend_title="Region"
)

fig.show()

# %%
all_prices = df.pivot(index="date", columns="region", values="price").reset_index()
all_prices.describe()
# Out:
# region                 date     jihocesky  jihomoravsky   karlovarsky  \
# count                    24     24.000000     24.000000     24.000000
# mean    2022-02-13 18:00:00  41406.625000  58228.958333  30183.208333
# min     2019-03-31 00:00:00  26028.000000  39865.000000  20701.000000
# 25%     2020-09-07 00:00:00  33230.750000  47354.750000  23549.750000
# 50%     2022-02-14 00:00:00  45710.500000  63519.500000  33311.500000
# 75%     2023-07-23 00:00:00  49282.500000  67018.250000  35501.500000
# max     2024-12-31 00:00:00  52378.000000  73451.000000  37144.000000
# std                     NaN   8911.729271  11718.000395   6146.296325
#
# region  kralovehradecky     liberecky  moravskoslezsky     olomoucky  \
# count          24.00000     24.000000        24.000000     24.000000
# mean        40865.00000  40396.500000     34911.333333  40459.750000
# min         27075.00000  24875.000000     22170.000000  27515.000000
# 25%         32652.50000  31802.250000     27537.000000  32601.750000
# 50%         45609.00000  43760.500000     38222.000000  44611.000000
# 75%         48294.00000  48081.250000     41576.250000  47732.500000
# max         50018.00000  50588.000000     44031.000000  49880.000000
# std          8435.44919   8723.873302      7744.180259   8331.739336
#
# region    pardubicky      plzensky          praha   stredocesky       ustecky  \
# count      24.000000     24.000000      24.000000     24.000000     24.000000
# mean    43229.291667  43448.750000   99193.333333  46866.166667  30034.958333
# min     28214.000000  30769.000000   73818.000000  28777.000000  18357.000000
# 25%     35761.000000  34728.500000   87260.250000  37832.250000  23662.750000
# 50%     47488.500000  46640.000000  103460.500000  51836.500000  33369.500000
# 75%     50212.750000  50995.750000  110377.000000  55122.250000  35282.750000
# max     53864.000000  56063.000000  121643.000000  58474.000000  37944.000000
# std      8968.796485   8688.045506   14786.199164  10088.469396   6648.853693
#
# region      vysocina       zlinsky
# count      24.000000     24.000000
# mean    41173.375000  40060.333333
# min     26948.000000  27871.000000
# 25%     33558.500000  31711.500000
# 50%     44886.500000  43609.500000
# 75%     48702.000000  47064.750000
# max     52256.000000  50700.000000
# std      8660.524669   8361.397068

# %%
order = df.groupby("region")["price"].median().sort_values().index

plt.figure(figsize=(12, 6), dpi=200)
sns.boxplot(data=df, x="region", y="price", order=order)
plt.xticks(rotation=90)
plt.xlabel("Region")
plt.ylabel("Price [m2]")
plt.title("Boxplot of apartment prices by region")
plt.tight_layout()
plt.show()

# %%
all_prices_diff = all_prices.set_index("date").diff().dropna()
corr_matrix = all_prices_diff.corr()

plt.figure(figsize=(12, 10), dpi=200)
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".3f",
    cmap="coolwarm",
    center=0
)

plt.title("Correlation matrix between regions")
plt.show()

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Hyperparameters

# %%
lags = [1, 2, 3, 4] # last year
h = 1 # next quarter
step_size = 1

max_num_windows = (one_length - (max(lags) + h)) // step_size
print(max_num_windows)
# Out:
# 19

# %% [markdown]
# ## Random Forest Regressor & XGBoost Hyperparameter Tuning

# %%
def tune_model(model_class, param_func, n_trials=20):
    model_name = model_class.__name__
    print(f"Initializing tuning for: {model_name}...")

    def objective(trial):
        params = param_func(trial)
        
        model = model_class(**params)
        
        mlf_tune = MLForecast(
            models=[model],
            freq='QE',
            lags=lags
        )
        
        cv_results = mlf_tune.cross_validation(
            df=df, 
            h=h, 
            step_size=step_size,
            n_windows=max_num_windows,
            id_col='region',
            time_col='date', 
            target_col='price',
        )
        
        error = mean_absolute_error(cv_results['price'], cv_results[model_name])
        return error

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=n_trials)
    
    print(f"Tuning {model_name} completed. Best MAE: {study.best_value:.2f}")
    return study.best_params

# %%
def xgb_params(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 6),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'random_state': 0,
        'n_jobs': -1
    }

def rf_params(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 10),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
        'random_state': 0,
        'n_jobs': -1
    }

best_params_xgb = tune_model(XGBRegressor, xgb_params, 20)
best_params_rf = tune_model(RandomForestRegressor, rf_params, 20)
# Out:
# [I 2026-03-03 12:59:01,241] A new study created in memory with name: no-name-0d541ba2-69c1-4596-9f0e-d54dfc80b353
# Initializing tuning for: XGBRegressor...
# [I 2026-03-03 12:59:02,881] Trial 0 finished with value: 2269.700927734375 and parameters: {'n_estimators': 214, 'max_depth': 4, 'learning_rate': 0.020321310435429844, 'subsample': 0.97436337922216, 'colsample_bytree': 0.7982443695490886}. Best is trial 0 with value: 2269.700927734375.
# [I 2026-03-03 12:59:04,325] Trial 1 finished with value: 3422.73681640625 and parameters: {'n_estimators': 127, 'max_depth': 5, 'learning_rate': 0.015235112689467426, 'subsample': 0.5706146151425295, 'colsample_bytree': 0.6588885910114823}. Best is trial 0 with value: 2269.700927734375.
# [I 2026-03-03 12:59:05,674] Trial 2 finished with value: 2034.4384765625 and parameters: {'n_estimators': 257, 'max_depth': 2, 'learning_rate': 0.05414466455736233, 'subsample': 0.7898211675966779, 'colsample_bytree': 0.9916750659031879}. Best is trial 2 with value: 2034.4384765625.
# [I 2026-03-03 12:59:07,315] Trial 3 finished with value: 3614.22412109375 and parameters: {'n_estimators': 174, 'max_depth': 6, 'learning_rate': 0.010103427949112698, 'subsample': 0.9249825229033368, 'colsample_bytree': 0.6851370647729818}. Best is trial 2 with value: 2034.4384765625.
# [I 2026-03-03 12:59:08,518] Trial 4 finished with value: 2227.409423828125 and parameters: {'n_estimators': 114, 'max_depth': 6, 'learning_rate': 0.0557565402146582, 'subsample': 0.9873713158352497, 'colsample_bytree': 0.7725278367559811}. Best is trial 2 with value: 2034.4384765625.
# [I 2026-03-03 12:59:10,093] Trial 5 finished with value: 2131.275390625 and parameters: {'n_estimators': 215, 'max_depth': 5, 'learning_rate': 0.047961276204764605, 'subsample': 0.7196055457435213, 'colsample_bytree': 0.6048534479057279}. Best is trial 2 with value: 2034.4384765625.
# [I 2026-03-03 12:59:12,201] Trial 6 finished with value: 2374.970458984375 and parameters: {'n_estimators': 269, 'max_depth': 6, 'learning_rate': 0.01566098230568504, 'subsample': 0.6682567730249531, 'colsample_bytree': 0.561198728014771}. Best is trial 2 with value: 2034.4384765625.
# [I 2026-03-03 12:59:12,810] Trial 7 finished with value: 6824.8525390625 and parameters: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.011301076671483947, 'subsample': 0.6108428880864534, 'colsample_bytree': 0.6343923632214016}. Best is trial 2 with value: 2034.4384765625.
# [I 2026-03-03 12:59:13,461] Trial 8 finished with value: 3931.098388671875 and parameters: {'n_estimators': 79, 'max_depth': 2, 'learning_rate': 0.02304170391240848, 'subsample': 0.5327912419463482, 'colsample_bytree': 0.7016220020559651}. Best is trial 2 with value: 2034.4384765625.
# [I 2026-03-03 12:59:14,311] Trial 9 finished with value: 2160.47607421875 and parameters: {'n_estimators': 118, 'max_depth': 3, 'learning_rate': 0.07091182163429216, 'subsample': 0.645025636690443, 'colsample_bytree': 0.6269511999677797}. Best is trial 2 with value: 2034.4384765625.
# [I 2026-03-03 12:59:15,660] Trial 10 finished with value: 2049.18603515625 and parameters: {'n_estimators': 296, 'max_depth': 2, 'learning_rate': 0.09716302978097273, 'subsample': 0.8032290341475892, 'colsample_bytree': 0.9916346239288703}. Best is trial 2 with value: 2034.4384765625.
# [I 2026-03-03 12:59:16,965] Trial 11 finished with value: 2041.448486328125 and parameters: {'n_estimators': 288, 'max_depth': 2, 'learning_rate': 0.08528743900835128, 'subsample': 0.8318855666832853, 'colsample_bytree': 0.9791055784780291}. Best is trial 2 with value: 2034.4384765625.
# [I 2026-03-03 12:59:18,170] Trial 12 finished with value: 2092.30126953125 and parameters: {'n_estimators': 257, 'max_depth': 2, 'learning_rate': 0.03669319480393576, 'subsample': 0.8264964555301296, 'colsample_bytree': 0.9959691404028033}. Best is trial 2 with value: 2034.4384765625.
# [I 2026-03-03 12:59:20,163] Trial 13 finished with value: 2091.66455078125 and parameters: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.09820570482064171, 'subsample': 0.8615730945426988, 'colsample_bytree': 0.88912294948875}. Best is trial 2 with value: 2034.4384765625.
# [I 2026-03-03 12:59:21,428] Trial 14 finished with value: 2001.5 and parameters: {'n_estimators': 226, 'max_depth': 2, 'learning_rate': 0.06773484735417805, 'subsample': 0.7611099286446696, 'colsample_bytree': 0.9043391925754731}. Best is trial 14 with value: 2001.5.
# [I 2026-03-03 12:59:22,737] Trial 15 finished with value: 2042.4544677734375 and parameters: {'n_estimators': 231, 'max_depth': 3, 'learning_rate': 0.04220665278548493, 'subsample': 0.7452025825022769, 'colsample_bytree': 0.8628137797398961}. Best is trial 14 with value: 2001.5.
# [I 2026-03-03 12:59:24,064] Trial 16 finished with value: 2042.382080078125 and parameters: {'n_estimators': 188, 'max_depth': 4, 'learning_rate': 0.06374679670049527, 'subsample': 0.6972831461109151, 'colsample_bytree': 0.9107395444619057}. Best is trial 14 with value: 2001.5.
# [I 2026-03-03 12:59:25,264] Trial 17 finished with value: 2110.48486328125 and parameters: {'n_estimators': 250, 'max_depth': 2, 'learning_rate': 0.031134112684054593, 'subsample': 0.772631173227876, 'colsample_bytree': 0.8391822448857739}. Best is trial 14 with value: 2001.5.
# [I 2026-03-03 12:59:26,401] Trial 18 finished with value: 2176.196533203125 and parameters: {'n_estimators': 185, 'max_depth': 3, 'learning_rate': 0.030052975661377348, 'subsample': 0.8785301813158444, 'colsample_bytree': 0.9233482833980141}. Best is trial 14 with value: 2001.5.
# [I 2026-03-03 12:59:27,585] Trial 19 finished with value: 2051.47705078125 and parameters: {'n_estimators': 158, 'max_depth': 4, 'learning_rate': 0.0715885595865874, 'subsample': 0.7696043618498398, 'colsample_bytree': 0.9402082499778872}. Best is trial 14 with value: 2001.5.
# [I 2026-03-03 12:59:27,586] A new study created in memory with name: no-name-b7415dfa-342d-4a95-82d8-72c6812eb44e
# Tuning XGBRegressor completed. Best MAE: 2001.50
# Initializing tuning for: RandomForestRegressor...
# [I 2026-03-03 12:59:34,338] Trial 0 finished with value: 2427.9694592124133 and parameters: {'n_estimators': 260, 'max_depth': 10, 'min_samples_split': 4}. Best is trial 0 with value: 2427.9694592124133.
# [I 2026-03-03 12:59:41,051] Trial 1 finished with value: 2552.8740480520996 and parameters: {'n_estimators': 261, 'max_depth': 9, 'min_samples_split': 6}. Best is trial 0 with value: 2427.9694592124133.
# [I 2026-03-03 12:59:47,931] Trial 2 finished with value: 2496.866796660161 and parameters: {'n_estimators': 265, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 0 with value: 2427.9694592124133.
# [I 2026-03-03 12:59:54,954] Trial 3 finished with value: 2435.8922217197396 and parameters: {'n_estimators': 273, 'max_depth': 5, 'min_samples_split': 4}. Best is trial 0 with value: 2427.9694592124133.
# [I 2026-03-03 12:59:59,212] Trial 4 finished with value: 2943.557585340445 and parameters: {'n_estimators': 155, 'max_depth': 10, 'min_samples_split': 10}. Best is trial 0 with value: 2427.9694592124133.
# [I 2026-03-03 13:00:04,795] Trial 5 finished with value: 2647.5594101001916 and parameters: {'n_estimators': 202, 'max_depth': 7, 'min_samples_split': 7}. Best is trial 0 with value: 2427.9694592124133.
# [I 2026-03-03 13:00:10,021] Trial 6 finished with value: 2645.365495000385 and parameters: {'n_estimators': 190, 'max_depth': 7, 'min_samples_split': 7}. Best is trial 0 with value: 2427.9694592124133.
# [I 2026-03-03 13:00:12,529] Trial 7 finished with value: 2385.1992822511347 and parameters: {'n_estimators': 78, 'max_depth': 6, 'min_samples_split': 4}. Best is trial 7 with value: 2385.1992822511347.
# [I 2026-03-03 13:00:18,742] Trial 8 finished with value: 3598.708925425976 and parameters: {'n_estimators': 245, 'max_depth': 2, 'min_samples_split': 3}. Best is trial 7 with value: 2385.1992822511347.
# [I 2026-03-03 13:00:23,125] Trial 9 finished with value: 2659.223871443582 and parameters: {'n_estimators': 160, 'max_depth': 9, 'min_samples_split': 7}. Best is trial 7 with value: 2385.1992822511347.
# [I 2026-03-03 13:00:25,142] Trial 10 finished with value: 2675.3412659709434 and parameters: {'n_estimators': 53, 'max_depth': 3, 'min_samples_split': 2}. Best is trial 7 with value: 2385.1992822511347.
# [I 2026-03-03 13:00:27,646] Trial 11 finished with value: 2461.5354622286354 and parameters: {'n_estimators': 79, 'max_depth': 6, 'min_samples_split': 5}. Best is trial 7 with value: 2385.1992822511347.
# [I 2026-03-03 13:00:31,066] Trial 12 finished with value: 2291.913841155895 and parameters: {'n_estimators': 112, 'max_depth': 8, 'min_samples_split': 2}. Best is trial 12 with value: 2291.913841155895.
# [I 2026-03-03 13:00:34,383] Trial 13 finished with value: 2261.2954312309193 and parameters: {'n_estimators': 108, 'max_depth': 7, 'min_samples_split': 2}. Best is trial 13 with value: 2261.2954312309193.
# [I 2026-03-03 13:00:37,972] Trial 14 finished with value: 2294.089657740905 and parameters: {'n_estimators': 120, 'max_depth': 8, 'min_samples_split': 2}. Best is trial 13 with value: 2261.2954312309193.
# [I 2026-03-03 13:00:41,720] Trial 15 finished with value: 2294.317086871207 and parameters: {'n_estimators': 126, 'max_depth': 8, 'min_samples_split': 2}. Best is trial 13 with value: 2261.2954312309193.
# [I 2026-03-03 13:00:45,195] Trial 16 finished with value: 2822.7303587869433 and parameters: {'n_estimators': 114, 'max_depth': 7, 'min_samples_split': 9}. Best is trial 13 with value: 2261.2954312309193.
# [I 2026-03-03 13:00:47,962] Trial 17 finished with value: 2356.8473057917145 and parameters: {'n_estimators': 85, 'max_depth': 5, 'min_samples_split': 3}. Best is trial 13 with value: 2261.2954312309193.
# [I 2026-03-03 13:00:53,723] Trial 18 finished with value: 2330.731540036548 and parameters: {'n_estimators': 216, 'max_depth': 8, 'min_samples_split': 3}. Best is trial 13 with value: 2261.2954312309193.
# [I 2026-03-03 13:00:57,800] Trial 19 finished with value: 2489.4588726571214 and parameters: {'n_estimators': 142, 'max_depth': 9, 'min_samples_split': 5}. Best is trial 13 with value: 2261.2954312309193.
# Tuning RandomForestRegressor completed. Best MAE: 2261.30

# %% [markdown]
# ## Training

# %%
best_xgb = XGBRegressor(**best_params_xgb, random_state=0)
best_rf = RandomForestRegressor(**best_params_rf, random_state=0)

mlf = MLForecast(
    models=[
        LinearRegression(),
        best_xgb,
        best_rf
    ],
    freq='QE',
    lags=lags,
)

sf = StatsForecast(
    models=[
        Naive(), 
        HistoricAverage(), 
        WindowAverage(window_size=max(lags))
    ],
    freq='QE',
)

cv_results_ml = mlf.cross_validation(
    df=df, 
    h=h, 
    step_size=step_size,
    n_windows=max_num_windows,
    id_col='region',
    time_col='date', 
    target_col='price',
)

cv_results_stat = sf.cross_validation(
    df=df,
    h=h, 
    step_size=step_size, 
    n_windows=max_num_windows,
    id_col='region',
    time_col='date', 
    target_col='price',
)

# %% [markdown]
# ## Results Analysis

# %%
def eval_pd(df: pd.DataFrame, col_name: str) -> None:
    mae = mean_absolute_error(
        df["price"],
        df[col_name]
    )
    mae_percent = (mae / df["price"].mean()) * 100

    print("-" * 50)
    print(f"Results for {col_name}")
    print(f"MAE: {mae:.2f} CZK")
    print(f"MAE (%): {mae_percent:.2f} %")

# %%
for model in sf.models:
    eval_pd(cv_results_stat, model.alias)

for model in mlf.models:
    eval_pd(cv_results_ml, model)
# Out:
# --------------------------------------------------
# Results for Naive
# MAE: 1833.51 CZK
# MAE (%): 3.78 %
# --------------------------------------------------
# Results for HistoricAverage
# MAE: 9574.61 CZK
# MAE (%): 19.76 %
# --------------------------------------------------
# Results for WindowAverage
# MAE: 3884.76 CZK
# MAE (%): 8.02 %
# --------------------------------------------------
# Results for LinearRegression
# MAE: 1762.08 CZK
# MAE (%): 3.64 %
# --------------------------------------------------
# Results for XGBRegressor
# MAE: 2001.50 CZK
# MAE (%): 4.13 %
# --------------------------------------------------
# Results for RandomForestRegressor
# MAE: 2261.30 CZK
# MAE (%): 4.67 %

# %% [markdown]
# ## Graphical Visualization

# %%
def show_graph(df: pd.DataFrame, forecasts: pd.DataFrame) -> None:
    regione = df["region"].unique()

    model_columns = [
        col for col in forecasts.columns
        if col not in ["region", "date"]
    ]

    colors = px.colors.qualitative.Plotly
    model_colors = {
        model: colors[i % len(colors)]
        for i, model in enumerate(model_columns)
    }

    fig = make_subplots(
        rows=len(regione),
        cols=1,
        shared_xaxes=False,
        vertical_spacing=0.02,
        subplot_titles=regione
    )

    trace_map = []

    for i, region in enumerate(regione, start=1):

        real = df[df["region"] == region]
        preds = forecasts[forecasts["region"] == region]

        # Actual
        fig.add_trace(
            go.Scatter(
                x=real["date"],
                y=real["price"],
                mode="lines",
                name="Actual",
                line=dict(color="black", width=4),
                showlegend=(i == 1)
            ),
            row=i,
            col=1
        )

        trace_map.append(("Actual", len(fig.data)-1))

        # Models
        for model in model_columns:
            if model in preds.columns:
                fig.add_trace(
                    go.Scatter(
                        x=preds["date"],
                        y=preds[model],
                        mode="lines",
                        name=model,
                        line=dict(color=model_colors[model]),
                        showlegend=(i == 1)
                    ),
                    row=i,
                    col=1
                )

                trace_map.append((model, len(fig.data)-1))

    # DROPDOWN MENU
    buttons = []

    for model in model_columns:
        visibility = []

        for name, idx in trace_map:
            if name == "Actual" or name == model:
                visibility.append(True)
            else:
                visibility.append(False)

        buttons.append(
            dict(
                label=model,
                method="update",
                args=[{"visible": visibility}]
            )
        )

    buttons.insert(
        0,
        dict(
            label="All models",
            method="update",
            args=[{"visible": [True] * len(trace_map)}]
        )
    )

    fig.update_layout(
        height=500 * len(regione),
        width=1100,
        legend=dict(
            orientation="v",
            x=1.02,
            xanchor="left",
            y=0.99,
            yanchor="top"
        ),
        updatemenus=[
            dict(
                buttons=buttons,
                direction="down",
                showactive=True,
                x=1.02,
                xanchor="left",
                y=1.0,
                yanchor="top"
            )
        ]
    )

    fig.show()

# %%
ml_forecasts = cv_results_ml.drop(columns=["price", "cutoff"])
stat_forecasts = cv_results_stat.drop(columns=["price", "cutoff"])

combined_forecasts = pd.merge(
    ml_forecasts,
    stat_forecasts,
    on=["region", "date"],
    how="inner"
)

show_graph(df, combined_forecasts)

# %% [markdown]
# # Prediction

# %%
mlf.fit(
    df=df,
    id_col='region',
    time_col='date',
    target_col='price'
)

predictions_ml = mlf.predict(h=4)

# %% [markdown]
# ## Graph Vizualization

# %%
show_graph(df, predictions_ml)
