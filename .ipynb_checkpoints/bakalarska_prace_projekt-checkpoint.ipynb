# %%
import pandas as pd
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
import optuna

from plotly.subplots import make_subplots
from matplotlib import pyplot as plt
from mlforecast import MLForecast
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsforecast import StatsForecast
from statsforecast.models import Naive, HistoricAverage, WindowAverage, AutoARIMA, AutoETS
from typing import Callable, List, Type

# %% [markdown]
# # Helper Functions

# %%
def eval_by_region(cv_df: pd.DataFrame, model_cols: list, caption: str = "MAPE by region") -> None:
    rows = []
    for region in sorted(cv_df['region'].unique()):
        subset = cv_df[cv_df['region'] == region]
        row = {'region': region}
        for model in model_cols:
            mae_pcts = []
            for h in sorted(subset['horizon'].unique()):
                h_subset = subset[subset['horizon'] == h]
                mae = mean_absolute_error(h_subset['price'], h_subset[model])
                mae_pcts.append((mae / h_subset['price'].mean()) * 100)
            row[model] = round(np.mean(mae_pcts), 2)
        rows.append(row)
    
    table = pd.DataFrame(rows).set_index('region')
    
    display(table.style
        .format('{:.2f}%')
        .background_gradient(cmap='Blues', axis=None)
        .highlight_min(axis=1, props='font-weight: bold; border: 3px solid black;')
        .set_caption(caption)
    )

# %%
def add_horizon(cv_df: pd.DataFrame) -> pd.DataFrame:
    cv_df = cv_df.copy()
    cv_df['horizon'] = cv_df.groupby(['region', 'cutoff']).cumcount() + 1
    return cv_df

# %%
def eval_by_horizon(cv_df: pd.DataFrame, model_cols: List[str]) -> pd.DataFrame:
    rows = []
    
    for model in model_cols:
        row = {'model': model}
        
        for h in range(1, 5):
            subset = cv_df[cv_df['horizon'] == h]
            
            mae = mean_absolute_error(subset['price'], subset[model])
            mae_pct = (mae / subset['price'].mean()) * 100
            rmse = np.sqrt(mean_squared_error(subset['price'], subset[model]))
            
            row[f'H{h} MAE'] = round(mae, 0)
            row[f'H{h} MAPE'] = round(mae_pct, 2)
            row[f'H{h} RMSE'] = round(rmse, 0)
            
        rows.append(row)
    return pd.DataFrame(rows).set_index('model')

# %%
def display_eval_table(table: pd.DataFrame, caption: str) -> None:
    table = table.copy()
    
    for metric in ['MAE', 'MAPE', 'RMSE']:
        cols = [c for c in table.columns if c.endswith(metric)]
        table[f'Avg {metric}'] = table[cols].mean(axis=1)
    
    mae_pct_cols = [c for c in table.columns if 'MAPE' in c]
    rmse_cols = [c for c in table.columns if 'RMSE' in c and 'MAE' not in c]

    display(table.style
        .format({
            col: '{:.2f}%' if 'MAPE' in col else '{:.0f}'
            for col in table.columns
        })
        .background_gradient(cmap='Blues', axis=None, subset=mae_pct_cols)
        .background_gradient(cmap='Purples', axis=None, subset=rmse_cols)
        .set_caption(caption)
    )

# %%
def show_graph(df: pd.DataFrame, forecasts: pd.DataFrame) -> None:
    regione = df["region"].unique()

    model_columns = [
        col for col in forecasts.columns
        if col not in ["region", "date"]
    ]

    colors = px.colors.qualitative.Plotly
    model_colors = {
        model: colors[i % len(colors)]
        for i, model in enumerate(model_columns)
    }

    fig = make_subplots(
        rows=len(regione),
        cols=1,
        shared_xaxes=False,
        vertical_spacing=0.02,
        subplot_titles=regione
    )

    trace_map = []

    for i, region in enumerate(regione, start=1):

        real = df[df["region"] == region]
        preds = forecasts[forecasts["region"] == region]

        # Actual
        fig.add_trace(
            go.Scatter(
                x=real["date"],
                y=real["price"],
                mode="lines",
                name="Actual",
                line=dict(color="black", width=3),
                showlegend=(i == 1)
            ),
            row=i,
            col=1
        )

        trace_map.append(("Actual", len(fig.data)-1))

        # Models
        for model in model_columns:
            if model in preds.columns:
                first_pred_date = preds["date"].iloc[0]
                last_actual = real[real["date"] < first_pred_date].iloc[-1]
                
                connector_x = [last_actual["date"]] + list(preds["date"])
                connector_y = [last_actual["price"]] + list(preds[model])
                
                fig.add_trace(
                    go.Scatter(
                        x=connector_x,
                        y=connector_y,
                        mode="lines",
                        name=model,
                        line=dict(color=model_colors[model]),
                        showlegend=(i == 1)
                    ),
                    row=i,
                    col=1
                )

                trace_map.append((model, len(fig.data)-1))

    # DROPDOWN MENU
    buttons = []

    for model in model_columns:
        visibility = []

        for name, idx in trace_map:
            if name == "Actual" or name == model:
                visibility.append(True)
            else:
                visibility.append(False)

        buttons.append(
            dict(
                label=model,
                method="update",
                args=[{"visible": visibility}]
            )
        )

    buttons.insert(
        0,
        dict(
            label="All models",
            method="update",
            args=[{"visible": [True] * len(trace_map)}]
        )
    )

    fig.update_layout(
        height=500 * len(regione),
        width=1100,
        legend=dict(
            orientation="v",
            x=1.02,
            xanchor="left",
            y=0.99,
            yanchor="top"
        ),
        updatemenus=[
            dict(
                buttons=buttons,
                direction="down",
                showactive=True,
                x=1.02,
                xanchor="left",
                y=1.0,
                yanchor="top"
            )
        ]
    )

    fig.show()

# %% [markdown]
# # Load Data

# %%
# Load dataset
df = pd.read_csv("data/dataset_ml.csv", sep=';', parse_dates=['date'], date_format='%d.%m.%Y')

dates_sorted = sorted(df['date'].unique())
holdout_dates = dates_sorted[-4:]           # 2024 Q1–Q4
cutoff_date = holdout_dates[0]              # 2024-03-31

df_train = df[df['date'] < cutoff_date].copy()    # training data
df_holdout = df[df['date'] >= cutoff_date].copy() # holdout data

print(f"Training set ends at:  {df_train['date'].max().date()}")
print(f"Holdout set starts at: {df_holdout['date'].min().date()}")

df.head(10)
# Out:
# Training set ends at:  2023-12-31
# Holdout set starts at: 2024-03-31
#         region       date  price
# 0        praha 2019-03-31  73818
# 1        praha 2019-06-30  75162
# 2        praha 2019-09-30  77202
# 3        praha 2019-12-31  79382
# 4  stredocesky 2019-03-31  28777
# 5  stredocesky 2019-06-30  31328
# 6  stredocesky 2019-09-30  31846
# 7  stredocesky 2019-12-31  32882
# 8    jihocesky 2019-03-31  26028
# 9    jihocesky 2019-06-30  26896

# %%
# Prague only
only_prague = df_train[df_train["region"] == "praha"]
one_length = len(only_prague)
print(one_length)
print(only_prague)
# Out:
# 20
#     region       date   price
# 0    praha 2019-03-31   73818
# 1    praha 2019-06-30   75162
# 2    praha 2019-09-30   77202
# 3    praha 2019-12-31   79382
# 56   praha 2020-03-31   82409
# 57   praha 2020-06-30   84096
# 58   praha 2020-09-30   88315
# 59   praha 2020-12-31   88315
# 112  praha 2021-03-31   93413
# 113  praha 2021-06-30   96950
# 114  praha 2021-09-30  103196
# 115  praha 2021-12-31  109350
# 168  praha 2022-03-31  110995
# 169  praha 2022-06-30  114746
# 170  praha 2022-09-30  114792
# 171  praha 2022-12-31  110171
# 224  praha 2023-03-31  103549
# 225  praha 2023-06-30  103992
# 226  praha 2023-09-30  103859
# 227  praha 2023-12-31  103372

# %%
fig = px.line(
    df_train,
    x="date",
    y="price",
    color="region",
    title="Historical apartment prices in CR",
    color_discrete_sequence=px.colors.qualitative.Alphabet
)

fig.update_yaxes(range=[df["price"].min(), df["price"].max()])

fig.update_layout(
    autosize=True,
    height=500,
    xaxis_title="Price [m2]",
    yaxis_title="Date",
    legend_title="Region"
)

fig.show()

# %%
all_prices = df_train.pivot(index="date", columns="region", values="price").reset_index()
all_prices.describe()
# Out:
# region                 date     jihocesky  jihomoravsky  karlovarsky  \
# count                    20     20.000000     20.000000     20.00000
# mean    2021-08-15 01:12:00  39707.150000  55455.600000  28958.00000
# min     2019-03-31 00:00:00  26028.000000  39865.000000  20701.00000
# 25%     2020-06-07 06:00:00  32658.500000  46353.500000  23192.00000
# 50%     2021-08-15 00:00:00  41073.500000  57148.000000  29828.50000
# 75%     2022-10-23 00:00:00  46287.000000  65222.000000  33729.75000
# max     2023-12-31 00:00:00  52378.000000  69560.000000  37072.00000
# std                     NaN   8825.231545  10839.622728   6012.02003
#
# region  kralovehradecky     liberecky  moravskoslezsky     olomoucky  \
# count         20.000000     20.000000        20.000000     20.000000
# mean       39141.000000  38689.800000     33277.000000  38839.900000
# min        27075.000000  24875.000000     22170.000000  27515.000000
# 25%        31684.750000  31137.000000     26916.500000  31705.750000
# 50%        41026.000000  39067.000000     35189.000000  39138.000000
# 75%        46505.000000  46103.000000     38909.000000  46039.250000
# max        48994.000000  50588.000000     43130.000000  49722.000000
# std         8205.422135   8580.439343      7451.629317   8202.941019
#
# region    pardubicky      plzensky          praha   stredocesky       ustecky  \
# count      20.000000     20.000000      20.000000     20.000000     20.000000
# mean    41436.950000  41583.100000   95854.200000  44749.450000  28782.750000
# min     28214.000000  30769.000000   73818.000000  28777.000000  18357.000000
# 25%     34977.000000  33722.250000   83674.250000  37166.250000  23037.500000
# 50%     42864.000000  42313.000000  100073.000000  46307.000000  30584.000000
# 75%     49818.750000  48177.250000  105331.500000  52822.000000  34273.000000
# max     52349.000000  53267.000000  114792.000000  57688.000000  37495.000000
# std      8746.516085   8267.243198   13773.904868   9723.451334   6581.286851
#
# region      vysocina       zlinsky
# count      20.000000     20.000000
# mean    39296.000000  38291.550000
# min     26948.000000  27871.000000
# 25%     31446.500000  30220.750000
# 50%     39570.500000  39016.500000
# 75%     46639.750000  45472.500000
# max     50247.000000  49553.000000
# std      8257.290361   8036.761874

# %%
order = df_train.groupby("region")["price"].median().sort_values().index

plt.figure(figsize=(12, 6), dpi=200)
sns.boxplot(data=df_train, x="region", y="price", order=order)
plt.xticks(rotation=90)
plt.xlabel("Region")
plt.ylabel("Price [m2]")
plt.title("Boxplot of apartment prices by region")
plt.tight_layout()
plt.show()

# %%
all_prices_diff = all_prices.set_index("date").diff().dropna()
corr_matrix = all_prices_diff.corr()

plt.figure(figsize=(12, 10), dpi=200)
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".3f",
    cmap="coolwarm",
    center=0
)

plt.title("Correlation matrix between cities")
plt.show()

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Hyperparameters

# %%
lags = [1, 2, 3, 4]
h = 4
step_size = 1

max_num_windows = (one_length - max(lags) - h) // step_size
print(max_num_windows)
# Out:
# 12

# %% [markdown]
# ## Random Forest Regressor & XGBoost Hyperparameter Tuning

# %%
def tune_model(model_class: Type, param_func: Callable[[optuna.Trial], dict], n_trials: int=20) -> dict:
    model_name = model_class.__name__
    print(f"Initializing tuning for: {model_name}...")
    def objective(trial):
        params = param_func(trial)
        
        model = model_class(**params)
        
        mlf_tune = MLForecast(
            models=[model],
            freq='QE',
            lags=lags
        )
        
        cv_results = mlf_tune.cross_validation(
            df=df_train, 
            h=h, 
            step_size=step_size,
            n_windows=max_num_windows,
            id_col='region',
            time_col='date', 
            target_col='price',
        )
        
        mape = ((cv_results['price'] - cv_results[model_name]).abs() / cv_results['price']).mean() * 100
        return mape
        
    sampler = optuna.samplers.TPESampler(seed=0)
    study = optuna.create_study(direction='minimize', sampler=sampler)
    study.optimize(objective, n_trials=n_trials)
    
    print(f"Tuning {model_name} completed. Best MAPE: {study.best_value:.2f}%; Best params: {study.best_params}")
    return study.best_params

# %%
def xgb_params(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 6),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'random_state': 0,
        'n_jobs': -1
    }

def rf_params(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 10),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
        'random_state': 0,
        'n_jobs': -1
    }

best_params_xgb = tune_model(XGBRegressor, xgb_params, 20)
best_params_rf = tune_model(RandomForestRegressor, rf_params, 20)
# Out:
# [I 2026-04-05 22:57:40,995] A new study created in memory with name: no-name-c0a91deb-bd02-4566-a91b-9c6c1c343f16
# Initializing tuning for: XGBRegressor...
# [I 2026-04-05 22:57:42,267] Trial 0 finished with value: 10.488162029066968 and parameters: {'n_estimators': 187, 'max_depth': 5, 'learning_rate': 0.040064836619643954, 'subsample': 0.7724415914984484, 'colsample_bytree': 0.7118273996694524}. Best is trial 0 with value: 10.488162029066968.
# [I 2026-04-05 22:57:43,377] Trial 1 finished with value: 10.66131882653772 and parameters: {'n_estimators': 212, 'max_depth': 4, 'learning_rate': 0.0779422611516095, 'subsample': 0.9818313802505146, 'colsample_bytree': 0.6917207594128889}. Best is trial 0 with value: 10.488162029066968.
# [I 2026-04-05 22:57:44,644] Trial 2 finished with value: 10.667582297836578 and parameters: {'n_estimators': 248, 'max_depth': 4, 'learning_rate': 0.036986612821028816, 'subsample': 0.9627983191463305, 'colsample_bytree': 0.5355180290989434}. Best is trial 0 with value: 10.488162029066968.
# [I 2026-04-05 22:57:45,168] Trial 3 finished with value: 10.546337850000752 and parameters: {'n_estimators': 71, 'max_depth': 2, 'learning_rate': 0.06801737161546002, 'subsample': 0.8890783754749252, 'colsample_bytree': 0.9350060741234096}. Best is trial 0 with value: 10.488162029066968.
# [I 2026-04-05 22:57:47,352] Trial 4 finished with value: 10.671682889955509 and parameters: {'n_estimators': 295, 'max_depth': 5, 'learning_rate': 0.028938722964976897, 'subsample': 0.8902645881432277, 'colsample_bytree': 0.5591372129344666}. Best is trial 0 with value: 10.488162029066968.
# [I 2026-04-05 22:57:48,275] Trial 5 finished with value: 10.214132857927316 and parameters: {'n_estimators': 210, 'max_depth': 2, 'learning_rate': 0.08803774642925566, 'subsample': 0.7609241608750359, 'colsample_bytree': 0.7073309699952618}. Best is trial 5 with value: 10.214132857927316.
# [I 2026-04-05 22:57:49,313] Trial 6 finished with value: 10.568413715657174 and parameters: {'n_estimators': 116, 'max_depth': 5, 'learning_rate': 0.028585798773369732, 'subsample': 0.7842169744343243, 'colsample_bytree': 0.5093949002181776}. Best is trial 5 with value: 10.214132857927316.
# [I 2026-04-05 22:57:50,849] Trial 7 finished with value: 10.755301558408242 and parameters: {'n_estimators': 205, 'max_depth': 5, 'learning_rate': 0.04139367608357545, 'subsample': 0.9718740392573121, 'colsample_bytree': 0.8409101495517417}. Best is trial 5 with value: 10.214132857927316.
# [I 2026-04-05 22:57:51,836] Trial 8 finished with value: 10.067598086232273 and parameters: {'n_estimators': 140, 'max_depth': 4, 'learning_rate': 0.049846101320948265, 'subsample': 0.5301127358146349, 'colsample_bytree': 0.8333833577228338}. Best is trial 8 with value: 10.067598086232273.
# [I 2026-04-05 22:57:52,865] Trial 9 finished with value: 10.497190702040129 and parameters: {'n_estimators': 218, 'max_depth': 3, 'learning_rate': 0.01345631972964045, 'subsample': 0.6577141754620919, 'colsample_bytree': 0.6818553854713113}. Best is trial 8 with value: 10.067598086232273.
# [I 2026-04-05 22:57:53,774] Trial 10 finished with value: 11.537285955454331 and parameters: {'n_estimators': 127, 'max_depth': 6, 'learning_rate': 0.010489839293581736, 'subsample': 0.5100229215872224, 'colsample_bytree': 0.9746400719702609}. Best is trial 8 with value: 10.067598086232273.
# [I 2026-04-05 22:57:54,735] Trial 11 finished with value: 10.384958925640495 and parameters: {'n_estimators': 143, 'max_depth': 2, 'learning_rate': 0.09066631261472131, 'subsample': 0.6435328022133981, 'colsample_bytree': 0.8144872135983158}. Best is trial 8 with value: 10.067598086232273.
# [I 2026-04-05 22:57:55,720] Trial 12 finished with value: 10.207701968936805 and parameters: {'n_estimators': 152, 'max_depth': 3, 'learning_rate': 0.05791622979510821, 'subsample': 0.5344530404843656, 'colsample_bytree': 0.8002996786047625}. Best is trial 8 with value: 10.067598086232273.
# [I 2026-04-05 22:57:56,352] Trial 13 finished with value: 10.555255563643787 and parameters: {'n_estimators': 71, 'max_depth': 3, 'learning_rate': 0.053673197393753, 'subsample': 0.5304813556217055, 'colsample_bytree': 0.8592330020327685}. Best is trial 8 with value: 10.067598086232273.
# [I 2026-04-05 22:57:57,236] Trial 14 finished with value: 10.370469732633293 and parameters: {'n_estimators': 154, 'max_depth': 3, 'learning_rate': 0.05586765983043986, 'subsample': 0.5978805467176352, 'colsample_bytree': 0.7844042282157563}. Best is trial 8 with value: 10.067598086232273.
# [I 2026-04-05 22:57:57,947] Trial 15 finished with value: 10.801964177266713 and parameters: {'n_estimators': 105, 'max_depth': 3, 'learning_rate': 0.01899742834327318, 'subsample': 0.5879396742197991, 'colsample_bytree': 0.8928909396168978}. Best is trial 8 with value: 10.067598086232273.
# [I 2026-04-05 22:57:58,791] Trial 16 finished with value: 10.48582828439474 and parameters: {'n_estimators': 160, 'max_depth': 4, 'learning_rate': 0.054224540047382135, 'subsample': 0.6937622468191424, 'colsample_bytree': 0.7682181646417399}. Best is trial 8 with value: 10.067598086232273.
# [I 2026-04-05 22:57:59,536] Trial 17 finished with value: 10.289834289720512 and parameters: {'n_estimators': 93, 'max_depth': 6, 'learning_rate': 0.06460034891907766, 'subsample': 0.5592992243314951, 'colsample_bytree': 0.6447718908083127}. Best is trial 8 with value: 10.067598086232273.
# [I 2026-04-05 22:58:00,387] Trial 18 finished with value: 10.514992816980156 and parameters: {'n_estimators': 174, 'max_depth': 4, 'learning_rate': 0.024761391361561615, 'subsample': 0.7088903805906936, 'colsample_bytree': 0.9044750309214883}. Best is trial 8 with value: 10.067598086232273.
# [I 2026-04-05 22:58:01,419] Trial 19 finished with value: 10.140140613887109 and parameters: {'n_estimators': 255, 'max_depth': 3, 'learning_rate': 0.046269460217693105, 'subsample': 0.5002709094548956, 'colsample_bytree': 0.8007518167756079}. Best is trial 8 with value: 10.067598086232273.
# [I 2026-04-05 22:58:01,421] A new study created in memory with name: no-name-a23996db-6af2-42e7-b469-a08a572cf545
# Tuning XGBRegressor completed. Best MAPE: 10.07%; Best params: {'n_estimators': 140, 'max_depth': 4, 'learning_rate': 0.049846101320948265, 'subsample': 0.5301127358146349, 'colsample_bytree': 0.8333833577228338}
# Initializing tuning for: RandomForestRegressor...
# [I 2026-04-05 22:58:06,453] Trial 0 finished with value: 11.631808386177124 and parameters: {'n_estimators': 187, 'max_depth': 8, 'min_samples_split': 7}. Best is trial 0 with value: 11.631808386177124.
# [I 2026-04-05 22:58:11,381] Trial 1 finished with value: 11.92997602139623 and parameters: {'n_estimators': 186, 'max_depth': 5, 'min_samples_split': 7}. Best is trial 0 with value: 11.631808386177124.
# [I 2026-04-05 22:58:15,306] Trial 2 finished with value: 13.128391105896972 and parameters: {'n_estimators': 159, 'max_depth': 10, 'min_samples_split': 10}. Best is trial 0 with value: 11.631808386177124.
# [I 2026-04-05 22:58:19,369] Trial 3 finished with value: 11.268984527138311 and parameters: {'n_estimators': 146, 'max_depth': 9, 'min_samples_split': 6}. Best is trial 3 with value: 11.268984527138311.
# [I 2026-04-05 22:58:24,763] Trial 4 finished with value: 10.747513671728044 and parameters: {'n_estimators': 192, 'max_depth': 10, 'min_samples_split': 2}. Best is trial 4 with value: 10.747513671728044.
# [I 2026-04-05 22:58:27,070] Trial 5 finished with value: 11.697831203694875 and parameters: {'n_estimators': 71, 'max_depth': 2, 'min_samples_split': 9}. Best is trial 4 with value: 10.747513671728044.
# [I 2026-04-05 22:58:32,778] Trial 6 finished with value: 13.23721014734342 and parameters: {'n_estimators': 245, 'max_depth': 9, 'min_samples_split': 10}. Best is trial 4 with value: 10.747513671728044.
# [I 2026-04-05 22:58:38,851] Trial 7 finished with value: 12.77478824257933 and parameters: {'n_estimators': 250, 'max_depth': 6, 'min_samples_split': 9}. Best is trial 4 with value: 10.747513671728044.
# [I 2026-04-05 22:58:41,420] Trial 8 finished with value: 10.7753608413611 and parameters: {'n_estimators': 79, 'max_depth': 7, 'min_samples_split': 3}. Best is trial 4 with value: 10.747513671728044.
# [I 2026-04-05 22:58:48,461] Trial 9 finished with value: 11.068384459629971 and parameters: {'n_estimators': 287, 'max_depth': 6, 'min_samples_split': 5}. Best is trial 4 with value: 10.747513671728044.
# [I 2026-04-05 22:58:52,166] Trial 10 finished with value: 10.43887619127523 and parameters: {'n_estimators': 129, 'max_depth': 3, 'min_samples_split': 2}. Best is trial 10 with value: 10.43887619127523.
# [I 2026-04-05 22:58:55,997] Trial 11 finished with value: 10.43887619127523 and parameters: {'n_estimators': 129, 'max_depth': 3, 'min_samples_split': 2}. Best is trial 10 with value: 10.43887619127523.
# [I 2026-04-05 22:58:59,547] Trial 12 finished with value: 10.400322512021171 and parameters: {'n_estimators': 117, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 12 with value: 10.400322512021171.
# [I 2026-04-05 22:59:03,012] Trial 13 finished with value: 10.92039944929925 and parameters: {'n_estimators': 109, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 12 with value: 10.400322512021171.
# [I 2026-04-05 22:59:06,443] Trial 14 finished with value: 11.029927039521647 and parameters: {'n_estimators': 108, 'max_depth': 2, 'min_samples_split': 4}. Best is trial 12 with value: 10.400322512021171.
# [I 2026-04-05 22:59:08,545] Trial 15 finished with value: 10.991101450003574 and parameters: {'n_estimators': 50, 'max_depth': 4, 'min_samples_split': 3}. Best is trial 12 with value: 10.400322512021171.
# [I 2026-04-05 22:59:11,989] Trial 16 finished with value: 10.811383233833872 and parameters: {'n_estimators': 107, 'max_depth': 4, 'min_samples_split': 2}. Best is trial 12 with value: 10.400322512021171.
# [I 2026-04-05 22:59:15,717] Trial 17 finished with value: 10.443504517037413 and parameters: {'n_estimators': 132, 'max_depth': 3, 'min_samples_split': 4}. Best is trial 12 with value: 10.400322512021171.
# [I 2026-04-05 22:59:21,301] Trial 18 finished with value: 10.35734900463305 and parameters: {'n_estimators': 223, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 18 with value: 10.35734900463305.
# [I 2026-04-05 22:59:26,745] Trial 19 finished with value: 11.187864343101579 and parameters: {'n_estimators': 224, 'max_depth': 5, 'min_samples_split': 5}. Best is trial 18 with value: 10.35734900463305.
# Tuning RandomForestRegressor completed. Best MAPE: 10.36%; Best params: {'n_estimators': 223, 'max_depth': 3, 'min_samples_split': 3}

# %% [markdown]
# ## Training

# %%
h_cv = 4
max_num_windows_cv = (one_length - max(lags) - 2 - h_cv) // step_size
print(f"max_num_windows for h=4: {max_num_windows_cv}")

best_xgb = XGBRegressor(**best_params_xgb, random_state=0)
best_rf = RandomForestRegressor(**best_params_rf, random_state=0)

mlf = MLForecast(
    models=[
        LinearRegression(),
        best_xgb,
        best_rf
    ],
    freq='QE',
    lags=lags,
)

sf = StatsForecast(
    models=[
        Naive(), 
        HistoricAverage(), 
        WindowAverage(window_size=max(lags)),
        AutoARIMA(season_length=max(lags)),
        AutoETS(season_length=max(lags))
    ],
    freq='QE',
    n_jobs=-1,
)

cv_results_ml = add_horizon(mlf.cross_validation(
    df=df_train, 
    h=h_cv, 
    step_size=step_size, 
    n_windows=max_num_windows_cv,
    id_col='region', 
    time_col='date', 
    target_col='price',
))

cv_results_stat = add_horizon(sf.cross_validation(
    df=df_train, 
    h=h_cv, 
    step_size=step_size, 
    n_windows=max_num_windows_cv,
    id_col='region', 
    time_col='date', 
    target_col='price',
))
# Out:
# max_num_windows for h=4: 10

# %% [markdown]
# ## Results Analysis

# %%
table_ml = eval_by_horizon(cv_results_ml, [str(m) for m in mlf.models])
table_stat = eval_by_horizon(cv_results_stat, [m.alias for m in sf.models])

display_eval_table(pd.concat([table_ml, table_stat]), "MAE, MAPE and RMSE by forecast horizon (H1–H4)")
# Out:
# <style type="text/css">
# #T_385c9_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_385c9_row0_col2, #T_385c9_row3_col2 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_385c9_row0_col4 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_385c9_row0_col5 {
#   background-color: #e2e2ef;
#   color: #000000;
# }
# #T_385c9_row0_col7 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_385c9_row0_col8, #T_385c9_row6_col8 {
#   background-color: #b9b9da;
#   color: #000000;
# }
# #T_385c9_row0_col10 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_385c9_row0_col11 {
#   background-color: #8784bd;
#   color: #f1f1f1;
# }
# #T_385c9_row0_col13 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_385c9_row0_col14 {
#   background-color: #cecfe5;
#   color: #000000;
# }
# #T_385c9_row1_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_385c9_row1_col2, #T_385c9_row7_col2 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_385c9_row1_col4, #T_385c9_row6_col4 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_385c9_row1_col5 {
#   background-color: #e1e0ee;
#   color: #000000;
# }
# #T_385c9_row1_col7 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_385c9_row1_col8 {
#   background-color: #bbbbdb;
#   color: #000000;
# }
# #T_385c9_row1_col10, #T_385c9_row5_col7 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_385c9_row1_col11 {
#   background-color: #9591c4;
#   color: #f1f1f1;
# }
# #T_385c9_row1_col13 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_385c9_row1_col14 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_385c9_row2_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_385c9_row2_col2 {
#   background-color: #f2f0f7;
#   color: #000000;
# }
# #T_385c9_row2_col4, #T_385c9_row3_col13, #T_385c9_row7_col4 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_385c9_row2_col5 {
#   background-color: #d7d7e9;
#   color: #000000;
# }
# #T_385c9_row2_col7 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_385c9_row2_col8 {
#   background-color: #b5b5d7;
#   color: #000000;
# }
# #T_385c9_row2_col10 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_385c9_row2_col11 {
#   background-color: #9894c5;
#   color: #f1f1f1;
# }
# #T_385c9_row2_col13 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_385c9_row2_col14 {
#   background-color: #c9c9e2;
#   color: #000000;
# }
# #T_385c9_row3_col1, #T_385c9_row6_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_385c9_row3_col4 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_385c9_row3_col5 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_385c9_row3_col7 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_385c9_row3_col8 {
#   background-color: #c3c4e0;
#   color: #000000;
# }
# #T_385c9_row3_col10, #T_385c9_row5_col13 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_385c9_row3_col11 {
#   background-color: #a5a2cd;
#   color: #f1f1f1;
# }
# #T_385c9_row3_col14 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_385c9_row4_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_385c9_row4_col2 {
#   background-color: #674ca1;
#   color: #f1f1f1;
# }
# #T_385c9_row4_col4 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_385c9_row4_col5 {
#   background-color: #572c92;
#   color: #f1f1f1;
# }
# #T_385c9_row4_col7 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_385c9_row4_col8 {
#   background-color: #4a1486;
#   color: #f1f1f1;
# }
# #T_385c9_row4_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_385c9_row4_col11 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_385c9_row4_col13 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_385c9_row4_col14 {
#   background-color: #51228d;
#   color: #f1f1f1;
# }
# #T_385c9_row5_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_385c9_row5_col2 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_385c9_row5_col4 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_385c9_row5_col5 {
#   background-color: #b6b6d8;
#   color: #000000;
# }
# #T_385c9_row5_col8 {
#   background-color: #9692c4;
#   color: #f1f1f1;
# }
# #T_385c9_row5_col10 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_385c9_row5_col11 {
#   background-color: #7e79b8;
#   color: #f1f1f1;
# }
# #T_385c9_row5_col14 {
#   background-color: #aaa8d0;
#   color: #000000;
# }
# #T_385c9_row6_col2 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_385c9_row6_col5 {
#   background-color: #e2e1ef;
#   color: #000000;
# }
# #T_385c9_row6_col7 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_385c9_row6_col10 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_385c9_row6_col11 {
#   background-color: #8e8bc1;
#   color: #f1f1f1;
# }
# #T_385c9_row6_col13 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_385c9_row6_col14 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_385c9_row7_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_385c9_row7_col5 {
#   background-color: #ddddec;
#   color: #000000;
# }
# #T_385c9_row7_col7 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_385c9_row7_col8 {
#   background-color: #b0afd4;
#   color: #000000;
# }
# #T_385c9_row7_col10 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_385c9_row7_col11 {
#   background-color: #8885be;
#   color: #f1f1f1;
# }
# #T_385c9_row7_col13 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_385c9_row7_col14 {
#   background-color: #cacae3;
#   color: #000000;
# }
# </style>
# <table id="T_385c9">
#   <caption>MAE, MAPE and RMSE by forecast horizon (H1–H4)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_385c9_level0_col0" class="col_heading level0 col0" >H1 MAE</th>
#       <th id="T_385c9_level0_col1" class="col_heading level0 col1" >H1 MAPE</th>
#       <th id="T_385c9_level0_col2" class="col_heading level0 col2" >H1 RMSE</th>
#       <th id="T_385c9_level0_col3" class="col_heading level0 col3" >H2 MAE</th>
#       <th id="T_385c9_level0_col4" class="col_heading level0 col4" >H2 MAPE</th>
#       <th id="T_385c9_level0_col5" class="col_heading level0 col5" >H2 RMSE</th>
#       <th id="T_385c9_level0_col6" class="col_heading level0 col6" >H3 MAE</th>
#       <th id="T_385c9_level0_col7" class="col_heading level0 col7" >H3 MAPE</th>
#       <th id="T_385c9_level0_col8" class="col_heading level0 col8" >H3 RMSE</th>
#       <th id="T_385c9_level0_col9" class="col_heading level0 col9" >H4 MAE</th>
#       <th id="T_385c9_level0_col10" class="col_heading level0 col10" >H4 MAPE</th>
#       <th id="T_385c9_level0_col11" class="col_heading level0 col11" >H4 RMSE</th>
#       <th id="T_385c9_level0_col12" class="col_heading level0 col12" >Avg MAE</th>
#       <th id="T_385c9_level0_col13" class="col_heading level0 col13" >Avg MAPE</th>
#       <th id="T_385c9_level0_col14" class="col_heading level0 col14" >Avg RMSE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_385c9_level0_row0" class="row_heading level0 row0" >LinearRegression</th>
#       <td id="T_385c9_row0_col0" class="data row0 col0" >2187</td>
#       <td id="T_385c9_row0_col1" class="data row0 col1" >4.56%</td>
#       <td id="T_385c9_row0_col2" class="data row0 col2" >2657</td>
#       <td id="T_385c9_row0_col3" class="data row0 col3" >4082</td>
#       <td id="T_385c9_row0_col4" class="data row0 col4" >8.29%</td>
#       <td id="T_385c9_row0_col5" class="data row0 col5" >5050</td>
#       <td id="T_385c9_row0_col6" class="data row0 col6" >5981</td>
#       <td id="T_385c9_row0_col7" class="data row0 col7" >11.92%</td>
#       <td id="T_385c9_row0_col8" class

# %%
cv_combined = cv_results_ml.merge(
    cv_results_stat[['region', 'date', 'cutoff', 'horizon', 'AutoARIMA', 'AutoETS', 'Naive']],
    on=['region', 'date', 'cutoff', 'horizon']
)

model_cols_cv = [c for c in cv_combined.columns 
                 if c not in ['region', 'date', 'cutoff', 'horizon', 'price']]

eval_by_region(cv_combined, model_cols_cv, "MAPE by region – cross-validation")
# Out:
# <style type="text/css">
# #T_167fe_row0_col0 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_167fe_row0_col1, #T_167fe_row13_col1 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_167fe_row0_col2, #T_167fe_row1_col4, #T_167fe_row7_col4, #T_167fe_row13_col4 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_167fe_row0_col3 {
#   background-color: #8dc1dd;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_167fe_row0_col4 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_167fe_row0_col5 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_167fe_row1_col0 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_167fe_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_167fe_row1_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_167fe_row1_col3, #T_167fe_row9_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_167fe_row1_col5 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_167fe_row2_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_167fe_row2_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_167fe_row2_col2 {
#   background-color: #bed8ec;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_167fe_row2_col3 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_167fe_row2_col4 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_167fe_row2_col5 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_167fe_row3_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_167fe_row3_col1, #T_167fe_row3_col5 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_167fe_row3_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_167fe_row3_col3 {
#   background-color: #deebf7;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_167fe_row3_col4 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_167fe_row4_col0 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_167fe_row4_col1 {
#   background-color: #a6cee4;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_167fe_row4_col2 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_167fe_row4_col3 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_167fe_row4_col4, #T_167fe_row6_col3, #T_167fe_row8_col3 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_167fe_row4_col5 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_167fe_row5_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_167fe_row5_col1 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_167fe_row5_col2 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_167fe_row5_col3 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_167fe_row5_col4 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_167fe_row5_col5 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_167fe_row6_col0, #T_167fe_row6_col2 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_167fe_row6_col1, #T_167fe_row12_col4 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_167fe_row6_col4 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_167fe_row6_col5 {
#   background-color: #9cc9e1;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_167fe_row7_col0 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_167fe_row7_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_167fe_row7_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_167fe_row7_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_167fe_row7_col5 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_167fe_row8_col0 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_167fe_row8_col1 {
#   background-color: #8abfdd;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_167fe_row8_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_167fe_row8_col4, #T_167fe_row8_col5 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_167fe_row9_col0 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_167fe_row9_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_167fe_row9_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_167fe_row9_col4 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_167fe_row9_col5 {
#   background-color: #e6f0f9;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_167fe_row10_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_167fe_row10_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_167fe_row10_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_167fe_row10_col3 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_167fe_row10_col4 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_167fe_row10_col5 {
#   background-color: #abd0e6;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_167fe_row11_col0 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_167fe_row11_col1 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_167fe_row11_col2 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_167fe_row11_col3 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_167fe_row11_col4 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_167fe_row11_col5 {
#   background-color: #7cb7da;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_167fe_row12_col0 {
#   background-color: #c9ddf0;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_167fe_row12_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_167fe_row12_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_167fe_row12_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_167fe_row12_col5 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_167fe_row13_col0 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_167fe_row13_col2 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_167fe_row13_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_167fe_row13_col5 {
#   background-color: #82bbdb;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# </style>
# <table id="T_167fe">
#   <caption>MAPE by region – cross-validation</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_167fe_level0_col0" class="col_heading level0 col0" >LinearRegression</th>
#       <th id="T_167fe_level0_col1" class="col_heading level0 col1" >XGBRegressor</th>
#       <th id="T_167fe_level0_col2" class="col_heading level0 col2" >RandomForestRegressor</th>
#       <th id="T_167fe_level0_col3" class="col_heading level0 col3" >AutoARIMA</th>
#       <th id="T_167fe_level0_col4" class="col_heading level0 col4" >AutoETS</th>
#       <th id="T_167fe_level0_col5" class="col_heading level0 col5" >Naive</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_167fe_level0_row0" class="row_heading level0 row0" >jihocesky</th>
#       <td id="T_167fe_row0_col0" class="data row0 col0" >11.38%</td>
#       <td id="T_167fe_row0_col1" class="data row0 col1" >11.15%</td>
#       <td id="T_167fe_row0_col2" class="data row0 col2" >11.20%</td>
#       <td id="T_167fe_row0_col3" class="data row0 col3" >10.67%</td>
#       <td id="T_167fe_row0_col4" class="data row0 col4" >12.77%</td>
#       <td id="T_167fe_row0_col5" class="data row0 col5" >11.23%</td>
#     </tr>
#     <tr>
#       <th id="T_167fe_level0_row1" class="row_heading level0 row1" >jihomoravsky</th>
#       <td id="T_167fe_row1_col0" class="data row1 col0" >8.68%</td>
#       <td id="T_167fe_row1_col1" class="data row1 col1" >6.97%</td>
#       <td id="T_167fe_row1_col2" class="data row1 col2" >15.88%</td>
#       <td id="T_167fe_row1_col3" class="data row1 col3" >9.28%</td>
#       <td id="T_167fe_row1_col4" class="data row1 col

# %% [markdown]
# ## Graphical Visualization

# %%
ml_forecasts = (cv_results_ml
    .sort_values("cutoff")
    .groupby(["region", "date"])
    .last()
    .reset_index()
    .drop(columns=["price", "cutoff", "horizon"]))

stat_forecasts = (cv_results_stat
    .sort_values("cutoff")
    .groupby(["region", "date"])
    .last()
    .reset_index()
    .drop(columns=["price", "cutoff", "horizon"]))

combined_forecasts = pd.merge(
    ml_forecasts, 
    stat_forecasts, 
    on=["region", "date"], 
    how="inner"
)

show_graph(df_train, combined_forecasts)

# %% [markdown]
# # Prediction

# %%
mlf.fit(
    df=df_train,
    id_col='region',
    time_col='date',
    target_col='price'
)

sf.fit(
    df=df_train,
    id_col='region',
    time_col='date',
    target_col='price'
)

h = 4

predictions_sf = sf.predict(h=h)
predictions_ml = mlf.predict(h=h)

predictions_sf_relevant = predictions_sf[['region', 'date', 'AutoARIMA', 'AutoETS', 'Naive']]

combined_predictions = pd.merge(
    predictions_ml, 
    predictions_sf_relevant, 
    on=['region', 'date'], 
    how='inner'
)

# %% [markdown]
# ## Prediction Evaluation

# %%
future_dates = sorted(df['date'].unique())[-4:]

df_holdout_eval = df[df['date'].isin(future_dates)][['region', 'date', 'price']]
eval_results = pd.merge(combined_predictions, df_holdout_eval, on=['region', 'date'])

date_to_horizon = {d: i+1 for i, d in enumerate(sorted(future_dates))}
eval_results['horizon'] = eval_results['date'].map(date_to_horizon)

model_cols = [c for c in combined_predictions.columns if c not in ['region', 'date']]
holdout_table = eval_by_horizon(eval_results, model_cols)

display_eval_table(holdout_table, "Model evaluation on holdout (2024 Q1–Q4) by horizon")
# Out:
# <style type="text/css">
# #T_79ab0_row0_col1, #T_79ab0_row1_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_79ab0_row0_col2 {
#   background-color: #eeecf4;
#   color: #000000;
# }
# #T_79ab0_row0_col4 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_79ab0_row0_col5 {
#   background-color: #b1b1d5;
#   color: #000000;
# }
# #T_79ab0_row0_col7 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_79ab0_row0_col8 {
#   background-color: #7f7bb9;
#   color: #f1f1f1;
# }
# #T_79ab0_row0_col10 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_79ab0_row0_col11 {
#   background-color: #5c3696;
#   color: #f1f1f1;
# }
# #T_79ab0_row0_col13 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_79ab0_row0_col14 {
#   background-color: #9d99c7;
#   color: #f1f1f1;
# }
# #T_79ab0_row1_col2 {
#   background-color: #f1f0f6;
#   color: #000000;
# }
# #T_79ab0_row1_col4 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_79ab0_row1_col5 {
#   background-color: #bbbbdb;
#   color: #000000;
# }
# #T_79ab0_row1_col7 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_79ab0_row1_col8 {
#   background-color: #8784bd;
#   color: #f1f1f1;
# }
# #T_79ab0_row1_col10 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_79ab0_row1_col11 {
#   background-color: #593093;
#   color: #f1f1f1;
# }
# #T_79ab0_row1_col13 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_79ab0_row1_col14 {
#   background-color: #a29fcb;
#   color: #f1f1f1;
# }
# #T_79ab0_row2_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_79ab0_row2_col2 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_79ab0_row2_col4 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_79ab0_row2_col5 {
#   background-color: #9490c3;
#   color: #f1f1f1;
# }
# #T_79ab0_row2_col7 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_79ab0_row2_col8 {
#   background-color: #7261ab;
#   color: #f1f1f1;
# }
# #T_79ab0_row2_col10 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_79ab0_row2_col11 {
#   background-color: #4d1a89;
#   color: #f1f1f1;
# }
# #T_79ab0_row2_col13 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_79ab0_row2_col14 {
#   background-color: #8683bd;
#   color: #f1f1f1;
# }
# #T_79ab0_row3_col1 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_79ab0_row3_col2 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_79ab0_row3_col4 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_79ab0_row3_col5 {
#   background-color: #9b97c6;
#   color: #f1f1f1;
# }
# #T_79ab0_row3_col7 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_79ab0_row3_col8 {
#   background-color: #694fa2;
#   color: #f1f1f1;
# }
# #T_79ab0_row3_col10 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_79ab0_row3_col11 {
#   background-color: #41047f;
#   color: #f1f1f1;
# }
# #T_79ab0_row3_col13 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_79ab0_row3_col14 {
#   background-color: #8481bc;
#   color: #f1f1f1;
# }
# #T_79ab0_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_79ab0_row4_col2 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_79ab0_row4_col4 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_79ab0_row4_col5 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_79ab0_row4_col7 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_79ab0_row4_col8 {
#   background-color: #d5d5e9;
#   color: #000000;
# }
# #T_79ab0_row4_col10 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_79ab0_row4_col11 {
#   background-color: #bdbedc;
#   color: #000000;
# }
# #T_79ab0_row4_col13 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_79ab0_row4_col14, #T_79ab0_row5_col2 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_79ab0_row5_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_79ab0_row5_col4 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_79ab0_row5_col5 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_79ab0_row5_col7 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_79ab0_row5_col8 {
#   background-color: #65489f;
#   color: #f1f1f1;
# }
# #T_79ab0_row5_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_79ab0_row5_col11 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_79ab0_row5_col13 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_79ab0_row5_col14 {
#   background-color: #807dba;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_79ab0">
#   <caption>Model evaluation on holdout (2024 Q1–Q4) by horizon</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79ab0_level0_col0" class="col_heading level0 col0" >H1 MAE</th>
#       <th id="T_79ab0_level0_col1" class="col_heading level0 col1" >H1 MAPE</th>
#       <th id="T_79ab0_level0_col2" class="col_heading level0 col2" >H1 RMSE</th>
#       <th id="T_79ab0_level0_col3" class="col_heading level0 col3" >H2 MAE</th>
#       <th id="T_79ab0_level0_col4" class="col_heading level0 col4" >H2 MAPE</th>
#       <th id="T_79ab0_level0_col5" class="col_heading level0 col5" >H2 RMSE</th>
#       <th id="T_79ab0_level0_col6" class="col_heading level0 col6" >H3 MAE</th>
#       <th id="T_79ab0_level0_col7" class="col_heading level0 col7" >H3 MAPE</th>
#       <th id="T_79ab0_level0_col8" class="col_heading level0 col8" >H3 RMSE</th>
#       <th id="T_79ab0_level0_col9" class="col_heading level0 col9" >H4 MAE</th>
#       <th id="T_79ab0_level0_col10" class="col_heading level0 col10" >H4 MAPE</th>
#       <th id="T_79ab0_level0_col11" class="col_heading level0 col11" >H4 RMSE</th>
#       <th id="T_79ab0_level0_col12" class="col_heading level0 col12" >Avg MAE</th>
#       <th id="T_79ab0_level0_col13" class="col_heading level0 col13" >Avg MAPE</th>
#       <th id="T_79ab0_level0_col14" class="col_heading level0 col14" >Avg RMSE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79ab0_level0_row0" class="row_heading level0 row0" >LinearRegression</th>
#       <td id="T_79ab0_row0_col0" class="data row0 col0" >2220</td>
#       <td id="T_79ab0_row0_col1" class="data row0 col1" >4.21%</td>
#       <td id="T_79ab0_row0_col2" class="data row0 col2" >2790</td>
#       <td id="T_79ab0_row0_col3" class="data row0 col3" >3170</td>
#       <td id="T_79ab0_row0_col4" class="data row0 col4" >5.85%</td>
#       <td id="T_79ab0_row0_col5" class="data row0 col5" >4169</td>
#       <td id="T_79ab0_row0_col6" class="data row0 col6" >3323</td>
#       <td id="T_79ab0_row0_col7" class="data row0 col7" >6.03%</td>
#       <td id="T_79ab0_row0_col8" class="data row0 col8" >5183</td>
#       <td id="T_79ab0_row0_col9" class="data row0 col9" >3416</td>
#       <td id="T_79ab0_row0_col10" class="data row0 col10" >6.11%</td>
#       <td id="T_79ab0_row0_col11" class="data row0 col11" >6143</td>
#       <td id="T_79ab0_row0_col12" class="data row0 col12" >3032</td>
#       <td id="T_79ab0_row0_col13" class="data row0 col13" >5.55%</td>
#       <td id="T_79ab0_row0_col14" class="data row0 col14" >4571</td>
#     </tr>
#     <tr>
#       <th id="T_79ab0_level0_row1" class="row_heading level0 row1" >XGBRegressor</th>
#       <td id="T_79ab0_row1_col0" class="data row1 col0" >2215</td>
#       <td id="T_79ab0_row1_col1" class="data row1 col1" >4.20%</td>
#       <td id="T_79ab0_row1_col2" class="data row1 col2" >2640</td>
#       <td id="T_79ab0_row1_col3" class="data row1 col3" >3384</td>
#       <td id="T_79ab0_row1_col4" class="data row1 col4" >6.24%</td>
#       <td id="T_79ab0_row1_col5" class="data row1 col5" >3985</td>
#       <td id="T_79ab0_row1_col6" class="data row1 col6" >4198</td>
#       <td id="T_79ab0_row1_col7" cl

# %% [markdown]
# ## Evaluation By Region

# %%
eval_by_region(eval_results, model_cols, "MAPE by region – holdout (2024)")
# Out:
# <style type="text/css">
# #T_3a170_row0_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_3a170_row0_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_3a170_row0_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_3a170_row0_col3, #T_3a170_row8_col2 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_3a170_row0_col4 {
#   background-color: #dae8f6;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_3a170_row0_col5 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_3a170_row1_col0 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_3a170_row1_col1 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_3a170_row1_col2, #T_3a170_row9_col0 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_3a170_row1_col3 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_3a170_row1_col4, #T_3a170_row12_col4 {
#   background-color: #dce9f6;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_3a170_row1_col5 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_3a170_row2_col0 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_3a170_row2_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_3a170_row2_col2, #T_3a170_row11_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_3a170_row2_col3 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_3a170_row2_col4 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_3a170_row2_col5 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_3a170_row3_col0 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_3a170_row3_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_3a170_row3_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_3a170_row3_col3 {
#   background-color: #e6f0f9;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_3a170_row3_col4 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_3a170_row3_col5 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_3a170_row4_col0 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_3a170_row4_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_3a170_row4_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_3a170_row4_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_3a170_row4_col4 {
#   background-color: #ddeaf7;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_3a170_row4_col5 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_3a170_row5_col0, #T_3a170_row6_col5 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_3a170_row5_col1 {
#   background-color: #ccdff1;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_3a170_row5_col2 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_3a170_row5_col3 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_3a170_row5_col4 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_3a170_row5_col5 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_3a170_row6_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3a170_row6_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_3a170_row6_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_3a170_row6_col3 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_3a170_row6_col4, #T_3a170_row11_col4 {
#   background-color: #f7fbff;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_3a170_row7_col0 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_3a170_row7_col1 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_3a170_row7_col2 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_3a170_row7_col3 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_3a170_row7_col4, #T_3a170_row10_col4 {
#   background-color: #eef5fc;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_3a170_row7_col5, #T_3a170_row12_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_3a170_row8_col0 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_3a170_row8_col1 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_3a170_row8_col3 {
#   background-color: #a8cee4;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_3a170_row8_col4, #T_3a170_row8_col5 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_3a170_row9_col1 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_3a170_row9_col2 {
#   background-color: #9dcae1;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_3a170_row9_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_3a170_row9_col4 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_3a170_row9_col5 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_3a170_row10_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_3a170_row10_col1 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_3a170_row10_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3a170_row10_col3 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_3a170_row10_col5 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_3a170_row11_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_3a170_row11_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_3a170_row11_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_3a170_row11_col5 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_3a170_row12_col0 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_3a170_row12_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_3a170_row12_col3 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_3a170_row12_col5 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_3a170_row13_col0 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_3a170_row13_col1 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_3a170_row13_col2 {
#   background-color: #dceaf6;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_3a170_row13_col3 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_3a170_row13_col4, #T_3a170_row13_col5 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# </style>
# <table id="T_3a170">
#   <caption>MAPE by region – holdout (2024)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a170_level0_col0" class="col_heading level0 col0" >LinearRegression</th>
#       <th id="T_3a170_level0_col1" class="col_heading level0 col1" >XGBRegressor</th>
#       <th id="T_3a170_level0_col2" class="col_heading level0 col2" >RandomForestRegressor</th>
#       <th id="T_3a170_level0_col3" class="col_heading level0 col3" >AutoARIMA</th>
#       <th id="T_3a170_level0_col4" class="col_heading level0 col4" >AutoETS</th>
#       <th id="T_3a170_level0_col5" class="col_heading level0 col5" >Naive</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a170_level0_row0" class="row_heading level0 row0" >jihocesky</th>
#       <td id="T_3a170_row0_col0" class="data row0 col0" >5.00%</td>
#       <td id="T_3a170_row0_col1" class="data row0 col1" >8.35%</td>
#       <td id="T_3a170_row0_col2" class="data row0 col2" >4.73%</td>
#       <td id="T_3a170_row0_col3" class="data row0 col3" >9.66%</td>
#       <td id="T_3a170_row0_col4" class="data row0 col4" >2.92%</td>
#       <td id="T_3a170_row0_col5" class="data row0 col5" >8.24%</td>
#     </tr>
#     <tr>
#       <th id="T_3a170_level0_row1" class="row_heading level0 row1" >jihomoravsky</th>
#       <td id="T_3a170_row1_col0" class="data row1 col0" >5.75%</td>
#       <td id="T_3a170_row1_col1" class="data row1 col1" >8.71%</td>
#       <td id="T_3a170_row1_col2" class="data row1 col2" >11.88%</td>
#       <td id="T_3a170_row1_col3" class="data row1 col3" >3.44%</td>
#       <td id="T_3a170_row1_col4" class="data row1 col4" >2.78%</td>
#       <td id="T_3a170_row1_col5" class="data row1 col5" >8.01%</td>
#     </tr>
#     <tr>

# %% [markdown]
# ## Graphical Vizualization

# %%
show_graph(df, combined_predictions.drop(columns=['Naive'], errors='ignore'))
