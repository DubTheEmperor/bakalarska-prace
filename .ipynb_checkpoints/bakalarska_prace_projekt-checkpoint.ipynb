# %%
import pandas as pd
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
import optuna

from plotly.subplots import make_subplots
from matplotlib import pyplot as plt
from mlforecast import MLForecast
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsforecast import StatsForecast
from statsforecast.models import Naive, HistoricAverage, WindowAverage, AutoARIMA, AutoETS
from typing import Callable, List, Type

# %% [markdown]
# # Helper functions

# %%
def add_horizon(cv_df: pd.DataFrame) -> pd.DataFrame:
    cv_df = cv_df.copy()
    cv_df['horizon'] = cv_df.groupby(['region', 'cutoff']).cumcount() + 1
    return cv_df

# %%
def eval_by_horizon(cv_df: pd.DataFrame, model_cols: List[str]) -> pd.DataFrame:
    rows = []
    
    for model in model_cols:
        row = {'model': model}
        
        for h in range(1, 5):
            subset = cv_df[cv_df['horizon'] == h]
            
            mae = mean_absolute_error(subset['price'], subset[model])
            mae_pct = (mae / subset['price'].mean()) * 100
            rmse = np.sqrt(mean_squared_error(subset['price'], subset[model]))
            
            row[f'H{h} MAE'] = round(mae, 0)
            row[f'H{h} MAE%'] = round(mae_pct, 2)
            row[f'H{h} RMSE'] = round(rmse, 0)
            
        rows.append(row)
    return pd.DataFrame(rows).set_index('model')

# %%
def display_eval_table(table: pd.DataFrame, caption: str) -> None:
    table = table.copy()
    
    for metric in ['MAE', 'MAE%', 'RMSE']:
        cols = [c for c in table.columns if c.endswith(metric)]
        table[f'Avg {metric}'] = table[cols].mean(axis=1)
    
    mae_pct_cols = [c for c in table.columns if 'MAE%' in c]
    rmse_cols = [c for c in table.columns if 'RMSE' in c and 'MAE' not in c]

    display(table.style
        .format({
            col: '{:.2f}%' if 'MAE%' in col else '{:.0f}'
            for col in table.columns
        })
        .background_gradient(cmap='Blues', axis=None, subset=mae_pct_cols)
        .background_gradient(cmap='Purples', axis=None, subset=rmse_cols)
        .set_caption(caption)
    )

# %%
def show_graph(df: pd.DataFrame, forecasts: pd.DataFrame) -> None:
    regione = df["region"].unique()

    model_columns = [
        col for col in forecasts.columns
        if col not in ["region", "date"]
    ]

    colors = px.colors.qualitative.Plotly
    model_colors = {
        model: colors[i % len(colors)]
        for i, model in enumerate(model_columns)
    }

    fig = make_subplots(
        rows=len(regione),
        cols=1,
        shared_xaxes=False,
        vertical_spacing=0.02,
        subplot_titles=regione
    )

    trace_map = []

    for i, region in enumerate(regione, start=1):

        real = df[df["region"] == region]
        preds = forecasts[forecasts["region"] == region]

        # Actual
        fig.add_trace(
            go.Scatter(
                x=real["date"],
                y=real["price"],
                mode="lines",
                name="Actual",
                line=dict(color="black", width=4),
                showlegend=(i == 1)
            ),
            row=i,
            col=1
        )

        trace_map.append(("Actual", len(fig.data)-1))

        # Models
        for model in model_columns:
            if model in preds.columns:
                first_pred_date = preds["date"].iloc[0]
                last_actual = real[real["date"] < first_pred_date].iloc[-1]
                
                connector_x = [last_actual["date"]] + list(preds["date"])
                connector_y = [last_actual["price"]] + list(preds[model])
                
                fig.add_trace(
                    go.Scatter(
                        x=connector_x,
                        y=connector_y,
                        mode="lines",
                        name=model,
                        line=dict(color=model_colors[model]),
                        showlegend=(i == 1)
                    ),
                    row=i,
                    col=1
                )

                trace_map.append((model, len(fig.data)-1))

    # DROPDOWN MENU
    buttons = []

    for model in model_columns:
        visibility = []

        for name, idx in trace_map:
            if name == "Actual" or name == model:
                visibility.append(True)
            else:
                visibility.append(False)

        buttons.append(
            dict(
                label=model,
                method="update",
                args=[{"visible": visibility}]
            )
        )

    buttons.insert(
        0,
        dict(
            label="All models",
            method="update",
            args=[{"visible": [True] * len(trace_map)}]
        )
    )

    fig.update_layout(
        height=500 * len(regione),
        width=1100,
        legend=dict(
            orientation="v",
            x=1.02,
            xanchor="left",
            y=0.99,
            yanchor="top"
        ),
        updatemenus=[
            dict(
                buttons=buttons,
                direction="down",
                showactive=True,
                x=1.02,
                xanchor="left",
                y=1.0,
                yanchor="top"
            )
        ]
    )

    fig.show()

# %% [markdown]
# # Load Data

# %%
# Load dataset
df = pd.read_csv("data/dataset_ml.csv", sep=';', parse_dates=['date'], date_format='%d.%m.%Y')

dates_sorted = sorted(df['date'].unique())
holdout_dates = dates_sorted[-4:]           # 2024 Q1–Q4
cutoff_date = holdout_dates[0]              # 2024-03-31

df_train = df[df['date'] < cutoff_date].copy()    # training data
df_holdout = df[df['date'] >= cutoff_date].copy() # holdout data

print(f"Training set ends at:  {df_train['date'].max().date()}")
print(f"Holdout set starts at: {df_holdout['date'].min().date()}")

df.head(10)
# Out:
# Training set ends at:  2023-12-31
# Holdout set starts at: 2024-03-31
#         region       date  price
# 0        praha 2019-03-31  73818
# 1        praha 2019-06-30  75162
# 2        praha 2019-09-30  77202
# 3        praha 2019-12-31  79382
# 4  stredocesky 2019-03-31  28777
# 5  stredocesky 2019-06-30  31328
# 6  stredocesky 2019-09-30  31846
# 7  stredocesky 2019-12-31  32882
# 8    jihocesky 2019-03-31  26028
# 9    jihocesky 2019-06-30  26896

# %%
# Prague only
only_prague = df_train[df_train["region"] == "praha"]
one_length = len(only_prague)
print(one_length)
print(only_prague)
# Out:
# 20
#     region       date   price
# 0    praha 2019-03-31   73818
# 1    praha 2019-06-30   75162
# 2    praha 2019-09-30   77202
# 3    praha 2019-12-31   79382
# 56   praha 2020-03-31   82409
# 57   praha 2020-06-30   84096
# 58   praha 2020-09-30   88315
# 59   praha 2020-12-31   88315
# 112  praha 2021-03-31   93413
# 113  praha 2021-06-30   96950
# 114  praha 2021-09-30  103196
# 115  praha 2021-12-31  109350
# 168  praha 2022-03-31  110995
# 169  praha 2022-06-30  114746
# 170  praha 2022-09-30  114792
# 171  praha 2022-12-31  110171
# 224  praha 2023-03-31  103549
# 225  praha 2023-06-30  103992
# 226  praha 2023-09-30  103859
# 227  praha 2023-12-31  103372

# %%
fig = px.line(
    df_train,
    x="date",
    y="price",
    color="region",
    title="Historical apartment prices in CR",
    color_discrete_sequence=px.colors.qualitative.Alphabet
)

fig.update_yaxes(range=[df["price"].min(), df["price"].max()])

fig.update_layout(
    autosize=True,
    height=500,
    xaxis_title="Price [m2]",
    yaxis_title="Date",
    legend_title="Region"
)

fig.show()

# %%
all_prices = df_train.pivot(index="date", columns="region", values="price").reset_index()
all_prices.describe()
# Out:
# region                 date     jihocesky  jihomoravsky  karlovarsky  \
# count                    20     20.000000     20.000000     20.00000
# mean    2021-08-15 01:12:00  39707.150000  55455.600000  28958.00000
# min     2019-03-31 00:00:00  26028.000000  39865.000000  20701.00000
# 25%     2020-06-07 06:00:00  32658.500000  46353.500000  23192.00000
# 50%     2021-08-15 00:00:00  41073.500000  57148.000000  29828.50000
# 75%     2022-10-23 00:00:00  46287.000000  65222.000000  33729.75000
# max     2023-12-31 00:00:00  52378.000000  69560.000000  37072.00000
# std                     NaN   8825.231545  10839.622728   6012.02003
#
# region  kralovehradecky     liberecky  moravskoslezsky     olomoucky  \
# count         20.000000     20.000000        20.000000     20.000000
# mean       39141.000000  38689.800000     33277.000000  38839.900000
# min        27075.000000  24875.000000     22170.000000  27515.000000
# 25%        31684.750000  31137.000000     26916.500000  31705.750000
# 50%        41026.000000  39067.000000     35189.000000  39138.000000
# 75%        46505.000000  46103.000000     38909.000000  46039.250000
# max        48994.000000  50588.000000     43130.000000  49722.000000
# std         8205.422135   8580.439343      7451.629317   8202.941019
#
# region    pardubicky      plzensky          praha   stredocesky       ustecky  \
# count      20.000000     20.000000      20.000000     20.000000     20.000000
# mean    41436.950000  41583.100000   95854.200000  44749.450000  28782.750000
# min     28214.000000  30769.000000   73818.000000  28777.000000  18357.000000
# 25%     34977.000000  33722.250000   83674.250000  37166.250000  23037.500000
# 50%     42864.000000  42313.000000  100073.000000  46307.000000  30584.000000
# 75%     49818.750000  48177.250000  105331.500000  52822.000000  34273.000000
# max     52349.000000  53267.000000  114792.000000  57688.000000  37495.000000
# std      8746.516085   8267.243198   13773.904868   9723.451334   6581.286851
#
# region      vysocina       zlinsky
# count      20.000000     20.000000
# mean    39296.000000  38291.550000
# min     26948.000000  27871.000000
# 25%     31446.500000  30220.750000
# 50%     39570.500000  39016.500000
# 75%     46639.750000  45472.500000
# max     50247.000000  49553.000000
# std      8257.290361   8036.761874

# %%
order = df_train.groupby("region")["price"].median().sort_values().index

plt.figure(figsize=(12, 6), dpi=200)
sns.boxplot(data=df_train, x="region", y="price", order=order)
plt.xticks(rotation=90)
plt.xlabel("Region")
plt.ylabel("Price [m2]")
plt.title("Boxplot of apartment prices by region")
plt.tight_layout()
plt.show()

# %%
all_prices_diff = all_prices.set_index("date").diff().dropna()
corr_matrix = all_prices_diff.corr()

plt.figure(figsize=(12, 10), dpi=200)
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".3f",
    cmap="coolwarm",
    center=0
)

plt.title("Correlation matrix between cities")
plt.show()

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Hyperparameters

# %%
lags = [1, 2, 3, 4]
h = 4
step_size = 1

min_train_size = max(lags)
max_num_windows = (one_length - min_train_size - h) // step_size
print(max_num_windows)
# Out:
# 12

# %% [markdown]
# ## Random Forest Regressor & XGBoost Hyperparameter Tuning

# %%
def tune_model(model_class: Type, param_func: Callable[[optuna.Trial], dict], n_trials: int=20) -> dict:
    model_name = model_class.__name__
    print(f"Initializing tuning for: {model_name}...")

    def objective(trial):
        params = param_func(trial)
        
        model = model_class(**params)
        
        mlf_tune = MLForecast(
            models=[model],
            freq='QE',
            lags=lags
        )
        
        cv_results = mlf_tune.cross_validation(
            df=df_train, 
            h=h, 
            step_size=step_size,
            n_windows=max_num_windows,
            id_col='region',
            time_col='date', 
            target_col='price',
        )
        
        error = mean_absolute_error(cv_results['price'], cv_results[model_name])
        return error

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=n_trials)
    
    print(f"Tuning {model_name} completed. Best MAE: {study.best_value:.2f}")
    return study.best_params

# %%
def xgb_params(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 6),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'random_state': 0,
        'n_jobs': -1
    }

def rf_params(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 10),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
        'random_state': 0,
        'n_jobs': -1
    }

best_params_xgb = tune_model(XGBRegressor, xgb_params, 20)
best_params_rf = tune_model(RandomForestRegressor, rf_params, 20)
# Out:
# [I 2026-03-20 21:28:48,787] A new study created in memory with name: no-name-bc69050d-0915-45e6-a15f-b74c392f9e9e
# Initializing tuning for: XGBRegressor...
# [I 2026-03-20 21:28:49,758] Trial 0 finished with value: 5310.4638671875 and parameters: {'n_estimators': 159, 'max_depth': 2, 'learning_rate': 0.026828160196348334, 'subsample': 0.8268091840923601, 'colsample_bytree': 0.7139141351357271}. Best is trial 0 with value: 5310.4638671875.
# [I 2026-03-20 21:28:50,670] Trial 1 finished with value: 4889.4951171875 and parameters: {'n_estimators': 173, 'max_depth': 2, 'learning_rate': 0.06311093872834679, 'subsample': 0.8697182964638692, 'colsample_bytree': 0.8377420277251244}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:28:51,323] Trial 2 finished with value: 6440.3251953125 and parameters: {'n_estimators': 54, 'max_depth': 5, 'learning_rate': 0.03318744118319791, 'subsample': 0.958220785027194, 'colsample_bytree': 0.6861277796415077}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:28:52,032] Trial 3 finished with value: 5425.0849609375 and parameters: {'n_estimators': 114, 'max_depth': 2, 'learning_rate': 0.03204610748469532, 'subsample': 0.8324131309000031, 'colsample_bytree': 0.5226673782609282}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:28:53,026] Trial 4 finished with value: 5033.58203125 and parameters: {'n_estimators': 217, 'max_depth': 3, 'learning_rate': 0.05645014248297026, 'subsample': 0.7789718247642907, 'colsample_bytree': 0.5961431815592307}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:28:54,509] Trial 5 finished with value: 4907.59912109375 and parameters: {'n_estimators': 269, 'max_depth': 5, 'learning_rate': 0.08536520233097669, 'subsample': 0.7516137563109482, 'colsample_bytree': 0.97581472141521}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:28:55,550] Trial 6 finished with value: 5126.01806640625 and parameters: {'n_estimators': 282, 'max_depth': 2, 'learning_rate': 0.017309907993776234, 'subsample': 0.5599346998921211, 'colsample_bytree': 0.8362398444429863}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:28:56,935] Trial 7 finished with value: 5073.61083984375 and parameters: {'n_estimators': 282, 'max_depth': 5, 'learning_rate': 0.013912075620559086, 'subsample': 0.7190577928519704, 'colsample_bytree': 0.5447125402322397}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:28:57,551] Trial 8 finished with value: 5977.04931640625 and parameters: {'n_estimators': 68, 'max_depth': 2, 'learning_rate': 0.03426748837244168, 'subsample': 0.7079618769882319, 'colsample_bytree': 0.6783700696168837}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:28:58,851] Trial 9 finished with value: 4941.30419921875 and parameters: {'n_estimators': 262, 'max_depth': 5, 'learning_rate': 0.04562054607463853, 'subsample': 0.5624085867842001, 'colsample_bytree': 0.5477778562427693}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:28:59,793] Trial 10 finished with value: 4978.04736328125 and parameters: {'n_estimators': 182, 'max_depth': 4, 'learning_rate': 0.07583073599172746, 'subsample': 0.9949100799156427, 'colsample_bytree': 0.8559077449413872}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:29:01,178] Trial 11 finished with value: 5062.0009765625 and parameters: {'n_estimators': 220, 'max_depth': 6, 'learning_rate': 0.09693031909911182, 'subsample': 0.8845032769689773, 'colsample_bytree': 0.9823662694226796}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:29:02,066] Trial 12 finished with value: 4942.6806640625 and parameters: {'n_estimators': 158, 'max_depth': 4, 'learning_rate': 0.06448964933164177, 'subsample': 0.661959669435986, 'colsample_bytree': 0.9970435401869622}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:29:03,450] Trial 13 finished with value: 4959.59033203125 and parameters: {'n_estimators': 219, 'max_depth': 6, 'learning_rate': 0.09818976692653933, 'subsample': 0.8990610525331936, 'colsample_bytree': 0.8924392301149158}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:29:04,154] Trial 14 finished with value: 5191.6123046875 and parameters: {'n_estimators': 113, 'max_depth': 3, 'learning_rate': 0.048051545219524164, 'subsample': 0.7986935152541264, 'colsample_bytree': 0.9206206335649832}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:29:05,407] Trial 15 finished with value: 4928.58837890625 and parameters: {'n_estimators': 251, 'max_depth': 3, 'learning_rate': 0.07500262126531965, 'subsample': 0.6730688676407107, 'colsample_bytree': 0.7905540445926277}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:29:06,660] Trial 16 finished with value: 5209.451171875 and parameters: {'n_estimators': 183, 'max_depth': 5, 'learning_rate': 0.021561747780183528, 'subsample': 0.8852867792930331, 'colsample_bytree': 0.9361894202911057}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:29:07,484] Trial 17 finished with value: 5082.86181640625 and parameters: {'n_estimators': 124, 'max_depth': 4, 'learning_rate': 0.042685266634274036, 'subsample': 0.6473388664435412, 'colsample_bytree': 0.7796551922531462}. Best is trial 1 with value: 4889.4951171875.
# [I 2026-03-20 21:29:08,655] Trial 18 finished with value: 4839.0693359375 and parameters: {'n_estimators': 299, 'max_depth': 3, 'learning_rate': 0.0772066009350332, 'subsample': 0.5034779309660014, 'colsample_bytree': 0.8389256871494717}. Best is trial 18 with value: 4839.0693359375.
# [I 2026-03-20 21:29:09,663] Trial 19 finished with value: 4878.24462890625 and parameters: {'n_estimators': 244, 'max_depth': 3, 'learning_rate': 0.05920128949767962, 'subsample': 0.6076529305968403, 'colsample_bytree': 0.8372669152871207}. Best is trial 18 with value: 4839.0693359375.
# [I 2026-03-20 21:29:09,664] A new study created in memory with name: no-name-1ef878bb-26b8-4d06-aeb6-bebae9f81ade
# Tuning XGBRegressor completed. Best MAE: 4839.07
# Initializing tuning for: RandomForestRegressor...
# [I 2026-03-20 21:29:14,879] Trial 0 finished with value: 5293.814650121385 and parameters: {'n_estimators': 209, 'max_depth': 6, 'min_samples_split': 3}. Best is trial 0 with value: 5293.814650121385.
# [I 2026-03-20 21:29:17,848] Trial 1 finished with value: 5655.045590367756 and parameters: {'n_estimators': 89, 'max_depth': 3, 'min_samples_split': 8}. Best is trial 0 with value: 5293.814650121385.
# [I 2026-03-20 21:29:22,589] Trial 2 finished with value: 5820.908146359468 and parameters: {'n_estimators': 183, 'max_depth': 4, 'min_samples_split': 7}. Best is trial 0 with value: 5293.814650121385.
# [I 2026-03-20 21:29:26,646] Trial 3 finished with value: 6591.339179141849 and parameters: {'n_estimators': 164, 'max_depth': 7, 'min_samples_split': 10}. Best is trial 0 with value: 5293.814650121385.
# [I 2026-03-20 21:29:31,981] Trial 4 finished with value: 5684.331016833114 and parameters: {'n_estimators': 216, 'max_depth': 3, 'min_samples_split': 8}. Best is trial 0 with value: 5293.814650121385.
# [I 2026-03-20 21:29:37,319] Trial 5 finished with value: 5490.5396878406045 and parameters: {'n_estimators': 210, 'max_depth': 7, 'min_samples_split': 5}. Best is trial 0 with value: 5293.814650121385.
# [I 2026-03-20 21:29:40,635] Trial 6 finished with value: 5265.85595252404 and parameters: {'n_estimators': 103, 'max_depth': 8, 'min_samples_split': 3}. Best is trial 6 with value: 5265.85595252404.
# [I 2026-03-20 21:29:42,890] Trial 7 finished with value: 5184.614953060221 and parameters: {'n_estimators': 63, 'max_depth': 8, 'min_samples_split': 2}. Best is trial 7 with value: 5184.614953060221.
# [I 2026-03-20 21:29:48,189] Trial 8 finished with value: 6285.14142699619 and parameters: {'n_estimators': 207, 'max_depth': 4, 'min_samples_split': 9}. Best is trial 7 with value: 5184.614953060221.
# [I 2026-03-20 21:29:51,379] Trial 9 finished with value: 5521.176872954313 and parameters: {'n_estimators': 93, 'max_depth': 5, 'min_samples_split': 5}. Best is trial 7 with value: 5184.614953060221.
# [I 2026-03-20 21:29:58,188] Trial 10 finished with value: 5320.931740973431 and parameters: {'n_estimators': 275, 'max_depth': 10, 'min_samples_split': 2}. Best is trial 7 with value: 5184.614953060221.
# [I 2026-03-20 21:30:00,280] Trial 11 finished with value: 5289.465322614979 and parameters: {'n_estimators': 51, 'max_depth': 9, 'min_samples_split': 3}. Best is trial 7 with value: 5184.614953060221.
# [I 2026-03-20 21:30:03,876] Trial 12 finished with value: 5241.897087692665 and parameters: {'n_estimators': 123, 'max_depth': 8, 'min_samples_split': 2}. Best is trial 7 with value: 5184.614953060221.
# [I 2026-03-20 21:30:07,614] Trial 13 finished with value: 5220.020765112594 and parameters: {'n_estimators': 134, 'max_depth': 9, 'min_samples_split': 2}. Best is trial 7 with value: 5184.614953060221.
# [I 2026-03-20 21:30:09,859] Trial 14 finished with value: 5379.860373121874 and parameters: {'n_estimators': 55, 'max_depth': 10, 'min_samples_split': 5}. Best is trial 7 with value: 5184.614953060221.
# [I 2026-03-20 21:30:13,643] Trial 15 finished with value: 5419.524567801 and parameters: {'n_estimators': 138, 'max_depth': 9, 'min_samples_split': 4}. Best is trial 7 with value: 5184.614953060221.
# [I 2026-03-20 21:30:17,449] Trial 16 finished with value: 5255.613858711511 and parameters: {'n_estimators': 146, 'max_depth': 8, 'min_samples_split': 2}. Best is trial 7 with value: 5184.614953060221.
# [I 2026-03-20 21:30:23,980] Trial 17 finished with value: 5429.922321040538 and parameters: {'n_estimators': 280, 'max_depth': 6, 'min_samples_split': 4}. Best is trial 7 with value: 5184.614953060221.
# [I 2026-03-20 21:30:26,439] Trial 18 finished with value: 5615.514725755628 and parameters: {'n_estimators': 80, 'max_depth': 9, 'min_samples_split': 6}. Best is trial 7 with value: 5184.614953060221.
# [I 2026-03-20 21:30:32,046] Trial 19 finished with value: 5416.273026482572 and parameters: {'n_estimators': 248, 'max_depth': 7, 'min_samples_split': 4}. Best is trial 7 with value: 5184.614953060221.
# Tuning RandomForestRegressor completed. Best MAE: 5184.61

# %% [markdown]
# ## Training

# %%
best_xgb = XGBRegressor(**best_params_xgb, random_state=0)
best_rf = RandomForestRegressor(**best_params_rf, random_state=0)

mlf = MLForecast(
    models=[
        LinearRegression(),
        best_xgb,
        best_rf
    ],
    freq='QE',
    lags=lags,
)

sf = StatsForecast(
    models=[
        Naive(), 
        HistoricAverage(), 
        WindowAverage(window_size=max(lags)),
        AutoARIMA(season_length=max(lags)),
        AutoETS(season_length=max(lags))
    ],
    freq='QE',
    n_jobs=-1,
)

h_cv = 4
max_num_windows_cv = (one_length - min_train_size - 2 - h_cv) // step_size
print(f"max_num_windows for h=4: {max_num_windows_cv}")

cv_results_ml = add_horizon(mlf.cross_validation(
    df=df_train, 
    h=h_cv, 
    step_size=step_size, 
    n_windows=max_num_windows_cv,
    id_col='region', 
    time_col='date', 
    target_col='price',
))

cv_results_stat = add_horizon(sf.cross_validation(
    df=df_train, 
    h=h_cv, 
    step_size=step_size, 
    n_windows=max_num_windows_cv,
    id_col='region', 
    time_col='date', 
    target_col='price',
))
# Out:
# max_num_windows for h=4: 10

# %% [markdown]
# ## Results Analysis

# %%
table_ml = eval_by_horizon(cv_results_ml, [str(m) for m in mlf.models])
table_stat = eval_by_horizon(cv_results_stat, [m.alias for m in sf.models])

display_eval_table(pd.concat([table_ml, table_stat]), "MAE and RMSE by forecast horizon (H1–H4)")
# Out:
# <style type="text/css">
# #T_573b9_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_573b9_row0_col2, #T_573b9_row3_col2 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_573b9_row0_col4 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_573b9_row0_col5, #T_573b9_row1_col5 {
#   background-color: #e2e2ef;
#   color: #000000;
# }
# #T_573b9_row0_col7 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_573b9_row0_col8, #T_573b9_row6_col8 {
#   background-color: #b9b9da;
#   color: #000000;
# }
# #T_573b9_row0_col10 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_573b9_row0_col11 {
#   background-color: #8784bd;
#   color: #f1f1f1;
# }
# #T_573b9_row0_col13 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_573b9_row0_col14 {
#   background-color: #cecfe5;
#   color: #000000;
# }
# #T_573b9_row1_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_573b9_row1_col2 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_573b9_row1_col4 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_573b9_row1_col7 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_573b9_row1_col8 {
#   background-color: #babadb;
#   color: #000000;
# }
# #T_573b9_row1_col10 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_573b9_row1_col11 {
#   background-color: #928fc3;
#   color: #f1f1f1;
# }
# #T_573b9_row1_col13, #T_573b9_row6_col13 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_573b9_row1_col14 {
#   background-color: #d1d2e7;
#   color: #000000;
# }
# #T_573b9_row2_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_573b9_row2_col2 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_573b9_row2_col4 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_573b9_row2_col5 {
#   background-color: #d9d9ea;
#   color: #000000;
# }
# #T_573b9_row2_col7 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_573b9_row2_col8, #T_573b9_row5_col14 {
#   background-color: #aaa8d0;
#   color: #000000;
# }
# #T_573b9_row2_col10 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_573b9_row2_col11 {
#   background-color: #807cba;
#   color: #f1f1f1;
# }
# #T_573b9_row2_col13 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_573b9_row2_col14, #T_573b9_row3_col8 {
#   background-color: #c3c4e0;
#   color: #000000;
# }
# #T_573b9_row3_col1, #T_573b9_row6_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_573b9_row3_col4 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_573b9_row3_col5 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_573b9_row3_col7 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_573b9_row3_col10, #T_573b9_row5_col13 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_573b9_row3_col11 {
#   background-color: #a5a2cd;
#   color: #f1f1f1;
# }
# #T_573b9_row3_col13, #T_573b9_row7_col4 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_573b9_row3_col14 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_573b9_row4_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_573b9_row4_col2 {
#   background-color: #674ca1;
#   color: #f1f1f1;
# }
# #T_573b9_row4_col4 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_573b9_row4_col5 {
#   background-color: #572c92;
#   color: #f1f1f1;
# }
# #T_573b9_row4_col7 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_573b9_row4_col8 {
#   background-color: #4a1486;
#   color: #f1f1f1;
# }
# #T_573b9_row4_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_573b9_row4_col11 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_573b9_row4_col13 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_573b9_row4_col14 {
#   background-color: #51228d;
#   color: #f1f1f1;
# }
# #T_573b9_row5_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_573b9_row5_col2 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_573b9_row5_col4 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_573b9_row5_col5 {
#   background-color: #b6b6d8;
#   color: #000000;
# }
# #T_573b9_row5_col7 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_573b9_row5_col8 {
#   background-color: #9692c4;
#   color: #f1f1f1;
# }
# #T_573b9_row5_col10 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_573b9_row5_col11 {
#   background-color: #7e79b8;
#   color: #f1f1f1;
# }
# #T_573b9_row6_col2 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_573b9_row6_col4 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_573b9_row6_col5 {
#   background-color: #e2e1ef;
#   color: #000000;
# }
# #T_573b9_row6_col7 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_573b9_row6_col10 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_573b9_row6_col11 {
#   background-color: #8e8bc1;
#   color: #f1f1f1;
# }
# #T_573b9_row6_col14 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_573b9_row7_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_573b9_row7_col2 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_573b9_row7_col5 {
#   background-color: #ddddec;
#   color: #000000;
# }
# #T_573b9_row7_col7 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_573b9_row7_col8 {
#   background-color: #b0afd4;
#   color: #000000;
# }
# #T_573b9_row7_col10 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_573b9_row7_col11 {
#   background-color: #8885be;
#   color: #f1f1f1;
# }
# #T_573b9_row7_col13 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_573b9_row7_col14 {
#   background-color: #cacae3;
#   color: #000000;
# }
# </style>
# <table id="T_573b9">
#   <caption>MAE and RMSE by forecast horizon (H1–H4)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_573b9_level0_col0" class="col_heading level0 col0" >H1 MAE</th>
#       <th id="T_573b9_level0_col1" class="col_heading level0 col1" >H1 MAE%</th>
#       <th id="T_573b9_level0_col2" class="col_heading level0 col2" >H1 RMSE</th>
#       <th id="T_573b9_level0_col3" class="col_heading level0 col3" >H2 MAE</th>
#       <th id="T_573b9_level0_col4" class="col_heading level0 col4" >H2 MAE%</th>
#       <th id="T_573b9_level0_col5" class="col_heading level0 col5" >H2 RMSE</th>
#       <th id="T_573b9_level0_col6" class="col_heading level0 col6" >H3 MAE</th>
#       <th id="T_573b9_level0_col7" class="col_heading level0 col7" >H3 MAE%</th>
#       <th id="T_573b9_level0_col8" class="col_heading level0 col8" >H3 RMSE</th>
#       <th id="T_573b9_level0_col9" class="col_heading level0 col9" >H4 MAE</th>
#       <th id="T_573b9_level0_col10" class="col_heading level0 col10" >H4 MAE%</th>
#       <th id="T_573b9_level0_col11" class="col_heading level0 col11" >H4 RMSE</th>
#       <th id="T_573b9_level0_col12" class="col_heading level0 col12" >Avg MAE</th>
#       <th id="T_573b9_level0_col13" class="col_heading level0 col13" >Avg MAE%</th>
#       <th id="T_573b9_level0_col14" class="col_heading level0 col14" >Avg RMSE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_573b9_level0_row0" class="row_heading level0 row0" >LinearRegression</th>
#       <td id="T_573b9_row0_col0" class="data row0 col0" >2187</td>
#       <td id="T_573b9_row0_col1" class="data row0 col1" >4.56%</td>
#       <td id="T_573b9_row0_col2" class="data row0 col2" >2657</td>
#       <td id="T_573b9_row0_col3" class="data row0 col3" >4082</td>
#       <td id="T_573b9_row0_col4" class="data row0 col4" >8.29%</td>
#       <td id="T_573b9_row0_col5" class="data row0 col5" >5050</td>
#       <td id="T_573b9_row0_col6" class="data row0 col6" >5981</td>
#       <td id="T_573b9_row0_col7" class="data row0 col7" >11.92%</td>
#       <td id="T_573b9_row0_col8" class="data

# %% [markdown]
# ## Graphical Visualization

# %%
ml_forecasts = (cv_results_ml
    .sort_values("cutoff")
    .groupby(["region", "date"])
    .last()
    .reset_index()
    .drop(columns=["price", "cutoff", "horizon"]))

stat_forecasts = (cv_results_stat
    .sort_values("cutoff")
    .groupby(["region", "date"])
    .last()
    .reset_index()
    .drop(columns=["price", "cutoff", "horizon"]))

combined_forecasts = pd.merge(
    ml_forecasts, 
    stat_forecasts, 
    on=["region", "date"], 
    how="inner"
)

show_graph(df_train, combined_forecasts)

# %% [markdown]
# # Prediction

# %%
mlf.fit(
    df=df_train,
    id_col='region',
    time_col='date',
    target_col='price',
    static_features=[]
)

sf.fit(
    df=df_train,
    id_col='region',
    time_col='date',
    target_col='price'
)

h = 4

predictions_sf = sf.predict(h=h)
predictions_ml = mlf.predict(h=h)

predictions_arima = predictions_sf[['region', 'date', 'AutoARIMA', 'AutoETS']]

combined_predictions = pd.merge(
    predictions_ml, 
    predictions_arima, 
    on=['region', 'date'], 
    how='inner'
)

# %% [markdown]
# ## Graph Vizualization

# %%
show_graph(df, combined_predictions)

# %% [markdown]
# ## Prediction Evaluation

# %%
combined_predictions = combined_predictions.drop(
    columns=[c for c in combined_predictions.columns if 'Naive' in c],
    errors='ignore'
)

# Naive
naive_pred = (df_train.groupby('region')['price']
              .last()
              .reset_index()
              .rename(columns={'price': 'Naive'}))
future_dates = sorted(df['date'].unique())[-4:]
naive_pred = pd.concat([
    naive_pred.assign(date=date) for date in future_dates
])

combined_predictions = pd.merge(
    combined_predictions,
    naive_pred,
    on=['region', 'date'],
    how='left'
)

df_holdout_eval = df[df['date'].isin(future_dates)][['region', 'date', 'price']]
eval_results = pd.merge(combined_predictions, df_holdout_eval, on=['region', 'date'])

date_to_horizon = {d: i+1 for i, d in enumerate(sorted(future_dates))}
eval_results['horizon'] = eval_results['date'].map(date_to_horizon)

model_cols = [c for c in combined_predictions.columns if c not in ['region', 'date']]
holdout_table = eval_by_horizon(eval_results, model_cols)

display_eval_table(holdout_table, "Model evaluation on holdout (2024 Q1–Q4) by horizon")
# Out:
# <style type="text/css">
# #T_a03ed_row0_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_a03ed_row0_col2, #T_a03ed_row2_col2 {
#   background-color: #eeecf4;
#   color: #000000;
# }
# #T_a03ed_row0_col4 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_a03ed_row0_col5 {
#   background-color: #b1b1d5;
#   color: #000000;
# }
# #T_a03ed_row0_col7 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_a03ed_row0_col8 {
#   background-color: #7f7bb9;
#   color: #f1f1f1;
# }
# #T_a03ed_row0_col10 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_a03ed_row0_col11 {
#   background-color: #5c3696;
#   color: #f1f1f1;
# }
# #T_a03ed_row0_col13 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_a03ed_row0_col14, #T_a03ed_row2_col14 {
#   background-color: #9d99c7;
#   color: #f1f1f1;
# }
# #T_a03ed_row1_col1, #T_a03ed_row4_col4 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_a03ed_row1_col2 {
#   background-color: #f3f2f8;
#   color: #000000;
# }
# #T_a03ed_row1_col4 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_a03ed_row1_col5 {
#   background-color: #c2c3df;
#   color: #000000;
# }
# #T_a03ed_row1_col7 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_a03ed_row1_col8 {
#   background-color: #8885be;
#   color: #f1f1f1;
# }
# #T_a03ed_row1_col10 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_a03ed_row1_col11 {
#   background-color: #53268f;
#   color: #f1f1f1;
# }
# #T_a03ed_row1_col13, #T_a03ed_row2_col4 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_a03ed_row1_col14 {
#   background-color: #a4a1cc;
#   color: #f1f1f1;
# }
# #T_a03ed_row2_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_a03ed_row2_col5 {
#   background-color: #b2b2d5;
#   color: #000000;
# }
# #T_a03ed_row2_col7 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_a03ed_row2_col8 {
#   background-color: #827fbb;
#   color: #f1f1f1;
# }
# #T_a03ed_row2_col10 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_a03ed_row2_col11 {
#   background-color: #562b91;
#   color: #f1f1f1;
# }
# #T_a03ed_row2_col13 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_a03ed_row3_col1 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_a03ed_row3_col2 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_a03ed_row3_col4 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_a03ed_row3_col5 {
#   background-color: #9b97c6;
#   color: #f1f1f1;
# }
# #T_a03ed_row3_col7 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_a03ed_row3_col8 {
#   background-color: #694fa2;
#   color: #f1f1f1;
# }
# #T_a03ed_row3_col10 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_a03ed_row3_col11 {
#   background-color: #41047f;
#   color: #f1f1f1;
# }
# #T_a03ed_row3_col13 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_a03ed_row3_col14 {
#   background-color: #8481bc;
#   color: #f1f1f1;
# }
# #T_a03ed_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a03ed_row4_col2 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_a03ed_row4_col5 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_a03ed_row4_col7 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_a03ed_row4_col8 {
#   background-color: #d5d5e9;
#   color: #000000;
# }
# #T_a03ed_row4_col10 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_a03ed_row4_col11 {
#   background-color: #bdbedc;
#   color: #000000;
# }
# #T_a03ed_row4_col13 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_a03ed_row4_col14, #T_a03ed_row5_col2 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_a03ed_row5_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_a03ed_row5_col4 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_a03ed_row5_col5 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_a03ed_row5_col7 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_a03ed_row5_col8 {
#   background-color: #65489f;
#   color: #f1f1f1;
# }
# #T_a03ed_row5_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a03ed_row5_col11 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_a03ed_row5_col13 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_a03ed_row5_col14 {
#   background-color: #807dba;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a03ed">
#   <caption>Model evaluation on holdout (2024 Q1–Q4) by horizon</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a03ed_level0_col0" class="col_heading level0 col0" >H1 MAE</th>
#       <th id="T_a03ed_level0_col1" class="col_heading level0 col1" >H1 MAE%</th>
#       <th id="T_a03ed_level0_col2" class="col_heading level0 col2" >H1 RMSE</th>
#       <th id="T_a03ed_level0_col3" class="col_heading level0 col3" >H2 MAE</th>
#       <th id="T_a03ed_level0_col4" class="col_heading level0 col4" >H2 MAE%</th>
#       <th id="T_a03ed_level0_col5" class="col_heading level0 col5" >H2 RMSE</th>
#       <th id="T_a03ed_level0_col6" class="col_heading level0 col6" >H3 MAE</th>
#       <th id="T_a03ed_level0_col7" class="col_heading level0 col7" >H3 MAE%</th>
#       <th id="T_a03ed_level0_col8" class="col_heading level0 col8" >H3 RMSE</th>
#       <th id="T_a03ed_level0_col9" class="col_heading level0 col9" >H4 MAE</th>
#       <th id="T_a03ed_level0_col10" class="col_heading level0 col10" >H4 MAE%</th>
#       <th id="T_a03ed_level0_col11" class="col_heading level0 col11" >H4 RMSE</th>
#       <th id="T_a03ed_level0_col12" class="col_heading level0 col12" >Avg MAE</th>
#       <th id="T_a03ed_level0_col13" class="col_heading level0 col13" >Avg MAE%</th>
#       <th id="T_a03ed_level0_col14" class="col_heading level0 col14" >Avg RMSE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a03ed_level0_row0" class="row_heading level0 row0" >LinearRegression</th>
#       <td id="T_a03ed_row0_col0" class="data row0 col0" >2220</td>
#       <td id="T_a03ed_row0_col1" class="data row0 col1" >4.21%</td>
#       <td id="T_a03ed_row0_col2" class="data row0 col2" >2790</td>
#       <td id="T_a03ed_row0_col3" class="data row0 col3" >3170</td>
#       <td id="T_a03ed_row0_col4" class="data row0 col4" >5.85%</td>
#       <td id="T_a03ed_row0_col5" class="data row0 col5" >4169</td>
#       <td id="T_a03ed_row0_col6" class="data row0 col6" >3323</td>
#       <td id="T_a03ed_row0_col7" class="data row0 col7" >6.03%</td>
#       <td id="T_a03ed_row0_col8" class="data row0 col8" >5183</td>
#       <td id="T_a03ed_row0_col9" class="data row0 col9" >3416</td>
#       <td id="T_a03ed_row0_col10" class="data row0 col10" >6.11%</td>
#       <td id="T_a03ed_row0_col11" class="data row0 col11" >6143</td>
#       <td id="T_a03ed_row0_col12" class="data row0 col12" >3032</td>
#       <td id="T_a03ed_row0_col13" class="data row0 col13" >5.55%</td>
#       <td id="T_a03ed_row0_col14" class="data row0 col14" >4571</td>
#     </tr>
#     <tr>
#       <th id="T_a03ed_level0_row1" class="row_heading level0 row1" >XGBRegressor</th>
#       <td id="T_a03ed_row1_col0" class="data row1 col0" >2065</td>
#       <td id="T_a03ed_row1_col1" class="data row1 col1" >3.92%</td>
#       <td id="T_a03ed_row1_col2" class="data row1 col2" >2545</td>
#       <td id="T_a03ed_row1_col3" class="data row1 col3" >3210</td>
#       <td id="T_a03ed_row1_col4" class="data row1 col4" >5.92%</td>
#       <td id="T_a03ed_row1_col5" class="data row1 col5" >3831</td>
#       <td id="T_a03ed_row1_col6" class="data row1 col6" >4174</td>
#       <td id="T_a03ed_row1_col7" class="data row1 col7" >7.58%</td>
#       <td id="T_a03ed_row1_col8" class="data row1 col8" >4995</td>
#       <td id="T_a03ed_row1_col9" class="data row1
