# %% [markdown]
# # Načtení dat

# %%
import pandas as pd
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
import optuna

from plotly.subplots import make_subplots
from matplotlib import pyplot as plt
from mlforecast import MLForecast
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsforecast import StatsForecast
from statsforecast.models import Naive, HistoricAverage, WindowAverage, AutoARIMA
from typing import Callable, List, Type

# %%
# Load dataset
df = pd.read_csv("data/dataset_ml.csv", sep=';', parse_dates=['date'], date_format='%d.%m.%Y')

dates_sorted = sorted(df['date'].unique())
holdout_dates = dates_sorted[-4:]           # 2024 Q1–Q4
cutoff_date = holdout_dates[0]              # 2024-03-31

df_train = df[df['date'] < cutoff_date].copy()    # training data (2019 Q1 – 2023 Q4)
df_holdout = df[df['date'] >= cutoff_date].copy() # holdout data  (2024 Q1 – 2024 Q4)

print(f"Training set ends at:  {df_train['date'].max().date()}")
print(f"Holdout set starts at: {df_holdout['date'].min().date()}")

df.head(10)
# Out:
# Training set ends at:  2023-12-31
# Holdout set starts at: 2024-03-31
#         region       date  price
# 0        praha 2019-03-31  73818
# 1        praha 2019-06-30  75162
# 2        praha 2019-09-30  77202
# 3        praha 2019-12-31  79382
# 4  stredocesky 2019-03-31  28777
# 5  stredocesky 2019-06-30  31328
# 6  stredocesky 2019-09-30  31846
# 7  stredocesky 2019-12-31  32882
# 8    jihocesky 2019-03-31  26028
# 9    jihocesky 2019-06-30  26896

# %%
# Prague only
only_prague = df_train[df_train["region"] == "praha"]
one_length = len(only_prague)
print(one_length)
print(only_prague)
# Out:
# 20
#     region       date   price
# 0    praha 2019-03-31   73818
# 1    praha 2019-06-30   75162
# 2    praha 2019-09-30   77202
# 3    praha 2019-12-31   79382
# 56   praha 2020-03-31   82409
# 57   praha 2020-06-30   84096
# 58   praha 2020-09-30   88315
# 59   praha 2020-12-31   88315
# 112  praha 2021-03-31   93413
# 113  praha 2021-06-30   96950
# 114  praha 2021-09-30  103196
# 115  praha 2021-12-31  109350
# 168  praha 2022-03-31  110995
# 169  praha 2022-06-30  114746
# 170  praha 2022-09-30  114792
# 171  praha 2022-12-31  110171
# 224  praha 2023-03-31  103549
# 225  praha 2023-06-30  103992
# 226  praha 2023-09-30  103859
# 227  praha 2023-12-31  103372

# %%
fig = px.line(
    df,
    x="date",
    y="price",
    color="region",
    title="Historical apartment prices in CR",
    color_discrete_sequence=px.colors.qualitative.Alphabet
)

fig.update_yaxes(range=[df["price"].min(), df["price"].max()])

fig.update_layout(
    autosize=True,
    height=500,
    xaxis_title="Price [m2]",
    yaxis_title="Date",
    legend_title="Region"
)

fig.show()

# %%
all_prices = df.pivot(index="date", columns="region", values="price").reset_index()
all_prices.describe()
# Out:
# region                 date     jihocesky  jihomoravsky   karlovarsky  \
# count                    24     24.000000     24.000000     24.000000
# mean    2022-02-13 18:00:00  41406.625000  58228.958333  30183.208333
# min     2019-03-31 00:00:00  26028.000000  39865.000000  20701.000000
# 25%     2020-09-07 00:00:00  33230.750000  47354.750000  23549.750000
# 50%     2022-02-14 00:00:00  45710.500000  63519.500000  33311.500000
# 75%     2023-07-23 00:00:00  49282.500000  67018.250000  35501.500000
# max     2024-12-31 00:00:00  52378.000000  73451.000000  37144.000000
# std                     NaN   8911.729271  11718.000395   6146.296325
#
# region  kralovehradecky     liberecky  moravskoslezsky     olomoucky  \
# count          24.00000     24.000000        24.000000     24.000000
# mean        40865.00000  40396.500000     34911.333333  40459.750000
# min         27075.00000  24875.000000     22170.000000  27515.000000
# 25%         32652.50000  31802.250000     27537.000000  32601.750000
# 50%         45609.00000  43760.500000     38222.000000  44611.000000
# 75%         48294.00000  48081.250000     41576.250000  47732.500000
# max         50018.00000  50588.000000     44031.000000  49880.000000
# std          8435.44919   8723.873302      7744.180259   8331.739336
#
# region    pardubicky      plzensky          praha   stredocesky       ustecky  \
# count      24.000000     24.000000      24.000000     24.000000     24.000000
# mean    43229.291667  43448.750000   99193.333333  46866.166667  30034.958333
# min     28214.000000  30769.000000   73818.000000  28777.000000  18357.000000
# 25%     35761.000000  34728.500000   87260.250000  37832.250000  23662.750000
# 50%     47488.500000  46640.000000  103460.500000  51836.500000  33369.500000
# 75%     50212.750000  50995.750000  110377.000000  55122.250000  35282.750000
# max     53864.000000  56063.000000  121643.000000  58474.000000  37944.000000
# std      8968.796485   8688.045506   14786.199164  10088.469396   6648.853693
#
# region      vysocina       zlinsky
# count      24.000000     24.000000
# mean    41173.375000  40060.333333
# min     26948.000000  27871.000000
# 25%     33558.500000  31711.500000
# 50%     44886.500000  43609.500000
# 75%     48702.000000  47064.750000
# max     52256.000000  50700.000000
# std      8660.524669   8361.397068

# %%
order = df.groupby("region")["price"].median().sort_values().index

plt.figure(figsize=(12, 6), dpi=200)
sns.boxplot(data=df, x="region", y="price", order=order)
plt.xticks(rotation=90)
plt.xlabel("Region")
plt.ylabel("Price [m2]")
plt.title("Boxplot of apartment prices by region")
plt.tight_layout()
plt.show()

# %%
all_prices_diff = all_prices.set_index("date").diff().dropna()
corr_matrix = all_prices_diff.corr()

plt.figure(figsize=(12, 10), dpi=200)
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".3f",
    cmap="coolwarm",
    center=0
)

plt.title("Correlation matrix between regions")
plt.show()

# %%
def add_correlation_features(df: pd.DataFrame, corr_matrix: pd.DataFrame, top_n: int = 3) -> pd.DataFrame:
    df = df.copy()
    regions = df['region'].unique()
    wide = df.pivot(index='date', columns='region', values='price')
    wide_diff = wide.diff()
    
    for region in regions:
        top_correlated = (corr_matrix[region]
                          .drop(region)
                          .nlargest(top_n)
                          .index.tolist())
        weights = corr_matrix[region][top_correlated]
        weights = weights / weights.sum()
        weighted_change = (wide_diff[top_correlated] * weights).sum(axis=1)
        
        mask = df['region'] == region
        df.loc[mask, 'corr_neighbors_change'] = df.loc[mask, 'date'].map(weighted_change)
    
    df['corr_neighbors_change_lag1'] = (df
                                        .groupby('region')['corr_neighbors_change']
                                        .shift(1)
                                        .fillna(0))

    df = df.drop(columns=['corr_neighbors_change'])
    
    return df

# %%
df = add_correlation_features(df, corr_matrix, top_n=3)
df_train = add_correlation_features(df_train, corr_matrix, top_n=3)

print(df_train[['region', 'date', 'corr_neighbors_change_lag1']].head(10))
# Out:
#         region       date  corr_neighbors_change_lag1
# 0        praha 2019-03-31                    0.000000
# 1        praha 2019-06-30                    0.000000
# 2        praha 2019-09-30                  683.987205
# 3        praha 2019-12-31                 1043.097828
# 4  stredocesky 2019-03-31                    0.000000
# 5  stredocesky 2019-06-30                    0.000000
# 6  stredocesky 2019-09-30                 1344.570064
# 7  stredocesky 2019-12-31                  292.223701
# 8    jihocesky 2019-03-31                    0.000000
# 9    jihocesky 2019-06-30                    0.000000

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Hyperparameters

# %%
lags = [1, 2, 3, 4] # last year
h = 1
step_size = 1

min_train_size = max(lags) + 2 # corr feature
max_num_windows = (one_length - min_train_size + h) // step_size
print(max_num_windows)
# Out:
# 15

# %% [markdown]
# ## Random Forest Regressor & XGBoost Hyperparameter Tuning

# %%
def tune_model(model_class: Type, param_func: Callable[[optuna.Trial], dict], n_trials: int=20) -> dict:
    model_name = model_class.__name__
    print(f"Initializing tuning for: {model_name}...")

    def objective(trial):
        params = param_func(trial)
        
        model = model_class(**params)
        
        mlf_tune = MLForecast(
            models=[model],
            freq='QE',
            lags=lags
        )
        
        cv_results = mlf_tune.cross_validation(
            df=df_train, 
            h=h, 
            step_size=step_size,
            n_windows=max_num_windows,
            id_col='region',
            time_col='date', 
            target_col='price',
            static_features=[]
        )
        
        error = mean_absolute_error(cv_results['price'], cv_results[model_name])
        return error

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=n_trials)
    
    print(f"Tuning {model_name} completed. Best MAE: {study.best_value:.2f}")
    return study.best_params

# %%
def xgb_params(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 6),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'random_state': 0,
        'n_jobs': -1
    }

def rf_params(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 10),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
        'random_state': 0,
        'n_jobs': -1
    }

best_params_xgb = tune_model(XGBRegressor, xgb_params, 20)
best_params_rf = tune_model(RandomForestRegressor, rf_params, 20)
# Out:
# [I 2026-03-16 19:59:12,231] A new study created in memory with name: no-name-6196d6ed-3888-4a87-87cf-b4313fb9918a
# Initializing tuning for: XGBRegressor...
# [I 2026-03-16 19:59:13,145] Trial 0 finished with value: 2853.498291015625 and parameters: {'n_estimators': 130, 'max_depth': 2, 'learning_rate': 0.022263519174398422, 'subsample': 0.575330419844357, 'colsample_bytree': 0.9829020476070065}. Best is trial 0 with value: 2853.498291015625.
# [I 2026-03-16 19:59:14,358] Trial 1 finished with value: 2954.101806640625 and parameters: {'n_estimators': 239, 'max_depth': 3, 'learning_rate': 0.010787262306420008, 'subsample': 0.5265566549319187, 'colsample_bytree': 0.9738429935533218}. Best is trial 0 with value: 2853.498291015625.
# [I 2026-03-16 19:59:15,150] Trial 2 finished with value: 2514.226806640625 and parameters: {'n_estimators': 129, 'max_depth': 2, 'learning_rate': 0.0300314159445155, 'subsample': 0.6270325317839553, 'colsample_bytree': 0.8628472383462427}. Best is trial 2 with value: 2514.226806640625.
# [I 2026-03-16 19:59:16,033] Trial 3 finished with value: 3290.31787109375 and parameters: {'n_estimators': 144, 'max_depth': 3, 'learning_rate': 0.014645245374128714, 'subsample': 0.577244353241211, 'colsample_bytree': 0.603875426128221}. Best is trial 2 with value: 2514.226806640625.
# [I 2026-03-16 19:59:17,012] Trial 4 finished with value: 2431.001953125 and parameters: {'n_estimators': 115, 'max_depth': 5, 'learning_rate': 0.0336913696551465, 'subsample': 0.5228679699106697, 'colsample_bytree': 0.9789137752650656}. Best is trial 4 with value: 2431.001953125.
# [I 2026-03-16 19:59:17,892] Trial 5 finished with value: 3143.335205078125 and parameters: {'n_estimators': 92, 'max_depth': 5, 'learning_rate': 0.02110268401035539, 'subsample': 0.7940513316205136, 'colsample_bytree': 0.9244762242162319}. Best is trial 4 with value: 2431.001953125.
# [I 2026-03-16 19:59:19,910] Trial 6 finished with value: 2219.366455078125 and parameters: {'n_estimators': 273, 'max_depth': 6, 'learning_rate': 0.0872754149830903, 'subsample': 0.5256540821877319, 'colsample_bytree': 0.668039402098754}. Best is trial 6 with value: 2219.366455078125.
# [I 2026-03-16 19:59:21,569] Trial 7 finished with value: 2278.83544921875 and parameters: {'n_estimators': 260, 'max_depth': 5, 'learning_rate': 0.03183614745288595, 'subsample': 0.9556659400831797, 'colsample_bytree': 0.5571095192517355}. Best is trial 6 with value: 2219.366455078125.
# [I 2026-03-16 19:59:22,941] Trial 8 finished with value: 2545.476806640625 and parameters: {'n_estimators': 282, 'max_depth': 3, 'learning_rate': 0.012701605877560515, 'subsample': 0.601804351171408, 'colsample_bytree': 0.9415360057353217}. Best is trial 6 with value: 2219.366455078125.
# [I 2026-03-16 19:59:23,666] Trial 9 finished with value: 2608.908447265625 and parameters: {'n_estimators': 66, 'max_depth': 4, 'learning_rate': 0.048136237061530446, 'subsample': 0.9046204973139058, 'colsample_bytree': 0.6825616067733713}. Best is trial 6 with value: 2219.366455078125.
# [I 2026-03-16 19:59:25,441] Trial 10 finished with value: 2206.25537109375 and parameters: {'n_estimators': 207, 'max_depth': 6, 'learning_rate': 0.0994016781280911, 'subsample': 0.7105529584329346, 'colsample_bytree': 0.7709538331576602}. Best is trial 10 with value: 2206.25537109375.
# [I 2026-03-16 19:59:27,154] Trial 11 finished with value: 2145.54541015625 and parameters: {'n_estimators': 200, 'max_depth': 6, 'learning_rate': 0.09356227824182872, 'subsample': 0.7146055090289067, 'colsample_bytree': 0.7744858746901855}. Best is trial 11 with value: 2145.54541015625.
# [I 2026-03-16 19:59:29,571] Trial 12 finished with value: 2188.055419921875 and parameters: {'n_estimators': 198, 'max_depth': 6, 'learning_rate': 0.09611533519101771, 'subsample': 0.7276266404295652, 'colsample_bytree': 0.7990582354035519}. Best is trial 11 with value: 2145.54541015625.
# [I 2026-03-16 19:59:31,247] Trial 13 finished with value: 2269.757080078125 and parameters: {'n_estimators': 185, 'max_depth': 6, 'learning_rate': 0.05816331530328778, 'subsample': 0.7531449891767181, 'colsample_bytree': 0.8047644974643953}. Best is trial 11 with value: 2145.54541015625.
# [I 2026-03-16 19:59:32,970] Trial 14 finished with value: 2242.89599609375 and parameters: {'n_estimators': 213, 'max_depth': 6, 'learning_rate': 0.06760053708207885, 'subsample': 0.8349423276840704, 'colsample_bytree': 0.8441039639366283}. Best is trial 11 with value: 2145.54541015625.
# [I 2026-03-16 19:59:34,230] Trial 15 finished with value: 2196.739990234375 and parameters: {'n_estimators': 171, 'max_depth': 5, 'learning_rate': 0.07532205980185812, 'subsample': 0.6969993119551624, 'colsample_bytree': 0.7273091643429671}. Best is trial 11 with value: 2145.54541015625.
# [I 2026-03-16 19:59:35,663] Trial 16 finished with value: 2263.88330078125 and parameters: {'n_estimators': 230, 'max_depth': 4, 'learning_rate': 0.04999048170516803, 'subsample': 0.6615675854212294, 'colsample_bytree': 0.8815123975959864}. Best is trial 11 with value: 2145.54541015625.
# [I 2026-03-16 19:59:37,108] Trial 17 finished with value: 2254.889892578125 and parameters: {'n_estimators': 180, 'max_depth': 6, 'learning_rate': 0.04412902330186278, 'subsample': 0.8208972087289059, 'colsample_bytree': 0.7342978753953706}. Best is trial 11 with value: 2145.54541015625.
# [I 2026-03-16 19:59:38,351] Trial 18 finished with value: 2340.281494140625 and parameters: {'n_estimators': 160, 'max_depth': 5, 'learning_rate': 0.07667724143435355, 'subsample': 0.7544934879361694, 'colsample_bytree': 0.8077116875734274}. Best is trial 11 with value: 2145.54541015625.
# [I 2026-03-16 19:59:39,633] Trial 19 finished with value: 2253.95361328125 and parameters: {'n_estimators': 205, 'max_depth': 4, 'learning_rate': 0.09880640641427509, 'subsample': 0.9001995296339351, 'colsample_bytree': 0.5007881515540271}. Best is trial 11 with value: 2145.54541015625.
# [I 2026-03-16 19:59:39,634] A new study created in memory with name: no-name-59f0ec8c-199c-4565-8f5f-991bb57f3838
# Tuning XGBRegressor completed. Best MAE: 2145.55
# Initializing tuning for: RandomForestRegressor...
# [I 2026-03-16 19:59:45,586] Trial 0 finished with value: 2875.6652804227733 and parameters: {'n_estimators': 287, 'max_depth': 3, 'min_samples_split': 5}. Best is trial 0 with value: 2875.6652804227733.
# [I 2026-03-16 19:59:48,727] Trial 1 finished with value: 3105.5662670582933 and parameters: {'n_estimators': 133, 'max_depth': 3, 'min_samples_split': 8}. Best is trial 0 with value: 2875.6652804227733.
# [I 2026-03-16 19:59:53,170] Trial 2 finished with value: 2817.098609105132 and parameters: {'n_estimators': 205, 'max_depth': 3, 'min_samples_split': 4}. Best is trial 2 with value: 2817.098609105132.
# [I 2026-03-16 19:59:58,579] Trial 3 finished with value: 3226.091095125403 and parameters: {'n_estimators': 261, 'max_depth': 5, 'min_samples_split': 10}. Best is trial 2 with value: 2817.098609105132.
# [I 2026-03-16 20:00:02,881] Trial 4 finished with value: 2768.4642011715164 and parameters: {'n_estimators': 191, 'max_depth': 4, 'min_samples_split': 5}. Best is trial 4 with value: 2768.4642011715164.
# [I 2026-03-16 20:00:09,084] Trial 5 finished with value: 2849.4236540554184 and parameters: {'n_estimators': 292, 'max_depth': 8, 'min_samples_split': 7}. Best is trial 4 with value: 2768.4642011715164.
# [I 2026-03-16 20:00:10,922] Trial 6 finished with value: 2809.210933861702 and parameters: {'n_estimators': 62, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 4 with value: 2768.4642011715164.
# [I 2026-03-16 20:00:13,558] Trial 7 finished with value: 2542.7333073105783 and parameters: {'n_estimators': 103, 'max_depth': 5, 'min_samples_split': 3}. Best is trial 7 with value: 2542.7333073105783.
# [I 2026-03-16 20:00:17,467] Trial 8 finished with value: 2401.125594807276 and parameters: {'n_estimators': 173, 'max_depth': 9, 'min_samples_split': 2}. Best is trial 8 with value: 2401.125594807276.
# [I 2026-03-16 20:00:19,092] Trial 9 finished with value: 2900.651657257728 and parameters: {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 8}. Best is trial 8 with value: 2401.125594807276.
# [I 2026-03-16 20:00:23,875] Trial 10 finished with value: 2424.758469238169 and parameters: {'n_estimators': 221, 'max_depth': 10, 'min_samples_split': 2}. Best is trial 8 with value: 2401.125594807276.
# [I 2026-03-16 20:00:28,947] Trial 11 finished with value: 2428.5339707113803 and parameters: {'n_estimators': 228, 'max_depth': 10, 'min_samples_split': 2}. Best is trial 8 with value: 2401.125594807276.
# [I 2026-03-16 20:00:32,427] Trial 12 finished with value: 2442.6737033467407 and parameters: {'n_estimators': 149, 'max_depth': 8, 'min_samples_split': 2}. Best is trial 8 with value: 2401.125594807276.
# [I 2026-03-16 20:00:37,354] Trial 13 finished with value: 2467.3162475347394 and parameters: {'n_estimators': 228, 'max_depth': 8, 'min_samples_split': 3}. Best is trial 8 with value: 2401.125594807276.
# [I 2026-03-16 20:00:40,978] Trial 14 finished with value: 2415.3552662426605 and parameters: {'n_estimators': 161, 'max_depth': 9, 'min_samples_split': 2}. Best is trial 8 with value: 2401.125594807276.
# [I 2026-03-16 20:00:44,487] Trial 15 finished with value: 2551.154645360726 and parameters: {'n_estimators': 160, 'max_depth': 7, 'min_samples_split': 4}. Best is trial 8 with value: 2401.125594807276.
# [I 2026-03-16 20:00:47,419] Trial 16 finished with value: 2450.1590658556993 and parameters: {'n_estimators': 117, 'max_depth': 9, 'min_samples_split': 3}. Best is trial 8 with value: 2401.125594807276.
# [I 2026-03-16 20:00:51,262] Trial 17 finished with value: 2627.823050709327 and parameters: {'n_estimators': 170, 'max_depth': 7, 'min_samples_split': 5}. Best is trial 8 with value: 2401.125594807276.
# [I 2026-03-16 20:00:53,588] Trial 18 finished with value: 2489.02355555671 and parameters: {'n_estimators': 88, 'max_depth': 9, 'min_samples_split': 4}. Best is trial 8 with value: 2401.125594807276.
# [I 2026-03-16 20:00:57,960] Trial 19 finished with value: 3108.9354825296914 and parameters: {'n_estimators': 193, 'max_depth': 9, 'min_samples_split': 10}. Best is trial 8 with value: 2401.125594807276.
# Tuning RandomForestRegressor completed. Best MAE: 2401.13

# %% [markdown]
# ## Training

# %%
def add_horizon(cv_df: pd.DataFrame) -> pd.DataFrame:
    cv_df = cv_df.copy()
    cv_df['horizon'] = cv_df.groupby(['region', 'cutoff']).cumcount() + 1
    return cv_df

# %%
best_xgb = XGBRegressor(**best_params_xgb, random_state=0)
best_rf = RandomForestRegressor(**best_params_rf, random_state=0)

mlf = MLForecast(
    models=[
        LinearRegression(),
        best_xgb,
        best_rf
    ],
    freq='QE',
    lags=lags,
)

sf = StatsForecast(
    models=[
        Naive(), 
        HistoricAverage(), 
        WindowAverage(window_size=max(lags)),
        AutoARIMA(season_length=max(lags), approximation=True)
    ],
    freq='QE',
    n_jobs=-1,
)

h_cv = 4
max_num_windows_cv = (one_length - min_train_size - h_cv) // step_size
print(f"max_num_windows for h=4: {max_num_windows_cv}")

cv_results_ml = add_horizon(mlf.cross_validation(
    df=df_train, 
    h=h_cv, 
    step_size=step_size, 
    n_windows=max_num_windows_cv,
    id_col='region', 
    time_col='date', 
    target_col='price',
    static_features=[]
))

cv_results_stat = add_horizon(sf.cross_validation(
    df=df_train, 
    h=h_cv, 
    step_size=step_size, 
    n_windows=max_num_windows_cv,
    id_col='region', 
    time_col='date', 
    target_col='price',
))
# Out:
# max_num_windows for h=4: 10

# %% [markdown]
# ## Results Analysis

# %%
def eval_by_horizon(cv_df: pd.DataFrame, model_cols: List[str]) -> pd.DataFrame:
    rows = []
    
    for model in model_cols:
        row = {'model': model}
        
        for h in range(1, 5):
            subset = cv_df[cv_df['horizon'] == h]
            
            mae = mean_absolute_error(subset['price'], subset[model])
            mae_pct = (mae / subset['price'].mean()) * 100
            rmse = np.sqrt(mean_squared_error(subset['price'], subset[model]))
            
            row[f'H{h} MAE'] = round(mae, 0)
            row[f'H{h} MAE%'] = round(mae_pct, 2)
            row[f'H{h} RMSE'] = round(rmse, 0)
            
        rows.append(row)
    return pd.DataFrame(rows).set_index('model')

# %%
ml_cols = [str(m) for m in mlf.models]
stat_cols = [m.alias for m in sf.models]

table_ml = eval_by_horizon(cv_results_ml, ml_cols)
table_stat = eval_by_horizon(cv_results_stat, stat_cols)

results_table = pd.concat([table_ml, table_stat])

display(results_table.style
    .format({
        col: '{:.2f}%' if 'MAE%' in col
        else '{:.0f}'
        for col in results_table.columns
    })
    .background_gradient(
        cmap='Blues', 
        axis=None,
        subset=[c for c in results_table.columns if 'MAE%' in c]
    )
    .background_gradient(
        cmap='Purples',
        axis=None,
        subset=[c for c in results_table.columns if 'RMSE' in c]
    )
    .set_caption("MAE and RMSE by forecast horizon (H1–H4)")
)
# Out:
# <style type="text/css">
# #T_6ca5d_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6ca5d_row0_col2 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_6ca5d_row0_col4 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_6ca5d_row0_col5 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_6ca5d_row0_col7 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_6ca5d_row0_col8 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_6ca5d_row0_col10, #T_6ca5d_row2_col7 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_6ca5d_row0_col11, #T_6ca5d_row2_col8 {
#   background-color: #a8a6cf;
#   color: #f1f1f1;
# }
# #T_6ca5d_row1_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_6ca5d_row1_col2 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_6ca5d_row1_col4 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_6ca5d_row1_col5, #T_6ca5d_row3_col5 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_6ca5d_row1_col7 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_6ca5d_row1_col8 {
#   background-color: #bdbedc;
#   color: #000000;
# }
# #T_6ca5d_row1_col10 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_6ca5d_row1_col11 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_6ca5d_row2_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_6ca5d_row2_col2 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_6ca5d_row2_col4 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_6ca5d_row2_col5 {
#   background-color: #d7d7e9;
#   color: #000000;
# }
# #T_6ca5d_row2_col10 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_6ca5d_row2_col11 {
#   background-color: #7d77b7;
#   color: #f1f1f1;
# }
# #T_6ca5d_row3_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_6ca5d_row3_col2 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_6ca5d_row3_col4 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_6ca5d_row3_col7 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_6ca5d_row3_col8 {
#   background-color: #c3c4e0;
#   color: #000000;
# }
# #T_6ca5d_row3_col10 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_6ca5d_row3_col11 {
#   background-color: #a5a2cd;
#   color: #f1f1f1;
# }
# #T_6ca5d_row4_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_6ca5d_row4_col2 {
#   background-color: #674ca1;
#   color: #f1f1f1;
# }
# #T_6ca5d_row4_col4 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_6ca5d_row4_col5 {
#   background-color: #572c92;
#   color: #f1f1f1;
# }
# #T_6ca5d_row4_col7 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_6ca5d_row4_col8 {
#   background-color: #4a1486;
#   color: #f1f1f1;
# }
# #T_6ca5d_row4_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6ca5d_row4_col11 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_6ca5d_row5_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_6ca5d_row5_col2 {
#   background-color: #dbdbec;
#   color: #000000;
# }
# #T_6ca5d_row5_col4 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_6ca5d_row5_col5 {
#   background-color: #b5b5d7;
#   color: #000000;
# }
# #T_6ca5d_row5_col7 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_6ca5d_row5_col8 {
#   background-color: #9692c4;
#   color: #f1f1f1;
# }
# #T_6ca5d_row5_col10 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_6ca5d_row5_col11 {
#   background-color: #7e79b8;
#   color: #f1f1f1;
# }
# #T_6ca5d_row6_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_6ca5d_row6_col2 {
#   background-color: #f1f0f6;
#   color: #000000;
# }
# #T_6ca5d_row6_col4 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_6ca5d_row6_col5 {
#   background-color: #d5d5e9;
#   color: #000000;
# }
# #T_6ca5d_row6_col7 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_6ca5d_row6_col8 {
#   background-color: #aeadd3;
#   color: #000000;
# }
# #T_6ca5d_row6_col10 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_6ca5d_row6_col11 {
#   background-color: #8582bc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6ca5d">
#   <caption>MAE and RMSE by forecast horizon (H1–H4)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ca5d_level0_col0" class="col_heading level0 col0" >H1 MAE</th>
#       <th id="T_6ca5d_level0_col1" class="col_heading level0 col1" >H1 MAE%</th>
#       <th id="T_6ca5d_level0_col2" class="col_heading level0 col2" >H1 RMSE</th>
#       <th id="T_6ca5d_level0_col3" class="col_heading level0 col3" >H2 MAE</th>
#       <th id="T_6ca5d_level0_col4" class="col_heading level0 col4" >H2 MAE%</th>
#       <th id="T_6ca5d_level0_col5" class="col_heading level0 col5" >H2 RMSE</th>
#       <th id="T_6ca5d_level0_col6" class="col_heading level0 col6" >H3 MAE</th>
#       <th id="T_6ca5d_level0_col7" class="col_heading level0 col7" >H3 MAE%</th>
#       <th id="T_6ca5d_level0_col8" class="col_heading level0 col8" >H3 RMSE</th>
#       <th id="T_6ca5d_level0_col9" class="col_heading level0 col9" >H4 MAE</th>
#       <th id="T_6ca5d_level0_col10" class="col_heading level0 col10" >H4 MAE%</th>
#       <th id="T_6ca5d_level0_col11" class="col_heading level0 col11" >H4 RMSE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ca5d_level0_row0" class="row_heading level0 row0" >LinearRegression</th>
#       <td id="T_6ca5d_row0_col0" class="data row0 col0" >2135</td>
#       <td id="T_6ca5d_row0_col1" class="data row0 col1" >4.45%</td>
#       <td id="T_6ca5d_row0_col2" class="data row0 col2" >2610</td>
#       <td id="T_6ca5d_row0_col3" class="data row0 col3" >3488</td>
#       <td id="T_6ca5d_row0_col4" class="data row0 col4" >7.08%</td>
#       <td id="T_6ca5d_row0_col5" class="data row0 col5" >4398</td>
#       <td id="T_6ca5d_row0_col6" class="data row0 col6" >5023</td>
#       <td id="T_6ca5d_row0_col7" class="data row0 col7" >10.01%</td>
#       <td id="T_6ca5d_row0_col8" class="data row0 col8" >6140</td>
#       <td id="T_6ca5d_row0_col9" class="data row0 col9" >6856</td>
#       <td id="T_6ca5d_row0_col10" class="data row0 col10" >13.47%</td>
#       <td id="T_6ca5d_row0_col11" class="data row0 col11" >8091</td>
#     </tr>
#     <tr>
#       <th id="T_6ca5d_level0_row1" class="row_heading level0 row1" >XGBRegressor</th>
#       <td id="T_6ca5d_row1_col0" class="data row1 col0" >2483</td>
#       <td id="T_6ca5d_row1_col1" class="data row1 col1" >5.18%</td>
#       <td id="T_6ca5d_row1_col2" class="data row1 col2" >2971</td>
#       <td id="T_6ca5d_row1_col3" class="data row1 col3" >4098</td>
#       <td id="T_6ca5d_row1_col4" class="data row1 col4" >8.32%</td>
#       <td id="T_6ca5d_row1_col5" class="data row1 col5" >4879</td>
#       <td id="T_6ca5d_row1_col6" class="data row1 col6" >5985</td>
#       <td id="T_6ca5d_row1_col7" class="data row1 col7" >11.92%</td>
#       <td id="T_6ca5d_row1_col8" class="data row1 col8" >7057</td>
#       <td id="T_6ca5d_row1_col9" class="data row1 col9" >7692</td>
#       <td id="T_6ca5d_row1_col10" class="data row1 col10" >15.11%</td>
#       <td id="T_6ca5d_row1_col11" class="data row1 col11" >8955</td>
#     </tr>
#     <tr>
#       <th id="T_6ca5d_level0_row2" class="row_heading level0 row2" >RandomForestRegressor</th>
#       <td id="T_6ca5d_row2_col0" class="data row2 col0" >2673</td>
#       <td id="T_6ca5d_row2_col1" class="data row2 col1" >5.57%</td>
#       <td id="T_6ca5d_row2_col2" class="data row2 col2" >3294</td>
#       <td id="T_6ca5d_row2_col3" class="data row2 col3" >4721</td>
#       <td id="T_6ca5d_row2_col4" class="data row2 col4" >9.59%</td>
#       <td id="T_6ca5d_row2_col5" class="data row2 col5" >5758</td>
#       <td id="T_6ca5d_row2_col6" class="data row2 col6" >6766</td>
#       <td id="T_6ca5d_row2_col7" class="data

# %% [markdown]
# ## Graphical Visualization

# %%
def show_graph(df: pd.DataFrame, forecasts: pd.DataFrame) -> None:
    regione = df["region"].unique()

    model_columns = [
        col for col in forecasts.columns
        if col not in ["region", "date"]
    ]

    colors = px.colors.qualitative.Plotly
    model_colors = {
        model: colors[i % len(colors)]
        for i, model in enumerate(model_columns)
    }

    fig = make_subplots(
        rows=len(regione),
        cols=1,
        shared_xaxes=False,
        vertical_spacing=0.02,
        subplot_titles=regione
    )

    trace_map = []

    for i, region in enumerate(regione, start=1):

        real = df[df["region"] == region]
        preds = forecasts[forecasts["region"] == region]

        # Actual
        fig.add_trace(
            go.Scatter(
                x=real["date"],
                y=real["price"],
                mode="lines",
                name="Actual",
                line=dict(color="black", width=4),
                showlegend=(i == 1)
            ),
            row=i,
            col=1
        )

        trace_map.append(("Actual", len(fig.data)-1))

        # Models
        for model in model_columns:
            if model in preds.columns:
                first_pred_date = preds["date"].iloc[0]
                last_actual = real[real["date"] < first_pred_date].iloc[-1]
                
                connector_x = [last_actual["date"]] + list(preds["date"])
                connector_y = [last_actual["price"]] + list(preds[model])
                
                fig.add_trace(
                    go.Scatter(
                        x=connector_x,
                        y=connector_y,
                        mode="lines",
                        name=model,
                        line=dict(color=model_colors[model]),
                        showlegend=(i == 1)
                    ),
                    row=i,
                    col=1
                )

                trace_map.append((model, len(fig.data)-1))

    # DROPDOWN MENU
    buttons = []

    for model in model_columns:
        visibility = []

        for name, idx in trace_map:
            if name == "Actual" or name == model:
                visibility.append(True)
            else:
                visibility.append(False)

        buttons.append(
            dict(
                label=model,
                method="update",
                args=[{"visible": visibility}]
            )
        )

    buttons.insert(
        0,
        dict(
            label="All models",
            method="update",
            args=[{"visible": [True] * len(trace_map)}]
        )
    )

    fig.update_layout(
        height=500 * len(regione),
        width=1100,
        legend=dict(
            orientation="v",
            x=1.02,
            xanchor="left",
            y=0.99,
            yanchor="top"
        ),
        updatemenus=[
            dict(
                buttons=buttons,
                direction="down",
                showactive=True,
                x=1.02,
                xanchor="left",
                y=1.0,
                yanchor="top"
            )
        ]
    )

    fig.show()

# %%
ml_forecasts = (cv_results_ml
    .sort_values("cutoff")
    .groupby(["region", "date"])
    .last()
    .reset_index()
    .drop(columns=["price", "cutoff", "horizon"]))

stat_forecasts = (cv_results_stat
    .sort_values("cutoff")
    .groupby(["region", "date"])
    .last()
    .reset_index()
    .drop(columns=["price", "cutoff", "horizon"]))

combined_forecasts = pd.merge(
    ml_forecasts, 
    stat_forecasts, 
    on=["region", "date"], 
    how="inner"
)

show_graph(df_train, combined_forecasts)

# %% [markdown]
# # Prediction

# %%
mlf.fit(
    df=df_train,
    id_col='region',
    time_col='date',
    target_col='price',
    static_features=[]
)

sf.fit(
    df=df_train,
    id_col='region',
    time_col='date',
    target_col='price'
)

future_dates = sorted(df['date'].unique())[-4:]  # 2024 Q1–Q4

last_known = (df_train.groupby('region')[['corr_neighbors_change_lag1']]
              .last()
              .reset_index())

X_df = pd.concat([
    last_known.assign(date=date) for date in future_dates
])

predictions_sf = sf.predict(h=4, X_df=X_df)
predictions_ml = mlf.predict(h=4, X_df=X_df)

predictions_arima = predictions_sf[['region', 'date', 'AutoARIMA']]

combined_predictions = pd.merge(
    predictions_ml, 
    predictions_arima, 
    on=['region', 'date'], 
    how='inner'
)

# %% [markdown]
# ## Graph Vizualization

# %%
show_graph(df, combined_predictions)
