# %%
import pandas as pd
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
import optuna

from plotly.subplots import make_subplots
from matplotlib import pyplot as plt
from mlforecast import MLForecast
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsforecast import StatsForecast
from statsforecast.models import Naive, HistoricAverage, WindowAverage, AutoARIMA, AutoETS
from typing import Callable, List, Type

# %% [markdown]
# # Helper Functions

# %%
def eval_by_region(cv_df: pd.DataFrame, model_cols: list, caption: str = "MAE% podle regionu") -> None:
    rows = []
    for region in sorted(cv_df['region'].unique()):
        subset = cv_df[cv_df['region'] == region]
        row = {'region': region}
        for model in model_cols:
            mae = mean_absolute_error(subset['price'], subset[model])
            row[model] = round((mae / subset['price'].mean()) * 100, 2)
        rows.append(row)
    
    table = pd.DataFrame(rows).set_index('region')
    
    display(table.style
        .format('{:.2f}%')
        .background_gradient(cmap='Blues', axis=None)
        .highlight_min(axis=1, props='font-weight: bold; border: 3px solid black;')
        .set_caption(caption)
    )

# %%
def add_horizon(cv_df: pd.DataFrame) -> pd.DataFrame:
    cv_df = cv_df.copy()
    cv_df['horizon'] = cv_df.groupby(['region', 'cutoff']).cumcount() + 1
    return cv_df

# %%
def eval_by_horizon(cv_df: pd.DataFrame, model_cols: List[str]) -> pd.DataFrame:
    rows = []
    
    for model in model_cols:
        row = {'model': model}
        
        for h in range(1, 5):
            subset = cv_df[cv_df['horizon'] == h]
            
            mae = mean_absolute_error(subset['price'], subset[model])
            mae_pct = (mae / subset['price'].mean()) * 100
            rmse = np.sqrt(mean_squared_error(subset['price'], subset[model]))
            
            row[f'H{h} MAE'] = round(mae, 0)
            row[f'H{h} MAE%'] = round(mae_pct, 2)
            row[f'H{h} RMSE'] = round(rmse, 0)
            
        rows.append(row)
    return pd.DataFrame(rows).set_index('model')

# %%
def display_eval_table(table: pd.DataFrame, caption: str) -> None:
    table = table.copy()
    
    for metric in ['MAE', 'MAE%', 'RMSE']:
        cols = [c for c in table.columns if c.endswith(metric)]
        table[f'Avg {metric}'] = table[cols].mean(axis=1)
    
    mae_pct_cols = [c for c in table.columns if 'MAE%' in c]
    rmse_cols = [c for c in table.columns if 'RMSE' in c and 'MAE' not in c]

    display(table.style
        .format({
            col: '{:.2f}%' if 'MAE%' in col else '{:.0f}'
            for col in table.columns
        })
        .background_gradient(cmap='Blues', axis=None, subset=mae_pct_cols)
        .background_gradient(cmap='Purples', axis=None, subset=rmse_cols)
        .set_caption(caption)
    )

# %%
def show_graph(df: pd.DataFrame, forecasts: pd.DataFrame) -> None:
    regione = df["region"].unique()

    model_columns = [
        col for col in forecasts.columns
        if col not in ["region", "date"]
    ]

    colors = px.colors.qualitative.Plotly
    model_colors = {
        model: colors[i % len(colors)]
        for i, model in enumerate(model_columns)
    }

    fig = make_subplots(
        rows=len(regione),
        cols=1,
        shared_xaxes=False,
        vertical_spacing=0.02,
        subplot_titles=regione
    )

    trace_map = []

    for i, region in enumerate(regione, start=1):

        real = df[df["region"] == region]
        preds = forecasts[forecasts["region"] == region]

        # Actual
        fig.add_trace(
            go.Scatter(
                x=real["date"],
                y=real["price"],
                mode="lines",
                name="Actual",
                line=dict(color="black", width=3),
                showlegend=(i == 1)
            ),
            row=i,
            col=1
        )

        trace_map.append(("Actual", len(fig.data)-1))

        # Models
        for model in model_columns:
            if model in preds.columns:
                first_pred_date = preds["date"].iloc[0]
                last_actual = real[real["date"] < first_pred_date].iloc[-1]
                
                connector_x = [last_actual["date"]] + list(preds["date"])
                connector_y = [last_actual["price"]] + list(preds[model])
                
                fig.add_trace(
                    go.Scatter(
                        x=connector_x,
                        y=connector_y,
                        mode="lines",
                        name=model,
                        line=dict(color=model_colors[model]),
                        showlegend=(i == 1)
                    ),
                    row=i,
                    col=1
                )

                trace_map.append((model, len(fig.data)-1))

    # DROPDOWN MENU
    buttons = []

    for model in model_columns:
        visibility = []

        for name, idx in trace_map:
            if name == "Actual" or name == model:
                visibility.append(True)
            else:
                visibility.append(False)

        buttons.append(
            dict(
                label=model,
                method="update",
                args=[{"visible": visibility}]
            )
        )

    buttons.insert(
        0,
        dict(
            label="All models",
            method="update",
            args=[{"visible": [True] * len(trace_map)}]
        )
    )

    fig.update_layout(
        height=500 * len(regione),
        width=1100,
        legend=dict(
            orientation="v",
            x=1.02,
            xanchor="left",
            y=0.99,
            yanchor="top"
        ),
        updatemenus=[
            dict(
                buttons=buttons,
                direction="down",
                showactive=True,
                x=1.02,
                xanchor="left",
                y=1.0,
                yanchor="top"
            )
        ]
    )

    fig.show()

# %% [markdown]
# # Load Data

# %%
# Load dataset
df = pd.read_csv("data/dataset_ml.csv", sep=';', parse_dates=['date'], date_format='%d.%m.%Y')

dates_sorted = sorted(df['date'].unique())
holdout_dates = dates_sorted[-4:]           # 2024 Q1–Q4
cutoff_date = holdout_dates[0]              # 2024-03-31

df_train = df[df['date'] < cutoff_date].copy()    # training data
df_holdout = df[df['date'] >= cutoff_date].copy() # holdout data

print(f"Training set ends at:  {df_train['date'].max().date()}")
print(f"Holdout set starts at: {df_holdout['date'].min().date()}")

df.head(10)
# Out:
# Training set ends at:  2023-12-31
# Holdout set starts at: 2024-03-31
#         region       date  price
# 0        praha 2019-03-31  73818
# 1        praha 2019-06-30  75162
# 2        praha 2019-09-30  77202
# 3        praha 2019-12-31  79382
# 4  stredocesky 2019-03-31  28777
# 5  stredocesky 2019-06-30  31328
# 6  stredocesky 2019-09-30  31846
# 7  stredocesky 2019-12-31  32882
# 8    jihocesky 2019-03-31  26028
# 9    jihocesky 2019-06-30  26896

# %%
# Prague only
only_prague = df_train[df_train["region"] == "praha"]
one_length = len(only_prague)
print(one_length)
print(only_prague)
# Out:
# 20
#     region       date   price
# 0    praha 2019-03-31   73818
# 1    praha 2019-06-30   75162
# 2    praha 2019-09-30   77202
# 3    praha 2019-12-31   79382
# 56   praha 2020-03-31   82409
# 57   praha 2020-06-30   84096
# 58   praha 2020-09-30   88315
# 59   praha 2020-12-31   88315
# 112  praha 2021-03-31   93413
# 113  praha 2021-06-30   96950
# 114  praha 2021-09-30  103196
# 115  praha 2021-12-31  109350
# 168  praha 2022-03-31  110995
# 169  praha 2022-06-30  114746
# 170  praha 2022-09-30  114792
# 171  praha 2022-12-31  110171
# 224  praha 2023-03-31  103549
# 225  praha 2023-06-30  103992
# 226  praha 2023-09-30  103859
# 227  praha 2023-12-31  103372

# %%
fig = px.line(
    df_train,
    x="date",
    y="price",
    color="region",
    title="Historical apartment prices in CR",
    color_discrete_sequence=px.colors.qualitative.Alphabet
)

fig.update_yaxes(range=[df["price"].min(), df["price"].max()])

fig.update_layout(
    autosize=True,
    height=500,
    xaxis_title="Price [m2]",
    yaxis_title="Date",
    legend_title="Region"
)

fig.show()

# %%
all_prices = df_train.pivot(index="date", columns="region", values="price").reset_index()
all_prices.describe()
# Out:
# region                 date     jihocesky  jihomoravsky  karlovarsky  \
# count                    20     20.000000     20.000000     20.00000
# mean    2021-08-15 01:12:00  39707.150000  55455.600000  28958.00000
# min     2019-03-31 00:00:00  26028.000000  39865.000000  20701.00000
# 25%     2020-06-07 06:00:00  32658.500000  46353.500000  23192.00000
# 50%     2021-08-15 00:00:00  41073.500000  57148.000000  29828.50000
# 75%     2022-10-23 00:00:00  46287.000000  65222.000000  33729.75000
# max     2023-12-31 00:00:00  52378.000000  69560.000000  37072.00000
# std                     NaN   8825.231545  10839.622728   6012.02003
#
# region  kralovehradecky     liberecky  moravskoslezsky     olomoucky  \
# count         20.000000     20.000000        20.000000     20.000000
# mean       39141.000000  38689.800000     33277.000000  38839.900000
# min        27075.000000  24875.000000     22170.000000  27515.000000
# 25%        31684.750000  31137.000000     26916.500000  31705.750000
# 50%        41026.000000  39067.000000     35189.000000  39138.000000
# 75%        46505.000000  46103.000000     38909.000000  46039.250000
# max        48994.000000  50588.000000     43130.000000  49722.000000
# std         8205.422135   8580.439343      7451.629317   8202.941019
#
# region    pardubicky      plzensky          praha   stredocesky       ustecky  \
# count      20.000000     20.000000      20.000000     20.000000     20.000000
# mean    41436.950000  41583.100000   95854.200000  44749.450000  28782.750000
# min     28214.000000  30769.000000   73818.000000  28777.000000  18357.000000
# 25%     34977.000000  33722.250000   83674.250000  37166.250000  23037.500000
# 50%     42864.000000  42313.000000  100073.000000  46307.000000  30584.000000
# 75%     49818.750000  48177.250000  105331.500000  52822.000000  34273.000000
# max     52349.000000  53267.000000  114792.000000  57688.000000  37495.000000
# std      8746.516085   8267.243198   13773.904868   9723.451334   6581.286851
#
# region      vysocina       zlinsky
# count      20.000000     20.000000
# mean    39296.000000  38291.550000
# min     26948.000000  27871.000000
# 25%     31446.500000  30220.750000
# 50%     39570.500000  39016.500000
# 75%     46639.750000  45472.500000
# max     50247.000000  49553.000000
# std      8257.290361   8036.761874

# %%
order = df_train.groupby("region")["price"].median().sort_values().index

plt.figure(figsize=(12, 6), dpi=200)
sns.boxplot(data=df_train, x="region", y="price", order=order)
plt.xticks(rotation=90)
plt.xlabel("Region")
plt.ylabel("Price [m2]")
plt.title("Boxplot of apartment prices by region")
plt.tight_layout()
plt.show()

# %%
all_prices_diff = all_prices.set_index("date").diff().dropna()
corr_matrix = all_prices_diff.corr()

plt.figure(figsize=(12, 10), dpi=200)
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".3f",
    cmap="coolwarm",
    center=0
)

plt.title("Correlation matrix between cities")
plt.show()

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Hyperparameters

# %%
lags = [1, 2, 3, 4]
h = 4
step_size = 1

max_num_windows = (one_length - max(lags) - h) // step_size
print(max_num_windows)
# Out:
# 12

# %% [markdown]
# ## Random Forest Regressor & XGBoost Hyperparameter Tuning

# %%
def tune_model(model_class: Type, param_func: Callable[[optuna.Trial], dict], n_trials: int=20) -> dict:
    model_name = model_class.__name__
    print(f"Initializing tuning for: {model_name}...")

    def objective(trial):
        params = param_func(trial)
        
        model = model_class(**params)
        
        mlf_tune = MLForecast(
            models=[model],
            freq='QE',
            lags=lags
        )
        
        cv_results = mlf_tune.cross_validation(
            df=df_train, 
            h=h, 
            step_size=step_size,
            n_windows=max_num_windows,
            id_col='region',
            time_col='date', 
            target_col='price',
        )
        
        error = mean_absolute_error(cv_results['price'], cv_results[model_name])
        return error
        
    sampler = optuna.samplers.TPESampler(seed=0)
    study = optuna.create_study(direction='minimize', sampler=sampler)
    study.optimize(objective, n_trials=n_trials)
    
    print(f"Tuning {model_name} completed. Best MAE: {study.best_value:.2f}")
    return study.best_params

# %%
def xgb_params(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 6),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'random_state': 0,
        'n_jobs': -1
    }

def rf_params(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 10),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
        'random_state': 0,
        'n_jobs': -1
    }

best_params_xgb = tune_model(XGBRegressor, xgb_params, 20)
best_params_rf = tune_model(RandomForestRegressor, rf_params, 20)
# Out:
# [I 2026-03-23 12:43:04,704] A new study created in memory with name: no-name-f9e8098e-de8a-47bc-a31e-40f62046df5b
# Initializing tuning for: XGBRegressor...
# [I 2026-03-23 12:43:05,751] Trial 0 finished with value: 4956.54638671875 and parameters: {'n_estimators': 187, 'max_depth': 5, 'learning_rate': 0.040064836619643954, 'subsample': 0.7724415914984484, 'colsample_bytree': 0.7118273996694524}. Best is trial 0 with value: 4956.54638671875.
# [I 2026-03-23 12:43:06,762] Trial 1 finished with value: 4987.78466796875 and parameters: {'n_estimators': 212, 'max_depth': 4, 'learning_rate': 0.0779422611516095, 'subsample': 0.9818313802505146, 'colsample_bytree': 0.6917207594128889}. Best is trial 0 with value: 4956.54638671875.
# [I 2026-03-23 12:43:07,915] Trial 2 finished with value: 5006.34765625 and parameters: {'n_estimators': 248, 'max_depth': 4, 'learning_rate': 0.036986612821028816, 'subsample': 0.9627983191463305, 'colsample_bytree': 0.5355180290989434}. Best is trial 0 with value: 4956.54638671875.
# [I 2026-03-23 12:43:08,428] Trial 3 finished with value: 5103.64453125 and parameters: {'n_estimators': 71, 'max_depth': 2, 'learning_rate': 0.06801737161546002, 'subsample': 0.8890783754749252, 'colsample_bytree': 0.9350060741234096}. Best is trial 0 with value: 4956.54638671875.
# [I 2026-03-23 12:43:09,970] Trial 4 finished with value: 5022.30078125 and parameters: {'n_estimators': 295, 'max_depth': 5, 'learning_rate': 0.028938722964976897, 'subsample': 0.8902645881432277, 'colsample_bytree': 0.5591372129344666}. Best is trial 0 with value: 4956.54638671875.
# [I 2026-03-23 12:43:10,932] Trial 5 finished with value: 4799.5146484375 and parameters: {'n_estimators': 210, 'max_depth': 2, 'learning_rate': 0.08803774642925566, 'subsample': 0.7609241608750359, 'colsample_bytree': 0.7073309699952618}. Best is trial 5 with value: 4799.5146484375.
# [I 2026-03-23 12:43:11,847] Trial 6 finished with value: 5285.5302734375 and parameters: {'n_estimators': 116, 'max_depth': 5, 'learning_rate': 0.028585798773369732, 'subsample': 0.7842169744343243, 'colsample_bytree': 0.5093949002181776}. Best is trial 5 with value: 4799.5146484375.
# [I 2026-03-23 12:43:13,074] Trial 7 finished with value: 5019.603515625 and parameters: {'n_estimators': 205, 'max_depth': 5, 'learning_rate': 0.04139367608357545, 'subsample': 0.9718740392573121, 'colsample_bytree': 0.8409101495517417}. Best is trial 5 with value: 4799.5146484375.
# [I 2026-03-23 12:43:13,850] Trial 8 finished with value: 4749.96435546875 and parameters: {'n_estimators': 140, 'max_depth': 4, 'learning_rate': 0.049846101320948265, 'subsample': 0.5301127358146349, 'colsample_bytree': 0.8333833577228338}. Best is trial 8 with value: 4749.96435546875.
# [I 2026-03-23 12:43:14,762] Trial 9 finished with value: 5353.4853515625 and parameters: {'n_estimators': 218, 'max_depth': 3, 'learning_rate': 0.01345631972964045, 'subsample': 0.6577141754620919, 'colsample_bytree': 0.6818553854713113}. Best is trial 8 with value: 4749.96435546875.
# [I 2026-03-23 12:43:15,684] Trial 10 finished with value: 6683.41650390625 and parameters: {'n_estimators': 127, 'max_depth': 6, 'learning_rate': 0.010489839293581736, 'subsample': 0.5100229215872224, 'colsample_bytree': 0.9746400719702609}. Best is trial 8 with value: 4749.96435546875.
# [I 2026-03-23 12:43:16,358] Trial 11 finished with value: 4849.9658203125 and parameters: {'n_estimators': 143, 'max_depth': 2, 'learning_rate': 0.09066631261472131, 'subsample': 0.6435328022133981, 'colsample_bytree': 0.8144872135983158}. Best is trial 8 with value: 4749.96435546875.
# [I 2026-03-23 12:43:17,094] Trial 12 finished with value: 4781.498046875 and parameters: {'n_estimators': 152, 'max_depth': 3, 'learning_rate': 0.05791622979510821, 'subsample': 0.5344530404843656, 'colsample_bytree': 0.8002996786047625}. Best is trial 8 with value: 4749.96435546875.
# [I 2026-03-23 12:43:17,668] Trial 13 finished with value: 5175.34765625 and parameters: {'n_estimators': 71, 'max_depth': 3, 'learning_rate': 0.053673197393753, 'subsample': 0.5304813556217055, 'colsample_bytree': 0.8592330020327685}. Best is trial 8 with value: 4749.96435546875.
# [I 2026-03-23 12:43:18,410] Trial 14 finished with value: 4865.7802734375 and parameters: {'n_estimators': 154, 'max_depth': 3, 'learning_rate': 0.05586765983043986, 'subsample': 0.5978805467176352, 'colsample_bytree': 0.7844042282157563}. Best is trial 8 with value: 4749.96435546875.
# [I 2026-03-23 12:43:19,054] Trial 15 finished with value: 6003.65869140625 and parameters: {'n_estimators': 105, 'max_depth': 3, 'learning_rate': 0.01899742834327318, 'subsample': 0.5879396742197991, 'colsample_bytree': 0.8928909396168978}. Best is trial 8 with value: 4749.96435546875.
# [I 2026-03-23 12:43:19,929] Trial 16 finished with value: 4916.53369140625 and parameters: {'n_estimators': 160, 'max_depth': 4, 'learning_rate': 0.054224540047382135, 'subsample': 0.6937622468191424, 'colsample_bytree': 0.7682181646417399}. Best is trial 8 with value: 4749.96435546875.
# [I 2026-03-23 12:43:20,673] Trial 17 finished with value: 4898.20947265625 and parameters: {'n_estimators': 93, 'max_depth': 6, 'learning_rate': 0.06460034891907766, 'subsample': 0.5592992243314951, 'colsample_bytree': 0.6447718908083127}. Best is trial 8 with value: 4749.96435546875.
# [I 2026-03-23 12:43:21,586] Trial 18 finished with value: 5114.52880859375 and parameters: {'n_estimators': 174, 'max_depth': 4, 'learning_rate': 0.024761391361561615, 'subsample': 0.7088903805906936, 'colsample_bytree': 0.9044750309214883}. Best is trial 8 with value: 4749.96435546875.
# [I 2026-03-23 12:43:22,603] Trial 19 finished with value: 4739.7509765625 and parameters: {'n_estimators': 255, 'max_depth': 3, 'learning_rate': 0.046269460217693105, 'subsample': 0.5002709094548956, 'colsample_bytree': 0.8007518167756079}. Best is trial 19 with value: 4739.7509765625.
# [I 2026-03-23 12:43:22,605] A new study created in memory with name: no-name-8452c4c6-e862-4bc8-ade5-63d31b2d1fcc
# Tuning XGBRegressor completed. Best MAE: 4739.75
# Initializing tuning for: RandomForestRegressor...
# [I 2026-03-23 12:43:27,429] Trial 0 finished with value: 5825.334094635975 and parameters: {'n_estimators': 187, 'max_depth': 8, 'min_samples_split': 7}. Best is trial 0 with value: 5825.334094635975.
# [I 2026-03-23 12:43:32,197] Trial 1 finished with value: 5966.5869773552 and parameters: {'n_estimators': 186, 'max_depth': 5, 'min_samples_split': 7}. Best is trial 0 with value: 5825.334094635975.
# [I 2026-03-23 12:43:36,170] Trial 2 finished with value: 6617.509294809373 and parameters: {'n_estimators': 159, 'max_depth': 10, 'min_samples_split': 10}. Best is trial 0 with value: 5825.334094635975.
# [I 2026-03-23 12:43:39,941] Trial 3 finished with value: 5637.933701868877 and parameters: {'n_estimators': 146, 'max_depth': 9, 'min_samples_split': 6}. Best is trial 3 with value: 5637.933701868877.
# [I 2026-03-23 12:43:44,976] Trial 4 finished with value: 5248.720879286057 and parameters: {'n_estimators': 192, 'max_depth': 10, 'min_samples_split': 2}. Best is trial 4 with value: 5248.720879286057.
# [I 2026-03-23 12:43:47,272] Trial 5 finished with value: 6015.085094268206 and parameters: {'n_estimators': 71, 'max_depth': 2, 'min_samples_split': 9}. Best is trial 4 with value: 5248.720879286057.
# [I 2026-03-23 12:43:52,847] Trial 6 finished with value: 6657.84628461808 and parameters: {'n_estimators': 245, 'max_depth': 9, 'min_samples_split': 10}. Best is trial 4 with value: 5248.720879286057.
# [I 2026-03-23 12:43:58,498] Trial 7 finished with value: 6406.17612860645 and parameters: {'n_estimators': 250, 'max_depth': 6, 'min_samples_split': 9}. Best is trial 4 with value: 5248.720879286057.
# [I 2026-03-23 12:44:00,931] Trial 8 finished with value: 5289.634981923552 and parameters: {'n_estimators': 79, 'max_depth': 7, 'min_samples_split': 3}. Best is trial 4 with value: 5248.720879286057.
# [I 2026-03-23 12:44:07,547] Trial 9 finished with value: 5489.7672133808055 and parameters: {'n_estimators': 287, 'max_depth': 6, 'min_samples_split': 5}. Best is trial 4 with value: 5248.720879286057.
# [I 2026-03-23 12:44:11,063] Trial 10 finished with value: 5120.340491235788 and parameters: {'n_estimators': 129, 'max_depth': 3, 'min_samples_split': 2}. Best is trial 10 with value: 5120.340491235788.
# [I 2026-03-23 12:44:14,659] Trial 11 finished with value: 5120.340491235787 and parameters: {'n_estimators': 129, 'max_depth': 3, 'min_samples_split': 2}. Best is trial 11 with value: 5120.340491235787.
# [I 2026-03-23 12:44:18,065] Trial 12 finished with value: 5133.30518103229 and parameters: {'n_estimators': 117, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 11 with value: 5120.340491235787.
# [I 2026-03-23 12:44:21,366] Trial 13 finished with value: 5277.555536000126 and parameters: {'n_estimators': 109, 'max_depth': 4, 'min_samples_split': 2}. Best is trial 11 with value: 5120.340491235787.
# [I 2026-03-23 12:44:24,812] Trial 14 finished with value: 5539.527842744607 and parameters: {'n_estimators': 122, 'max_depth': 2, 'min_samples_split': 4}. Best is trial 11 with value: 5120.340491235787.
# [I 2026-03-23 12:44:26,784] Trial 15 finished with value: 5439.631736058426 and parameters: {'n_estimators': 50, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 11 with value: 5120.340491235787.
# [I 2026-03-23 12:44:30,444] Trial 16 finished with value: 5307.4702872587195 and parameters: {'n_estimators': 137, 'max_depth': 4, 'min_samples_split': 2}. Best is trial 11 with value: 5120.340491235787.
# [I 2026-03-23 12:44:33,561] Trial 17 finished with value: 5111.776366081535 and parameters: {'n_estimators': 98, 'max_depth': 3, 'min_samples_split': 4}. Best is trial 17 with value: 5111.776366081535.
# [I 2026-03-23 12:44:36,465] Trial 18 finished with value: 5108.423741161671 and parameters: {'n_estimators': 89, 'max_depth': 3, 'min_samples_split': 4}. Best is trial 18 with value: 5108.423741161671.
# [I 2026-03-23 12:44:39,288] Trial 19 finished with value: 5494.24245328747 and parameters: {'n_estimators': 87, 'max_depth': 5, 'min_samples_split': 5}. Best is trial 18 with value: 5108.423741161671.
# Tuning RandomForestRegressor completed. Best MAE: 5108.42

# %% [markdown]
# ## Training

# %%
best_xgb = XGBRegressor(**best_params_xgb, random_state=0)
best_rf = RandomForestRegressor(**best_params_rf, random_state=0)

mlf = MLForecast(
    models=[
        LinearRegression(),
        best_xgb,
        best_rf
    ],
    freq='QE',
    lags=lags,
)

sf = StatsForecast(
    models=[
        Naive(), 
        HistoricAverage(), 
        WindowAverage(window_size=max(lags)),
        AutoARIMA(season_length=max(lags)),
        AutoETS(season_length=max(lags))
    ],
    freq='QE',
    n_jobs=-1,
)

h_cv = 4
max_num_windows_cv = (one_length - max(lags) - 2 - h_cv) // step_size
print(f"max_num_windows for h=4: {max_num_windows_cv}")

cv_results_ml = add_horizon(mlf.cross_validation(
    df=df_train, 
    h=h_cv, 
    step_size=step_size, 
    n_windows=max_num_windows_cv,
    id_col='region', 
    time_col='date', 
    target_col='price',
))

cv_results_stat = add_horizon(sf.cross_validation(
    df=df_train, 
    h=h_cv, 
    step_size=step_size, 
    n_windows=max_num_windows_cv,
    id_col='region', 
    time_col='date', 
    target_col='price',
))
# Out:
# max_num_windows for h=4: 10

# %% [markdown]
# ## Results Analysis

# %%
table_ml = eval_by_horizon(cv_results_ml, [str(m) for m in mlf.models])
table_stat = eval_by_horizon(cv_results_stat, [m.alias for m in sf.models])

display_eval_table(pd.concat([table_ml, table_stat]), "MAE and RMSE by forecast horizon (H1–H4)")
# Out:
# <style type="text/css">
# #T_e2325_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e2325_row0_col2, #T_e2325_row3_col2 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_e2325_row0_col4 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_e2325_row0_col5 {
#   background-color: #e2e2ef;
#   color: #000000;
# }
# #T_e2325_row0_col7 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_e2325_row0_col8, #T_e2325_row6_col8 {
#   background-color: #b9b9da;
#   color: #000000;
# }
# #T_e2325_row0_col10 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_e2325_row0_col11 {
#   background-color: #8784bd;
#   color: #f1f1f1;
# }
# #T_e2325_row0_col13 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_e2325_row0_col14 {
#   background-color: #cecfe5;
#   color: #000000;
# }
# #T_e2325_row1_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_e2325_row1_col2 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_e2325_row1_col4, #T_e2325_row6_col4 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_e2325_row1_col5 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_e2325_row1_col7 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_e2325_row1_col8 {
#   background-color: #bdbedc;
#   color: #000000;
# }
# #T_e2325_row1_col10 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_e2325_row1_col11, #T_e2325_row2_col11 {
#   background-color: #9591c4;
#   color: #f1f1f1;
# }
# #T_e2325_row1_col13 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_e2325_row1_col14 {
#   background-color: #d3d3e8;
#   color: #000000;
# }
# #T_e2325_row2_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_e2325_row2_col2 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_e2325_row2_col4 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_e2325_row2_col5 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_e2325_row2_col7 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_e2325_row2_col8 {
#   background-color: #b2b2d5;
#   color: #000000;
# }
# #T_e2325_row2_col10 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_e2325_row2_col13 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_e2325_row2_col14 {
#   background-color: #c6c7e1;
#   color: #000000;
# }
# #T_e2325_row3_col1, #T_e2325_row6_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_e2325_row3_col4 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_e2325_row3_col5 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_e2325_row3_col7 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_e2325_row3_col8 {
#   background-color: #c3c4e0;
#   color: #000000;
# }
# #T_e2325_row3_col10, #T_e2325_row5_col13 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_e2325_row3_col11 {
#   background-color: #a5a2cd;
#   color: #f1f1f1;
# }
# #T_e2325_row3_col13, #T_e2325_row7_col4 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_e2325_row3_col14 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_e2325_row4_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_e2325_row4_col2 {
#   background-color: #674ca1;
#   color: #f1f1f1;
# }
# #T_e2325_row4_col4 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_e2325_row4_col5 {
#   background-color: #572c92;
#   color: #f1f1f1;
# }
# #T_e2325_row4_col7 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_e2325_row4_col8 {
#   background-color: #4a1486;
#   color: #f1f1f1;
# }
# #T_e2325_row4_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e2325_row4_col11 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_e2325_row4_col13 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_e2325_row4_col14 {
#   background-color: #51228d;
#   color: #f1f1f1;
# }
# #T_e2325_row5_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_e2325_row5_col2 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_e2325_row5_col4 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_e2325_row5_col5 {
#   background-color: #b6b6d8;
#   color: #000000;
# }
# #T_e2325_row5_col7 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_e2325_row5_col8 {
#   background-color: #9692c4;
#   color: #f1f1f1;
# }
# #T_e2325_row5_col10 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_e2325_row5_col11 {
#   background-color: #7e79b8;
#   color: #f1f1f1;
# }
# #T_e2325_row5_col14 {
#   background-color: #aaa8d0;
#   color: #000000;
# }
# #T_e2325_row6_col2 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_e2325_row6_col5 {
#   background-color: #e2e1ef;
#   color: #000000;
# }
# #T_e2325_row6_col7 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_e2325_row6_col10 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_e2325_row6_col11 {
#   background-color: #8e8bc1;
#   color: #f1f1f1;
# }
# #T_e2325_row6_col13 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_e2325_row6_col14 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_e2325_row7_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_e2325_row7_col2 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_e2325_row7_col5 {
#   background-color: #ddddec;
#   color: #000000;
# }
# #T_e2325_row7_col7 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_e2325_row7_col8 {
#   background-color: #b0afd4;
#   color: #000000;
# }
# #T_e2325_row7_col10 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_e2325_row7_col11 {
#   background-color: #8885be;
#   color: #f1f1f1;
# }
# #T_e2325_row7_col13 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_e2325_row7_col14 {
#   background-color: #cacae3;
#   color: #000000;
# }
# </style>
# <table id="T_e2325">
#   <caption>MAE and RMSE by forecast horizon (H1–H4)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2325_level0_col0" class="col_heading level0 col0" >H1 MAE</th>
#       <th id="T_e2325_level0_col1" class="col_heading level0 col1" >H1 MAE%</th>
#       <th id="T_e2325_level0_col2" class="col_heading level0 col2" >H1 RMSE</th>
#       <th id="T_e2325_level0_col3" class="col_heading level0 col3" >H2 MAE</th>
#       <th id="T_e2325_level0_col4" class="col_heading level0 col4" >H2 MAE%</th>
#       <th id="T_e2325_level0_col5" class="col_heading level0 col5" >H2 RMSE</th>
#       <th id="T_e2325_level0_col6" class="col_heading level0 col6" >H3 MAE</th>
#       <th id="T_e2325_level0_col7" class="col_heading level0 col7" >H3 MAE%</th>
#       <th id="T_e2325_level0_col8" class="col_heading level0 col8" >H3 RMSE</th>
#       <th id="T_e2325_level0_col9" class="col_heading level0 col9" >H4 MAE</th>
#       <th id="T_e2325_level0_col10" class="col_heading level0 col10" >H4 MAE%</th>
#       <th id="T_e2325_level0_col11" class="col_heading level0 col11" >H4 RMSE</th>
#       <th id="T_e2325_level0_col12" class="col_heading level0 col12" >Avg MAE</th>
#       <th id="T_e2325_level0_col13" class="col_heading level0 col13" >Avg MAE%</th>
#       <th id="T_e2325_level0_col14" class="col_heading level0 col14" >Avg RMSE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2325_level0_row0" class="row_heading level0 row0" >LinearRegression</th>
#       <td id="T_e2325_row0_col0" class="data row0 col0" >2187</td>
#       <td id="T_e2325_row0_col1" class="data row0 col1" >4.56%</td>
#       <td id="T_e2325_row0_col2" class="data row0 col2" >2657</td>
#       <td id="T_e2325_row0_col3" class="data row0 col3" >4082</td>
#       <td id="T_e2325_row0_col4" class="data row0 col4" >8.29%</td>
#       <td id="T_e2325_row0_col5" class="data row0 col5" >5050</td>
#       <td id="T_e2325_row0_col6" class="data row0 col6" >5981</td>
#       <td id=

# %%
cv_combined = cv_results_ml.merge(
    cv_results_stat[['region', 'date', 'cutoff', 'horizon', 'AutoARIMA', 'AutoETS']],
    on=['region', 'date', 'cutoff', 'horizon']
)

model_cols_cv = [c for c in cv_combined.columns 
                 if c not in ['region', 'date', 'cutoff', 'horizon', 'price']]

eval_by_region(cv_combined, model_cols_cv, "MAE% podle regionu – cross-validation")
# Out:
# <style type="text/css">
# #T_7a85e_row0_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_7a85e_row0_col1, #T_7a85e_row6_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_7a85e_row0_col2, #T_7a85e_row8_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_7a85e_row0_col3 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_7a85e_row0_col4 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_7a85e_row1_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_7a85e_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_7a85e_row1_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7a85e_row1_col3 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_7a85e_row1_col4, #T_7a85e_row13_col1, #T_7a85e_row13_col4 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_7a85e_row2_col0 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_7a85e_row2_col1 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_7a85e_row2_col2 {
#   background-color: #d0e2f2;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_7a85e_row2_col3 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_7a85e_row2_col4, #T_7a85e_row8_col3 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_7a85e_row3_col0 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_7a85e_row3_col1, #T_7a85e_row3_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_7a85e_row3_col3 {
#   background-color: #eef5fc;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_7a85e_row3_col4 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_7a85e_row4_col0 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_7a85e_row4_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_7a85e_row4_col2 {
#   background-color: #c6dbef;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_7a85e_row4_col3 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_7a85e_row4_col4, #T_7a85e_row6_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_7a85e_row5_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_7a85e_row5_col1 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_7a85e_row5_col2 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_7a85e_row5_col3 {
#   background-color: #7db8da;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_7a85e_row5_col4 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_7a85e_row6_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_7a85e_row6_col1 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_7a85e_row6_col4 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_7a85e_row7_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_7a85e_row7_col1 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_7a85e_row7_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_7a85e_row7_col3 {
#   background-color: #e8f1fa;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_7a85e_row7_col4 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_7a85e_row8_col1 {
#   background-color: #add0e6;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_7a85e_row8_col2 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_7a85e_row8_col4 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_7a85e_row9_col0 {
#   background-color: #eaf3fb;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_7a85e_row9_col1 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_7a85e_row9_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_7a85e_row9_col3 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_7a85e_row9_col4 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_7a85e_row10_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_7a85e_row10_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_7a85e_row10_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_7a85e_row10_col3 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_7a85e_row10_col4 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_7a85e_row11_col0 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_7a85e_row11_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_7a85e_row11_col2 {
#   background-color: #75b4d8;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_7a85e_row11_col3 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_7a85e_row11_col4 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_7a85e_row12_col0 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_7a85e_row12_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_7a85e_row12_col2 {
#   background-color: #dfebf7;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_7a85e_row12_col3 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_7a85e_row12_col4 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_7a85e_row13_col0 {
#   background-color: #a0cbe2;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_7a85e_row13_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_7a85e_row13_col3 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7a85e">
#   <caption>MAE% podle regionu – cross-validation</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a85e_level0_col0" class="col_heading level0 col0" >LinearRegression</th>
#       <th id="T_7a85e_level0_col1" class="col_heading level0 col1" >XGBRegressor</th>
#       <th id="T_7a85e_level0_col2" class="col_heading level0 col2" >RandomForestRegressor</th>
#       <th id="T_7a85e_level0_col3" class="col_heading level0 col3" >AutoARIMA</th>
#       <th id="T_7a85e_level0_col4" class="col_heading level0 col4" >AutoETS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a85e_level0_row0" class="row_heading level0 row0" >jihocesky</th>
#       <td id="T_7a85e_row0_col0" class="data row0 col0" >11.47%</td>
#       <td id="T_7a85e_row0_col1" class="data row0 col1" >10.63%</td>
#       <td id="T_7a85e_row0_col2" class="data row0 col2" >11.07%</td>
#       <td id="T_7a85e_row0_col3" class="data row0 col3" >10.76%</td>
#       <td id="T_7a85e_row0_col4" class="data row0 col4" >12.87%</td>
#     </tr>
#     <tr>
#       <th id="T_7a85e_level0_row1" class="row_heading level0 row1" >jihomoravsky</th>
#       <td id="T_7a85e_row1_col0" class="data row1 col0" >8.78%</td>
#       <td id="T_7a85e_row1_col1" class="data row1 col1" >7.72%</td>
#       <td id="T_7a85e_row1_col2" class="data row1 col2" >17.11%</td>
#       <td id="T_7a85e_row1_col3" class="data row1 col3" >9.38%</td>
#       <td id="T_7a85e_row1_col4" class="data row1 col4" >11.30%</td>
#     </tr>
#     <tr>
#       <th id="T_7a85e_level0_row2" class="row_heading level0 row2" >karlovarsky</th>
#       <td id="T_7a85e_row2_col0" class="data row2 col0" >11.21%</td>
#       <td id="T_7a85e_row2_col1" class="data row2 col1" >13.78%</td>
#       <td id="T_7a85e_row2_col2" class="data row2 col2" >9.59%</td>
#       <td id="T_7a85e_row2_col3" class="data row2 col3" >11.64%</td>
#       <td id="T_7a85e_row2_col4" class="data row2 col4" >13.05%</td>
#     </tr>
#     <tr>
#       <th id="T_7a85e_level0_row3" class="row_heading level0 row3" >kralovehradecky</th>
#       <td id="T_7a85e_row3_col0" class="data row3 col0" >10.01%</td>
#       <td id="T_7a85e_row3_col1" class="data row3 col1" >8.87%</td>
#       <td id="T_7a85e_row3_col2" class="data row3 col2" >8.89%</td>
#       <td id="T_7a85e_row3_col3" class="data row3 col3" >8.18%</td>
#       <td id="T_7a85e_row3_col4" class="data row3 col4" >11.44%</td>
#     </tr>
#     <tr>
#       <th id="T_7a85e_level0_row4" class="row_heading level0 row4" >liberecky</th>

# %% [markdown]
# ## Graphical Visualization

# %%
ml_forecasts = (cv_results_ml
    .sort_values("cutoff")
    .groupby(["region", "date"])
    .last()
    .reset_index()
    .drop(columns=["price", "cutoff", "horizon"]))

stat_forecasts = (cv_results_stat
    .sort_values("cutoff")
    .groupby(["region", "date"])
    .last()
    .reset_index()
    .drop(columns=["price", "cutoff", "horizon"]))

combined_forecasts = pd.merge(
    ml_forecasts, 
    stat_forecasts, 
    on=["region", "date"], 
    how="inner"
)

show_graph(df_train, combined_forecasts)

# %% [markdown]
# # Prediction

# %%
mlf.fit(
    df=df_train,
    id_col='region',
    time_col='date',
    target_col='price'
)

sf.fit(
    df=df_train,
    id_col='region',
    time_col='date',
    target_col='price'
)

h = 4

predictions_sf = sf.predict(h=h)
predictions_ml = mlf.predict(h=h)

predictions_arima = predictions_sf[['region', 'date', 'AutoARIMA', 'AutoETS']]

combined_predictions = pd.merge(
    predictions_ml, 
    predictions_arima, 
    on=['region', 'date'], 
    how='inner'
)

# %% [markdown]
# ## Prediction Evaluation

# %%
combined_predictions = combined_predictions.drop(
    columns=[c for c in combined_predictions.columns if 'Naive' in c],
    errors='ignore'
)

# Naive
naive_pred = (df_train.groupby('region')['price']
              .last()
              .reset_index()
              .rename(columns={'price': 'Naive'}))
future_dates = sorted(df['date'].unique())[-4:]
naive_pred = pd.concat([
    naive_pred.assign(date=date) for date in future_dates
])

combined_predictions = pd.merge(
    combined_predictions,
    naive_pred,
    on=['region', 'date'],
    how='left'
)

df_holdout_eval = df[df['date'].isin(future_dates)][['region', 'date', 'price']]
eval_results = pd.merge(combined_predictions, df_holdout_eval, on=['region', 'date'])

date_to_horizon = {d: i+1 for i, d in enumerate(sorted(future_dates))}
eval_results['horizon'] = eval_results['date'].map(date_to_horizon)

model_cols = [c for c in combined_predictions.columns if c not in ['region', 'date']]
holdout_table = eval_by_horizon(eval_results, model_cols)

display_eval_table(holdout_table, "Model evaluation on holdout (2024 Q1–Q4) by horizon")
# Out:
# <style type="text/css">
# #T_6e4ff_row0_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_6e4ff_row0_col2 {
#   background-color: #eeecf4;
#   color: #000000;
# }
# #T_6e4ff_row0_col4 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_6e4ff_row0_col5 {
#   background-color: #b1b1d5;
#   color: #000000;
# }
# #T_6e4ff_row0_col7 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_6e4ff_row0_col8 {
#   background-color: #7f7bb9;
#   color: #f1f1f1;
# }
# #T_6e4ff_row0_col10 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_6e4ff_row0_col11 {
#   background-color: #5c3696;
#   color: #f1f1f1;
# }
# #T_6e4ff_row0_col13 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_6e4ff_row0_col14 {
#   background-color: #9d99c7;
#   color: #f1f1f1;
# }
# #T_6e4ff_row1_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_6e4ff_row1_col2 {
#   background-color: #f2f0f7;
#   color: #000000;
# }
# #T_6e4ff_row1_col4 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_6e4ff_row1_col5 {
#   background-color: #bebfdd;
#   color: #000000;
# }
# #T_6e4ff_row1_col7 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_6e4ff_row1_col8 {
#   background-color: #8683bd;
#   color: #f1f1f1;
# }
# #T_6e4ff_row1_col10, #T_6e4ff_row2_col10 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_6e4ff_row1_col11 {
#   background-color: #582e92;
#   color: #f1f1f1;
# }
# #T_6e4ff_row1_col13 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_6e4ff_row1_col14 {
#   background-color: #a3a0cb;
#   color: #f1f1f1;
# }
# #T_6e4ff_row2_col1, #T_6e4ff_row3_col1 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_6e4ff_row2_col2 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_6e4ff_row2_col4 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_6e4ff_row2_col5 {
#   background-color: #9390c3;
#   color: #f1f1f1;
# }
# #T_6e4ff_row2_col7 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_6e4ff_row2_col8 {
#   background-color: #7262ac;
#   color: #f1f1f1;
# }
# #T_6e4ff_row2_col11 {
#   background-color: #4d1b89;
#   color: #f1f1f1;
# }
# #T_6e4ff_row2_col13 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_6e4ff_row2_col14 {
#   background-color: #8582bc;
#   color: #f1f1f1;
# }
# #T_6e4ff_row3_col2 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_6e4ff_row3_col4 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_6e4ff_row3_col5 {
#   background-color: #9b97c6;
#   color: #f1f1f1;
# }
# #T_6e4ff_row3_col7 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_6e4ff_row3_col8 {
#   background-color: #694fa2;
#   color: #f1f1f1;
# }
# #T_6e4ff_row3_col10 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_6e4ff_row3_col11 {
#   background-color: #41047f;
#   color: #f1f1f1;
# }
# #T_6e4ff_row3_col13 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_6e4ff_row3_col14 {
#   background-color: #8481bc;
#   color: #f1f1f1;
# }
# #T_6e4ff_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6e4ff_row4_col2 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_6e4ff_row4_col4 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_6e4ff_row4_col5 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_6e4ff_row4_col7 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_6e4ff_row4_col8 {
#   background-color: #d5d5e9;
#   color: #000000;
# }
# #T_6e4ff_row4_col10 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_6e4ff_row4_col11 {
#   background-color: #bdbedc;
#   color: #000000;
# }
# #T_6e4ff_row4_col13 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_6e4ff_row4_col14, #T_6e4ff_row5_col2 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_6e4ff_row5_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_6e4ff_row5_col4 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_6e4ff_row5_col5 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_6e4ff_row5_col7 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_6e4ff_row5_col8 {
#   background-color: #65489f;
#   color: #f1f1f1;
# }
# #T_6e4ff_row5_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6e4ff_row5_col11 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_6e4ff_row5_col13 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_6e4ff_row5_col14 {
#   background-color: #807dba;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6e4ff">
#   <caption>Model evaluation on holdout (2024 Q1–Q4) by horizon</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e4ff_level0_col0" class="col_heading level0 col0" >H1 MAE</th>
#       <th id="T_6e4ff_level0_col1" class="col_heading level0 col1" >H1 MAE%</th>
#       <th id="T_6e4ff_level0_col2" class="col_heading level0 col2" >H1 RMSE</th>
#       <th id="T_6e4ff_level0_col3" class="col_heading level0 col3" >H2 MAE</th>
#       <th id="T_6e4ff_level0_col4" class="col_heading level0 col4" >H2 MAE%</th>
#       <th id="T_6e4ff_level0_col5" class="col_heading level0 col5" >H2 RMSE</th>
#       <th id="T_6e4ff_level0_col6" class="col_heading level0 col6" >H3 MAE</th>
#       <th id="T_6e4ff_level0_col7" class="col_heading level0 col7" >H3 MAE%</th>
#       <th id="T_6e4ff_level0_col8" class="col_heading level0 col8" >H3 RMSE</th>
#       <th id="T_6e4ff_level0_col9" class="col_heading level0 col9" >H4 MAE</th>
#       <th id="T_6e4ff_level0_col10" class="col_heading level0 col10" >H4 MAE%</th>
#       <th id="T_6e4ff_level0_col11" class="col_heading level0 col11" >H4 RMSE</th>
#       <th id="T_6e4ff_level0_col12" class="col_heading level0 col12" >Avg MAE</th>
#       <th id="T_6e4ff_level0_col13" class="col_heading level0 col13" >Avg MAE%</th>
#       <th id="T_6e4ff_level0_col14" class="col_heading level0 col14" >Avg RMSE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e4ff_level0_row0" class="row_heading level0 row0" >LinearRegression</th>
#       <td id="T_6e4ff_row0_col0" class="data row0 col0" >2220</td>
#       <td id="T_6e4ff_row0_col1" class="data row0 col1" >4.21%</td>
#       <td id="T_6e4ff_row0_col2" class="data row0 col2" >2790</td>
#       <td id="T_6e4ff_row0_col3" class="data row0 col3" >3170</td>
#       <td id="T_6e4ff_row0_col4" class="data row0 col4" >5.85%</td>
#       <td id="T_6e4ff_row0_col5" class="data row0 col5" >4169</td>
#       <td id="T_6e4ff_row0_col6" class="data row0 col6" >3323</td>
#       <td id="T_6e4ff_row0_col7" class="data row0 col7" >6.03%</td>
#       <td id="T_6e4ff_row0_col8" class="data row0 col8" >5183</td>
#       <td id="T_6e4ff_row0_col9" class="data row0 col9" >3416</td>
#       <td id="T_6e4ff_row0_col10" class="data row0 col10" >6.11%</td>
#       <td id="T_6e4ff_row0_col11" class="data row0 col11" >6143</td>
#       <td id="T_6e4ff_row0_col12" class="data row0 col12" >3032</td>
#       <td id="T_6e4ff_row0_col13" class="data row0 col13" >5.55%</td>
#       <td id="T_6e4ff_row0_col14" class="data row0 col14" >4571</td>
#     </tr>
#     <tr>
#       <th id="T_6e4ff_level0_row1" class="row_heading level0 row1" >XGBRegressor</th>
#       <td id="T_6e4ff_row1_col0" class="data row1 col0" >2209</td>
#       <td id="T_6e4ff_row1_col1" class="data row1 col1" >4.19%</td>
#       <td id="T_6e4ff_row1_col2" class="data row1 col2" >2603</td>
#       <td id="T_6e4ff_row1_col3" class="data row1 col3" >3335</td>
#       <td id="T_6e4ff_row1_col4" class="data row1 col4" >6.15%</td>
#       <td id="T_6e4ff_row1_col5" class="data row1 col5" >3898</td>
#       <td id="T_6e4ff_row1_col6" class="data row1 col6" >4337</td>
#       <td id="T_6e4ff_row1_col7" class="data row1 col7" >7.87%</td>
#       <td id="T_6

# %% [markdown]
# ## Evaluation By Region

# %%
eval_by_region(eval_results, model_cols, "MAE% podle regionu – holdout (2024)")
# Out:
# <style type="text/css">
# #T_f4aca_row0_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_f4aca_row0_col1, #T_f4aca_row7_col2 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_f4aca_row0_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_f4aca_row0_col3 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_f4aca_row0_col4 {
#   background-color: #dae8f6;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_f4aca_row0_col5 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_f4aca_row1_col0 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_f4aca_row1_col1, #T_f4aca_row2_col5 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_f4aca_row1_col2 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_f4aca_row1_col3 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_f4aca_row1_col4, #T_f4aca_row12_col4 {
#   background-color: #dce9f6;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_f4aca_row1_col5 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_f4aca_row2_col0 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_f4aca_row2_col1 {
#   background-color: #f5fafe;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_f4aca_row2_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_f4aca_row2_col3, #T_f4aca_row3_col1, #T_f4aca_row7_col0 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_f4aca_row2_col4, #T_f4aca_row11_col2, #T_f4aca_row13_col3 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_f4aca_row3_col0 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_f4aca_row3_col2 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_f4aca_row3_col3 {
#   background-color: #e6f0f9;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_f4aca_row3_col4 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_f4aca_row3_col5 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_f4aca_row4_col0 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_f4aca_row4_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_f4aca_row4_col2, #T_f4aca_row11_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_f4aca_row4_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_f4aca_row4_col4, #T_f4aca_row13_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_f4aca_row4_col5 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_f4aca_row5_col0, #T_f4aca_row6_col5 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_f4aca_row5_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_f4aca_row5_col2 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_f4aca_row5_col3 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_f4aca_row5_col4 {
#   background-color: #c9ddf0;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_f4aca_row5_col5 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_f4aca_row6_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_f4aca_row6_col1 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_f4aca_row6_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_f4aca_row6_col3 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_f4aca_row6_col4, #T_f4aca_row11_col4 {
#   background-color: #f7fbff;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_f4aca_row7_col1 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_f4aca_row7_col3, #T_f4aca_row13_col4, #T_f4aca_row13_col5 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_f4aca_row7_col4, #T_f4aca_row10_col4 {
#   background-color: #eef5fc;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_f4aca_row7_col5 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_f4aca_row8_col0 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_f4aca_row8_col1 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_f4aca_row8_col2 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_f4aca_row8_col3 {
#   background-color: #a5cde3;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_f4aca_row8_col4, #T_f4aca_row8_col5 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_f4aca_row9_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_f4aca_row9_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_f4aca_row9_col2 {
#   background-color: #9fcae1;
#   color: #000000;
#   font-weight: bold;
#   border: 3px solid black;
# }
# #T_f4aca_row9_col3 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_f4aca_row9_col4 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_f4aca_row9_col5 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_f4aca_row10_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_f4aca_row10_col1 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_f4aca_row10_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f4aca_row10_col3 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_f4aca_row10_col5, #T_f4aca_row12_col0 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_f4aca_row11_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_f4aca_row11_col3 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_f4aca_row11_col5 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_f4aca_row12_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_f4aca_row12_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_f4aca_row12_col3 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_f4aca_row12_col5 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_f4aca_row13_col0 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_f4aca_row13_col1 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# </style>
# <table id="T_f4aca">
#   <caption>MAE% podle regionu – holdout (2024)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4aca_level0_col0" class="col_heading level0 col0" >LinearRegression</th>
#       <th id="T_f4aca_level0_col1" class="col_heading level0 col1" >XGBRegressor</th>
#       <th id="T_f4aca_level0_col2" class="col_heading level0 col2" >RandomForestRegressor</th>
#       <th id="T_f4aca_level0_col3" class="col_heading level0 col3" >AutoARIMA</th>
#       <th id="T_f4aca_level0_col4" class="col_heading level0 col4" >AutoETS</th>
#       <th id="T_f4aca_level0_col5" class="col_heading level0 col5" >Naive</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4aca_level0_row0" class="row_heading level0 row0" >jihocesky</th>
#       <td id="T_f4aca_row0_col0" class="data row0 col0" >5.00%</td>
#       <td id="T_f4aca_row0_col1" class="data row0 col1" >8.74%</td>
#       <td id="T_f4aca_row0_col2" class="data row0 col2" >4.64%</td>
#       <td id="T_f4aca_row0_col3" class="data row0 col3" >9.67%</td>
#       <td id="T_f4aca_row0_col4" class="data row0 col4" >2.91%</td>
#       <td id="T_f4aca_row0_col5" class="data row0 col5" >8.24%</td>
#     </tr>
#     <tr>
#       <th id="T_f4aca_level0_row1" class="row_heading level0 row1" >jihomoravsky</th>
#       <td id="T_f4aca_row1_col0" class="data row1 col0" >5.76%</td>
#       <td id="T_f4aca_row1_col1" class="data row1 col1" >8.15%</td>
#       <td id="T_f4aca_row1_col2" class="data row1 col2" >12.30%</td>
#       <td id="T_f4aca_row1_col3" class="data row1 col3" >3.43%</td>
#       <td id="T_f4aca_row1_col4" class="data row1 col4" >2.77%</td>
#       <td id="T_f4aca_row1_col5" class="data row1 col5" >8.02%</td>
#     </tr>
#     <tr>
#       <th id="T_f4aca_level0_row2" class="row_heading level0 row2" >karlovarsky</th>
#       <td id="T_f4aca_row2_col0" class="data row2 col0" >3.01%</td>
#       <td id="T_f4aca_row2_col1" class="data row2 col1" >0.71%</td>
#       <td id="T_f4aca_row2_col2" class="data row2 col2" >1.72%</td>
#       <td id="T_f4aca_row2_col3" class="data row2 col3"

# %% [markdown]
# ## Graph Vizualization

# %%
show_graph(df, combined_predictions.drop(columns=['Naive'], errors='ignore'))
